# %%
import pickle

# %%
with open('./res/url_signature.pkl', 'rb') as f:
    signatures = pickle.load(f)

# %%
signatures
# Out:
# {0: [('tien', 91032),
#   ('enda', 91005),
#   ('tienda', 90971),
#   (' HTTP/1.1', 89642),
#   ('.jsp', 69174),
#   ('GET ', 66830),
#   ('GET tienda1', 65366),
#   ('GET tienda1/', 65150),
#   ('blic', 48714),
#   ('public', 48684),
#   ('sp HTTP/1.1', 45946),
#   ('.jsp HTTP/1.1', 45904),
#   ('GET tienda1/publico', 26444),
#   ('GET tienda1/publico/', 26359),
#   ('POST tienda1/publico/', 22210),
#   ('mbros', 20590),
#   ('/miembros', 20560),
#   ('enes', 18716),
#   ('gene', 18674),
#   ('mage', 18674),
#   ('GET tienda1/miembros', 15105),
#   ('GET tienda1/miembros/', 15065),
#   ('a1/i', 14537),
#   ('a1/imagenes', 12472),
#   ('tica', 12456),
#   ('a1/imagenes/', 12441),
#   ('ntra', 11511),
#   ('stro', 10670),
#   ('f HTTP/1.1', 10369),
#   ('o.jsp', 10129),
#   ('r HTTP/1.1', 8530),
#   ('loba', 8391),
#   ('a1/global', 8361),
#   ('logi', 8352),
#   ('a1/global/', 8328),
#   ('&login=', 8237),
#   ('edit', 7989),
#   ('ir.jsp', 7987),
#   ('arri', 7472),
#   ('carr', 7399),
#   ('rito', 7308),
#   ('carri', 7308),
#   ('nombre', 7278),
#   ('ncia', 7278),
#   ('carrito', 7278),
#   ('&nombre=', 7166),
#   ('stra', 6891),
#   ('enti', 6791),
#   ('icar', 6741),
#   ('tent', 6735),
#   ('gar.', 6597),
#   ('agar', 6597),
#   ('tos.', 6252),
#   ('tos.jsp', 6218),
#   ('GET tienda1/miembros/imagenes/', 6172),
#   ('anad', 6003),
#   ('tar.', 5940),
#   ('nadir', 5921),
#   ('GET tienda1/publico/a', 5918),
#   ('acia', 5783),
#   ('rist', 5780),
#   ('stic', 5770),
#   ('iar.', 5762),
#   ('ciar', 5762),
#   ('teri', 5724),
#   ('arac', 5714),
#   ('icas', 5713),
#   ('risti', 5712),
#   ('cara', 5712),
#   ('stica', 5710),
#   ('ract', 5710),
#   ('&ntc=', 5668),
#   ('&dni=', 5471),
#   ('cion', 5449),
#   ('ccion', 5343),
#   ('&cp=', 5332),
#   ('recio', 5330),
#   ('eccion', 5313),
#   ('GET tienda1/publico/p', 5295),
#   ('&direccion=', 5283),
#   ('%2C+', 5249),
#   ('&precio=', 5153),
#   ('do=registro', 5040),
#   ('tro&login=', 5037),
#   ('do=registro&login=', 4996),
#   ('=Reg', 4814),
#   ('iudad', 4787),
#   ('B1=Registrar HTTP/1.1', 4785),
#   ('&ciudad=', 4728),
#   ('elli', 4708),
#   ('pell', 4674),
#   ('&B1=Registrar HTTP/1.1', 4652),
#   ('idos', 4651),
#   ('apell', 4643),
#   ('lido', 4642),
#   ('&apellidos=', 4613),
#   ('rovi', 4273),
#   ('&provincia=', 4243),
#   ('inde', 4189),
#   ('/index.jsp', 4154),
#   ('o.jpg HTTP/1.1', 4024),
#   ('passw', 3890),
#   ('&password=', 3857),
#   ('&email=', 3747),
#   ('a&ntc=', 3721),
#   ('POST tienda1/publico/anadir.jsp HTTP/1.1', 3379),
#   ('POST tienda1/miembros/editar.jsp HTTP/1.1', 3361),
#   ('co/registro.jsp HTTP/1.1', 3361),
#   ('POST tienda1/publico/autenticar.jsp HTTP/1.1', 3359),
#   ('GET tienda1/publico/autenticar.jsp', 3346),
#   ('POST tienda1/publico/pagar.jsp HTTP/1.1', 3342),
#   ('GET tienda1/publico/autenticar.jsp?modo', 3270),
#   ('POST tienda1/publico/registro.jsp HTTP/1.1', 3263),
#   ('GET tienda1/publico/pagar.jsp', 3225),
#   ('rar&', 3213),
#   ('GET tienda1/publico/autenticar.jsp?modo=', 3185),
#   ('&direccion=C', 3184),
#   ('%F1a', 3183),
#   ('erta', 3166),
#   ('GET tienda1/publico/pagar.jsp?modo', 3158),
#   ('GET tienda1/publico/autenticar.jsp?modo=entrar', 3146),
#   ('=entrar&login=', 3102),
#   ('GET tienda1/publico/autenticar.jsp?modo=entrar&login', 3101),
#   ('enci', 3035),
#   ('GET tienda1/publico/pagar.jsp?modo=', 3027),
#   ('GET tienda1/publico/autenticar.jsp?modo=entrar&login=', 3021),
#   ('encia', 3003),
#   ('GET tienda1/publico/pagar.jsp?modo=insertar', 2963),
#   ('POST tienda1/publico/caracteristicas.jsp HTTP/1.1', 2950),
#   ('POST tienda1/publico/vaciar.jsp HTTP/1.1', 2916),
#   ('POST tienda1/publico/entrar.jsp HTTP/1.1', 2894),
#   ('GET tienda1/publico/pagar.jsp?modo=insertar&precio', 2893),
#   ('GET tienda1/publico/vaciar.jsp', 2816),
#   ('erro', 2773),
#   ('&pwd=', 2754),
#   ('orre', 2754),
#   ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=', 2747),
#   ('GET tienda1/publico/caracteristicas.jsp', 2730),
#   ('GET tienda1/publico/entrar.jsp', 2721),
#   ('logo', 2710),
#   ('ales', 2703),
#   ('les+', 2672),
#   ('=Entra', 2639),
#   ('GET tienda1/publico/registro.jsp', 2636),
#   ('%F1ad', 2612),
#   ('=Entrar HTTP/1.1', 2609),
#   ('cial', 2599),
#   ('ales+', 2598),
#   ('A%F1a', 2581),
#   ('+al+', 2581),
#   ('&B1=Entrar HTTP/1.1', 2578),
#   ('inco', 2575),
#   ('rede', 2575),
#   ('encial', 2566),
#   ('iales', 2566),
#   ('corr', 2566),
#   ('GET tienda1/publico/registro.jsp?modo=', 2555),
#   ('&B1=A%F1adir+al+carrito HTTP/1.1', 2551),
#   ('GET tienda1/miembros/editar.jsp', 2549),
#   ('mber', 2535),
#   ('anti', 2530),
#   ('GET tienda1/publico/registro.jsp?modo=registro&login=', 2521),
#   ('GET tienda1/publico/anadir.jsp', 2512),
#   ('cant', 2489),
#   ('GET tienda1/miembros/editar.jsp?modo=', 2485),
#   ('idad', 2471),
#   ('GET tienda1/miembros/editar.jsp?modo=registro&login=', 2434),
#   ('&cantidad=', 2405),
#   ('+&ciudad=', 2333),
#   ('GET tienda1/publico/vaciar.jsp?B2=', 2291),
#   ('erra', 2271),
#   ('GET tienda1/publico/entrar.jsp?errorMsg=', 2214),
#   ('GET tienda1/publico/caracteristicas.jsp?id=', 2202),
#   ('GET tienda1/publico/vaciar.jsp?B2=Vaciar+carrito', 2182),
#   ('ierra', 2128),
#   ('ros.', 2120),
#   ('GET tienda1/publico/entrar.jsp?errorMsg=Credenciales+incorrectas', 2097),
#   ('astro', 2093),
#   ('sali', 2092),
#   ('itos', 2085),
#   ('ros.jsp', 2084),
#   ('titu', 2083),
#   ('esti', 2081),
#   ('estr', 2081),
#   ('GET tienda1/miembros/index.jsp', 2076),
#   ('los.', 2069),
#   ('zara', 2068),
#   ('GET tienda1/publico/carrito', 2066),
#   ('cast', 2066),
#   ('os/salir.jsp', 2062),
#   ('co/miembros', 2061),
#   ('rati', 2058),
#   ('ditos.jsp', 2056),
#   ('os/fotos.jsp', 2055),
#   ('a1/global/titulo.jsp', 2052),
#   ('stil', 2052),
#   ('uest', 2051),
#   ('a1/global/menum.jsp', 2049),
#   ('ito.', 2048),
#   ('duct', 2047),
#   ('ctos', 2047),
#   ('a1/global/credit', 2045),
#   ('ono.', 2038),
#   ('os.c', 2037),
#   ('GET tienda1/miembros/imagenes/castro.j', 2033),
#   ('%2C+1', 2031),
#   ('ros.jsp HTTP/1.1', 2026),
#   ('a1/index.jsp HTTP/1.1', 2021),
#   ('a1/imagenes/2.gif HTTP/1.1', 2021),
#   ('a1/imagenes/3.gif HTTP/1.1', 2021),
#   ('a1/imagenes/nuestratierra.jpg HTTP/1.1', 2021),
#   ('os/fotos.jsp HTTP/1.1', 2020),
#   ('os/salir.jsp HTTP/1.1', 2020),
#   ('a1/imagenes/1.gif HTTP/1.1', 2020),
#   ('a1/imagenes/cmenbul.gif HTTP/1.1', 2020),
#   ('a1/imagenes/logo.gif HTTP/1.1', 2020),
#   ('ito.jsp HTTP/1.1', 2017),
#   ('ditos.jsp HTTP/1.1', 2017),
#   ('o/productos.jsp HTTP/1.1', 2017),
#   ('GET tienda1/publico/entrar.jsp?errorMsg=Credenciales+incorrectas HTTP/1.1',
#    2008),
#   ('GET tienda1/publico/vaciar.jsp?B2=Vaciar+carrito HTTP/1.1', 2008),
#   ('GET tienda1/miembros/index.jsp HTTP/1.1', 2008),
#   ('a1/global/menum.jsp HTTP/1.1', 2007),
#   ('a1/global/titulo.jsp HTTP/1.1', 2007),
#   ('a1/global/estilos.css HTTP/1.1', 2007),
#   ('GET tienda1/miembros/imagenes/ogono.jpg HTTP/1.1', 2007),
#   ('GET tienda1/miembros/imagenes/zarauz.jpg HTTP/1.1', 2007),
#   ('GET tienda1/miembros/imagenes/castro.jpg HTTP/1.1', 1980),
#   ('GET tienda1/publico/carrito.jsp HTTP/1.1', 1964),
#   ('a1/global/creditos.jsp HTTP/1.1', 1949),
#   ('GET tienda1/publico/productos.jsp HTTP/1.1', 1857),
#   ('a&cp=', 1751),
#   ('&direccion=Ca', 1671),
#   ('alle', 1654),
#   ('a&apellidos=', 1623),
#   ('GET tienda1/imagenes/logo.gif HTTP/1.1', 1595),
#   ('GET tienda1/imagenes/nuestratierra.jpg HTTP/1.1', 1595),
#   ('GET tienda1/index.jsp HTTP/1.1', 1594),
#   ('GET tienda1/imagenes/1.gif HTTP/1.1', 1594),
#   ('GET tienda1/imagenes/2.gif HTTP/1.1', 1594),
#   ('GET tienda1/imagenes/3.gif HTTP/1.1', 1594),
#   ('GET tienda1/imagenes/cmenbul.gif HTTP/1.1', 1594),
#   ('GET tienda1/miembros/fotos.jsp HTTP/1.1', 1553),
#   ('GET tienda1/miembros/salir.jsp HTTP/1.1', 1552),
#   ('a HTTP/1.1', 1533),
#   ('Calle', 1514),
#   ('%F3n', 1512),
#   ('alle+', 1486),
#   ('+de+', 1462),
#   ('&cp=4', 1440),
#   ('=Pas', 1440),
#   ('&direccion=Calle', 1425),
#   ('&direccion=C%2F+', 1405),
#   ('&direccion=Calle+', 1395),
#   ('0&provincia=', 1383),
#   ('asar', 1343),
#   ('=Pasa', 1338),
#   ('off&', 1291),
#   ('1 HTTP/1.1', 1280),
#   ('=off&B1=Entrar HTTP/1.1', 1262),
#   ('&remember=on&B1=Entrar HTTP/1.1', 1241),
#   ('&remember=off&B1=Entrar HTTP/1.1', 1231),
#   ('a&nombre=', 1197),
#   ('s&cp=', 1193),
#   ('=Con', 1159),
#   ('%2C+&ciudad=', 1156),
#   ('&cp=0', 1096),
#   ('&B1=Confirmar HTTP/1.1', 1094),
#   ('o&apellidos=', 1083),
#   ('GET tienda1/publico/caracteristicas.jsp?id=2', 1080),
#   ('co/miembros.jsp HTTP/1.1', 1080),
#   ('GET tienda1/publico/caracteristicas.jsp?id=2 HTTP/1.1', 1036),
#   ('GET tienda1/publico/caracteristicas.jsp?id=1', 1024),
#   ('&nombre=J', 992),
#   ('GET tienda1/publico/caracteristicas.jsp?id=1 HTTP/1.1', 978),
#   ('+Rio', 960),
#   ('a&email=', 942),
#   ('+Rioja&', 921),
#   ('&nombre=Vi', 920),
#   ('&cp=3', 902),
#   ('1&nombre=', 886),
#   ('&cp=2', 880),
#   ('3&nombre=', 880),
#   ('o&cp=', 878),
#   ('GET tienda1/publico/anadir.jsp?id=3', 872),
#   ('ino+', 868),
#   ('2&nombre=', 854),
#   ('a%2C+', 852),
#   ('&cp=1', 845),
#   ('o&nombre=', 842),
#   ('ico&', 840),
#   ('rico', 838),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre', 831),
#   ('Vino', 831),
#   ('100&', 816),
#   ('anch', 811),
#   ('=39&', 803),
#   ('%F3n+', 799),
#   ('nche', 791),
#   ('ego&', 790),
#   ('n%40', 783),
#   ('=85&', 779),
#   ('+De+', 778),
#   ('rico&', 778),
#   ('%E9r', 773),
#   ('+Man', 770),
#   ('&nombre=Jam', 770),
#   ('b%E9', 770),
#   ('co&p', 769),
#   ('o+Ma', 761),
#   ('=Que', 761),
#   ('anche', 760),
#   ('GET tienda1/publico/anadir.jsp?id=1&nombre', 744),
#   ('%40c', 741),
#   ('in=m', 738),
#   ('jsp/', 730),
#   ('illa', 719),
#   ('s%2C+', 713),
#   ('%F3n&', 669),
#   ('&ntc=5', 655),
#   ('&provincia=C', 655),
#   ('ad=C', 651),
#   ('&dni=3', 642),
#   ('&ntc=3', 642),
#   ('&apellidos=C', 633),
#   ('&ntc=8', 623),
#   ('&ntc=9', 618),
#   ('&ntc=2', 609),
#   ('in=s', 607),
#   ('in=c', 604),
#   ('&direccion=P', 604),
#   ('s&email=', 597),
#   ('&ntc=7', 587),
#   ('&ntc=0', 584),
#   ('&dni=9', 581),
#   ('1&B1=Registrar HTTP/1.1', 577),
#   ('&apellidos=M', 575),
#   ('4&B1=Registrar HTTP/1.1', 573),
#   ('a+de+', 573),
#   ('&dni=0', 568),
#   ('&dni=4', 567),
#   ('&dni=1', 548),
#   ('&apellidos=B', 541),
#   ('.com', 540),
#   ('%40e', 540),
#   ('6&B1=Registrar HTTP/1.1', 534),
#   ('&ntc=6', 533),
#   ('&dni=7', 527),
#   ('re=A', 525),
#   ('ona&', 525),
#   ('ide.', 525),
#   ('in=b', 520),
#   ('cia&', 515),
#   ('s%2C+1', 509),
#   ('e&password=', 508),
#   ('&dni=6', 508),
#   ('&dni=5', 501),
#   ('ad=V', 498),
#   ('ad=A', 491),
#   ('a&cp=4', 490),
#   ('+S%2', 489),
#   ('&dni=8', 487),
#   ('&email=b', 484),
#   ('=San', 482),
#   ('.com.', 474),
#   ('a&ntc=3', 472),
#   ('arra', 468),
#   ('%40s', 465),
#   ('+S%2FN', 459),
#   ('&provincia=S', 459),
#   ('2&B1=Registrar HTTP/1.1', 458),
#   ('ente', 457),
#   ('o&email=', 454),
#   ('GET tienda1/publico/vaciar.jsp?B2A=Vaciar+carrito HTTP/1.1', 448),
#   ('%40m', 447),
#   ('rago', 447),
#   ('7&B1=Registrar HTTP/1.1', 444),
#   ('&provincia=G', 444),
#   ('ad=S', 443),
#   ('&ntc=1', 443),
#   ('&password=c', 442),
#   ('GET tienda1/publico/entrar.jsp?errorMsgA=Credenciales+incorrectas HTTP/1.1',
#    440),
#   ('a%40', 439),
#   ('n&apellidos=', 439),
#   ('9&provincia=', 437),
#   ('r%40', 434),
#   ('nte&', 434),
#   ('3&B1=Registrar HTTP/1.1', 432),
#   ('n&password=', 427),
#   ('jsp.', 426),
#   ('&email=s', 426),
#   ('in=a', 425),
#   ('&email=m', 423),
#   ('0&B1=Registrar HTTP/1.1', 420),
#   ('9&B1=Registrar HTTP/1.1', 418),
#   ('a&ntc=5', 418),
#   ('a&ntc=9', 416),
#   ('a&ntc=2', 411),
#   ('&dni=2', 411),
#   ('%40a', 409),
#   ('=Val', 403),
#   ('in=d', 398),
#   ('ia=L', 397),
#   ('ad=P', 393),
#   ('+del', 393),
#   ('+San', 392),
#   ('5&B1=Registrar HTTP/1.1', 391),
#   ('io&apellidos=', 389),
#   ('a%2C+1', 382),
#   ('a&ntc=8', 380),
#   ('Sant', 380),
#   ('r&nombre=', 376),
#   ('o%2C+', 375),
#   ('a&ntc=7', 374),
#   ('a&cp=2', 373),
#   ('8&B1=Registrar HTTP/1.1', 373),
#   ('a&password=', 372),
#   ('na&apellidos=', 366),
#   ('a&cp=0', 360),
#   ('2569', 359),
#   ('69%2', 359),
#   ('a&ntc=6', 353),
#   ('2574', 352),
#   ('San+', 351),
#   ('a&ntc=0', 348),
#   ('alen', 345),
#   ('1&provincia=', 343),
#   ('e&pwd=', 341),
#   ('in=t', 336),
#   ('anta', 333),
#   ('in=h', 331),
#   ('2&provincia=', 331),
#   ('%40p', 328),
#   ('&provincia=L', 324),
#   ('ia=Za', 324),
#   ('re=S', 323),
#   ('/ HTTP/1.1', 322),
#   ('y%40', 315),
#   ('in=r', 314),
#   ('os=A', 311),
#   ('&direccion=Pl', 308),
#   ('ad=Ca', 308),
#   ('in=l', 307),
#   ('e%40', 306),
#   ('ana&', 306),
#   ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=1', 305),
#   ('7&B1=A%F1adir+al+carrito HTTP/1.1', 304),
#   ('5&B1=A%F1adir+al+carrito HTTP/1.1', 303),
#   ('=Vil', 303),
#   ('ad=Sa', 302),
#   ('te&n', 301),
#   ('s&cp=4', 300),
#   ('e+Sa', 299),
#   ('e&nombre=', 297),
#   ('a&ntc=1', 295),
#   ('s%40', 293),
#   ('del+', 292),
#   ('in=k', 290),
#   ('n&pwd=', 288),
#   ('s&cp=3', 285),
#   ('il=c', 281),
#   ('ad=M', 278),
#   ('in=p', 277),
#   ('ad=B', 277),
#   ('4&B1=A%F1adir+al+carrito HTTP/1.1', 274),
#   ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=8', 273),
#   ('A&ciudad=', 273),
#   ('1&B1=A%F1adir+al+carrito HTTP/1.1', 272),
#   ('ad=Vi', 272),
#   ('arag', 272),
#   ('a&remember=off&B1=Entrar HTTP/1.1', 271),
#   ('lencia', 270),
#   ('ment', 269),
#   ('.gif/', 267),
#   ('a&remember=on&B1=Entrar HTTP/1.1', 266),
#   ('6&B1=A%F1adir+al+carrito HTTP/1.1', 266),
#   ('rd=a', 266),
#   ('urgo', 266),
#   ('1&nombre=Qu', 266),
#   ('&ntc=4', 265),
#   ('ia=T', 264),
#   ('4&provincia=', 263),
#   ('+del+', 262),
#   ('/6909030637832563290.jsp', 261),
#   ('a&cp=1', 261),
#   ('e+la', 261),
#   ('+de+l', 261),
#   ('a&apellidos=C', 258),
#   ('C&direccion=', 258),
#   ('ad=San', 256),
#   ('Villa', 256),
#   ('o&remember=off&B1=Entrar HTTP/1.1', 255),
#   ('E%256', 253),
#   ('os=P', 253),
#   ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=3', 248),
#   ('s&cp=0', 248),
#   ('jsp/asf-logo-wide.', 246),
#   ('9&B1=A%F1adir+al+carrito HTTP/1.1', 244),
#   ('6&provincia=', 244),
#   ('re=R', 243),
#   ('1&nombre=J', 243),
#   ('7&provincia=', 242),
#   ('=Zar', 242),
#   ('alencia', 241),
#   ('a&apellidos=B', 241),
#   ('o&remember=on&B1=Entrar HTTP/1.1', 239),
#   ('ad=Vil', 239),
#   ('=Bar', 237),
#   ('=Burgo', 237),
#   ('s+de+', 236),
#   ('%F3n&n', 236),
#   ('s&cp=1', 235),
#   ('a&cp=3', 233),
#   ('H&ciudad=', 233),
#   ('i%40', 233),
#   ('0&B1=A%F1adir+al+carrito HTTP/1.1', 232),
#   ('D&ciudad=', 232),
#   ('+la+', 231),
#   ('o&cp=4', 230),
#   ('ad=2', 229),
#   ('er%40', 229),
#   ('l&apellidos=', 229),
#   ('GET tienda1/publico/caracteristicas.jsp?idA=1 HTTP/1.1', 227),
#   ('ara&', 227),
#   ('8&B1=A%F1adir+al+carrito HTTP/1.1', 226),
#   ('C HTTP/1.1', 226),
#   ('C&ciudad=', 225),
#   ('in=g', 221),
#   ('r&password=', 221),
#   ('GET tienda1/publico/caracteristicas.jsp?idA=2 HTTP/1.1', 220),
#   ('ad=3', 220),
#   ('ia&apellidos=', 220),
#   ('=Villa', 220),
#   ('.Old HTTP/1.1', 219),
#   ('0 HTTP/1.1', 218),
#   ('ros%', 217),
#   ('o%2C+1', 216),
#   ('ada&', 215),
#   ('V&direccion=', 215),
#   ('era&', 214),
#   ('%F1a&', 214),
#   ('8&provincia=', 213),
#   ('ina&', 213),
#   ('252E%256', 212),
#   ('B&ciudad=', 212),
#   ('.old HTTP/1.1', 211),
#   ('io=2', 211),
#   ('arce', 211),
#   ('Juan', 211),
#   ('ad=1', 210),
#   ('nte&n', 210),
#   ('%2C+13', 210),
#   ('L&direccion=', 209),
#   ('enca', 209),
#   ('io=7', 208),
#   ('%EDa', 208),
#   ('Cast', 207),
#   ('3&B1=A%F1adir+al+carrito HTTP/1.1', 205),
#   ('illo', 204),
#   ('0&provincia=C', 204),
#   ('a&ntc=4', 204),
#   ('re=M', 203),
#   ('io=5', 202),
#   ('e HTTP/1.1', 202),
#   ('E&ciudad=', 202),
#   ('3&provincia=', 202),
#   ('a&apellidos=M', 201),
#   ('e+la+', 201),
#   ('ad=8', 199),
#   ('X&direccion=', 199),
#   ('in=ma', 198),
#   ('7%2C+', 198),
#   ('odoA=', 197),
#   ('B%256', 197),
#   ('ad=4', 196),
#   ('ad=5', 196),
#   ('5&provincia=', 196),
#   ('onte', 196),
#   ('.Inc HTTP/1.1', 195),
#   ('.java HTTP/1.1', 191),
#   ('ente&', 190),
#   ('ad=Villa', 189),
#   ('Q&direccion=', 188),
#   ('loca', 187),
#   ('+San+', 187),
#   ('er&p', 187),
#   ('%E9n', 187),
#   ('.bak HTTP/1.1', 186),
#   ('in=j', 186),
#   ('http', 186),
#   ('e+La', 186),
#   ('2&B1=A%F1adir+al+carrito HTTP/1.1', 185),
#   ('=Cas', 185),
#   ('+Val', 184),
#   ('a+De', 184),
#   ('=Nav', 184),
#   ('.inc HTTP/1.1', 183),
#   ('Nava', 183),
#   ('ntan', 183),
#   ('=Cam', 183),
#   ('as%2C+', 182),
#   ('=Cue', 181),
#   ('ET a', 180),
#   ('o&cp=0', 180),
#   ('%40co', 180),
#   ('an%40', 180),
#   ('ad=7', 179),
#   ('uenca&', 179),
#   ('ad=9', 178),
#   ('arcelona', 178),
#   ('da&apellidos=', 177),
#   ('.OLD HTTP/1.1', 176),
#   ('erna', 174),
#   ('io=4', 173),
#   ('ad=R', 171),
#   ('ad=Sant', 171),
#   ('ra&nombre=', 170),
#   ('ad=Al', 170),
#   ('+de+la+', 170),
#   ('7&B1=Pasar+por+caja HTTP/1.1', 169),
#   ('o&cp=2', 168),
#   ('io=6', 167),
#   ('re=N', 166),
#   ('W&direccion=', 165),
#   ('~ HTTP/1.1', 162),
#   ('&apellidos=A', 162),
#   ('0&provincia=B', 162),
#   ('ares', 162),
#   ('cioA=', 161),
#   ('+De+L', 161),
#   ('J&direccion=', 161),
#   ('ia=A', 160),
#   ('.BAK HTTP/1.1', 159),
#   ('a+del', 159),
#   ('.Bak HTTP/1.1', 156),
#   ('es%2C+', 156),
#   ('n%2C+', 155),
#   ('re=Ma', 154),
#   ('=Nava', 154),
#   ('n%40a', 154),
#   ('%2C+10', 154),
#   ('n&nombre=', 154),
#   ('e%F1', 154),
#   ('io=9', 153),
#   ('F&ciudad=', 153),
#   ('Z&direccion=', 153),
#   ('r%2C+', 153),
#   ('da1.', 152),
#   ('9&B1=Pasar+por+caja HTTP/1.1', 152),
#   ('&apellidos=Ca', 152),
#   ('as%2C+1', 152),
#   ('e&cp=', 152),
#   ('ria&', 151),
#   ('ra&ntc=3', 151),
#   ('e+Val', 151),
#   ('ad=6', 150),
#   ('m HTTP/1.1', 150),
#   ('&cp=44', 150),
#   ('&cp=05', 149),
#   ('1%40', 149),
#   ('a+De+', 148),
#   ('jara', 148),
#   ('rra&', 148),
#   ('.INC HTTP/1.1', 147),
#   ('a%F1', 147),
#   ('rd=e', 147),
#   ('2&B1=Pasar+por+caja HTTP/1.1', 146),
#   ('ia=V', 146),
#   ('=cha', 146),
#   ('G&ciudad=', 145),
#   ('4&B1=Pasar+por+caja HTTP/1.1', 145),
#   ('0&provincia=S', 145),
#   ('6&B1=Confirmar HTTP/1.1', 144),
#   ('i&email=', 144),
#   ('/4861362529278789730 HTTP/1.1', 143),
#   ('o&cp=1', 143),
#   ('%2F&', 142),
#   ('0&provincia=G', 142),
#   ('a1/asf-logo-wide.', 141),
#   ('2%2C+', 141),
#   ('ET http://localhost:8080.', 140),
#   ('5&B1=Confirmar HTTP/1.1', 140),
#   ('+S%2FN%2C+', 139),
#   ('5&B1=Pasar+por+caja HTTP/1.1', 138),
#   ('re=E', 138),
#   ('in=n', 138),
#   ('o&apellidos=M', 136),
#   ('re=C', 135),
#   ('2C+S%2FN', 135),
#   ('a&pwd=', 134),
#   ('/6909030637832563290.jsp HTTP/1.1', 134),
#   ('=San+', 134),
#   ('ad=T', 133),
#   ('=Pal', 133),
#   ('P&direccion=', 133),
#   ('3%2C+', 133),
#   ('lla&', 133),
#   ('l&email=', 132),
#   ('on=A', 132),
#   ('y&password=', 131),
#   ('s&apellidos=', 131),
#   ('acio', 131),
#   ('ia&ntc=9', 131),
#   ('s&password=', 130),
#   ('in=ch', 130),
#   ('il=p', 128),
#   ('tell', 128),
#   ('=mar', 128),
#   ('o&cp=3', 127),
#   ('t%40', 127),
#   ('ia&nombre=', 127),
#   ('+La+', 127),
#   ('rt%2', 127),
#   ('n%40e', 126),
#   ('adri', 126),
#   ('ila&', 125),
#   ('os=G', 125),
#   ('a&email=s', 124),
#   ('1%3F', 124),
#   ('D&direccion=', 124),
#   ('M&direccion=', 124),
#   ('8&B1=Pasar+por+caja HTTP/1.1', 123),
#   ('&pwd=p', 123),
#   ('da&nombre=', 123),
#   ('%2C+11', 123),
#   ('nca&ntc=5', 123),
#   ('%2C+12', 123),
#   ('F&direccion=', 123),
#   ('S&direccion=', 123),
#   ('s+del', 123),
#   ('+S%2FN+', 122),
#   ('te&nombre=', 122),
#   ('ona&ntc=0', 122),
#   ('%40l', 122),
#   ('&pwd=c', 121),
#   ('s&ntc=7', 121),
#   ('Juan+', 121),
#   ('e+San+', 121),
#   ('ora&', 121),
#   ('3n&nombre=', 121),
#   ('es%2C+1', 121),
#   ('res+', 121),
#   ('50&provincia=', 120),
#   ('el&apellidos=', 120),
#   ('llo&', 120),
#   ('ana&apellidos=', 120),
#   ('mente&', 120),
#   ('=car', 120),
#   ('n&email=', 119),
#   ('ella', 119),
#   ('1&B1=Pasar+por+caja HTTP/1.1', 119),
#   ('6%2C+', 119),
#   ('2C+3', 119),
#   ('%E9n&', 119),
#   ('s%2C+13', 119),
#   ('&cp=24', 119),
#   ('nder', 119),
#   ('iana&', 119),
#   ('e+Sant', 119),
#   ('3&B1=Confirmar HTTP/1.1', 118),
#   ('a&email=m', 118),
#   ('60&provincia=', 118),
#   ('on=Sa', 118),
#   ('0&B1=Pasar+por+caja HTTP/1.1', 117),
#   ('os=R', 117),
#   ('jsp/6909030637832563290.jsp', 116),
#   ('6&B1=Pasar+por+caja HTTP/1.1', 116),
#   ('0%2C+', 116),
#   ('2C+2', 116),
#   ('+Mar', 115),
#   ('re=D', 115),
#   ('il=r', 115),
#   ('2561%256', 114),
#   ('&password=a', 114),
#   ('i&password=', 114),
#   ('eres', 113),
#   ('1%2C+', 113),
#   ('ator', 112),
#   ('an&p', 111),
#   ('4&B1=Confirmar HTTP/1.1', 110),
#   ('%3D%27', 109),
#   ('er&password=', 109),
#   ('ET asf-logo-wide.', 108),
#   ('2&B1=Confirmar HTTP/1.1', 108),
#   ('ante', 108),
#   ('o&apellidos=C', 107),
#   ('ano&', 107),
#   ('252E%2563%256', 105),
#   ('re=G', 105),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Jam%F3n+Ib%E9rico&precio=100&cantidad=',
#    104),
#   ('as&email=', 104),
#   ('0&provincia=L', 104),
#   ('5%2C+', 104),
#   ('ia=Val', 104),
#   ('os%2C+', 103),
#   ('D%256', 102),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Queso+Manchego&precio=39&cantidad=',
#    102),
#   ('%E1n', 102),
#   ('%3FA&ciudad=', 102),
#   ('r%ED', 102),
#   ('8%2C+', 102),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Vino+Rioja&precio=85&cantidad=',
#    101),
#   ('a%F1a', 101),
#   ('%EDn', 101),
#   ('=Sal', 100),
#   ('aler', 100),
#   ('no&apellidos=', 100),
#   ('rd=d', 100),
#   ('re=F', 99),
#   ('ande', 99),
#   ('=Car', 99),
#   ('/4861362529278789730.', 98),
#   ('l%40', 98),
#   ('re=I', 98),
#   ('s&email=m', 98),
#   ('A&direccion=', 98),
#   ('ia=M', 98),
#   ('ie&password=', 98),
#   ('ert%2', 98),
#   ('a+del+', 97),
#   ('na&nombre=', 97),
#   ('9%2C+', 97),
#   ('r&email=', 97),
#   ('do&n', 97),
#   ('3F%2', 96),
#   ('in=f', 96),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Jam%F3n+Ib%E9rico&precio=100&cantidad=',
#    96),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Vino+Rioja&precio=100&cantidad=',
#    96),
#   ('alde', 96),
#   ('os=V', 96),
#   ('a+de+l', 96),
#   ('arro', 96),
#   ('T&direccion=', 96),
#   ('ar%2', 95),
#   ('ET _', 95),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Vino+Rioja&precio=100&cantidad=',
#    95),
#   ('admin', 95),
#   ('GET tienda1/publico/anadir.jsp?id=1&nombre=Vino+Rioja&precio=39&cantidad=',
#    95),
#   ('&email=c', 94),
#   ('e%F1a', 94),
#   ('r&dni=9', 94),
#   ('%3FD&ciudad=', 94),
#   ('&pwd=e', 94),
#   ('e+La+', 94),
#   ('8%256', 93),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Vino+Rioja&precio=85&cantidad=',
#    93),
#   ('7&B1=Confirmar HTTP/1.1', 93),
#   ('s+del+', 93),
#   ('%40h', 93),
#   ('eral', 93),
#   ('os=E', 93),
#   ('amor', 93),
#   ('1&B1=Confirmar HTTP/1.1', 92),
#   ('%3C%2F', 92),
#   ('s&cp=2', 92),
#   ('er%2', 92),
#   ('ena&', 92),
#   ('a%40m', 92),
#   ('orte', 92),
#   ('=Ter', 92),
#   ('&email=ma', 92),
#   ('port', 92),
#   ('anue', 92),
#   ('9&provincia=B', 92),
#   ('cookie', 91),
#   ('amples/', 91),
#   ('a&email=b', 91),
#   ('8&B1=Confirmar HTTP/1.1', 91),
#   ('ares+', 91),
#   ('res&', 91),
#   ('ina&apellidos=', 91),
#   ('n%2C+1', 91),
#   ('rd=7', 91),
#   ('ra&ntc=5', 91),
#   ('n+De+', 91),
#   ('mont', 91),
#   ('=Pla', 91),
#   ('%F3n&nombre=', 91),
#   ('V&direccion=C%2F', 91),
#   ('%2C+19', 91),
#   ('+Pin', 91),
#   ('+De+La', 91),
#   ('=248', 91),
#   ('=Zam', 91),
#   ('%27%2', 90),
#   ('samp', 90),
#   ('alla', 90),
#   ('H&direccion=', 90),
#   ('ntes', 90),
#   ('r+de+', 90),
#   ('2C+L', 90),
#   ('+10%', 90),
#   ('h%40', 90),
#   ('10&provincia=', 90),
#   ('isco', 90),
#   ('m%F3n&', 90),
#   ('=Santa', 90),
#   ('in=ca', 90),
#   ('+Cam', 90),
#   ('&cp=43', 90),
#   ('n&apellidos=M', 90),
#   ('illan', 90),
#   ('=443', 90),
#   ('eruel', 90),
#   ('nt&p', 90),
#   ('nare', 90),
#   ('ana%', 90),
#   ('tor+', 90),
#   ('E&direccion=', 90),
#   ('ragon', 90),
#   ('arrag', 90),
#   ('lare', 90),
#   ('intor', 90),
#   ('da&ntc=9', 90),
#   ('uera', 90),
#   ('onta', 90),
#   ('nte&nombre=', 90),
#   ('on%2', 90),
#   ('k%40', 90),
#   ('&pwd=d', 90),
#   ('ca&ntc=3', 90),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Jam%F3n+Ib%E9rico&precio=85&cantidad=',
#    89),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Jam%F3n+Ib%E9rico&precio=39&cantidad=',
#    89),
#   ('ra&ntc=4', 89),
#   ('%40la', 89),
#   ('0&nombre=', 89),
#   ('ende', 89),
#   ('s%2C+16', 89),
#   ('ad=Cast', 89),
#   ('Vall', 89),
#   ('Q&direccion=C%2F+', 89),
#   ('N&direccion=', 89),
#   ('K&direccion=C', 89),
#   ('R&direccion=', 89),
#   ('on=San', 89),
#   ('Quint', 89),
#   ('ona&ntc=2', 89),
#   ('Castel', 89),
#   ('dela', 88),
#   ('7%2C+&ciudad=', 88),
#   ('ero&', 88),
#   ('e&email=', 88),
#   ('4&provincia=C', 88),
#   ('Alba', 88),
#   ('o&dni=4', 88),
#   ('nda&apellidos=', 88),
#   ('villa', 88),
#   ('ernand', 88),
#   ('es&cp=4', 88),
#   ('il=ch', 87),
#   ('en%40', 87),
#   ('=Alb', 87),
#   ('t&email=', 86),
#   ('GET tienda1/publico/anadir.jsp?id=1&nombre=Vino+Rioja&precio=85&cantidad=',
#    85),
#   ('0&B1=Confirmar HTTP/1.1', 85),
#   ('re=L', 85),
#   ('il=g', 85),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Queso+Manchego&precio=100&cantidad=',
#    84),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Queso+Manchego&precio=85&cantidad=',
#    83),
#   ('9&B1=Confirmar HTTP/1.1', 83),
#   ('GET tienda1/publico/anadir.jsp?id=1&nombre=Queso+Manchego&precio=100&cantidad=',
#    83),
#   ('3&B1=Pasar+por+caja HTTP/1.1', 83),
#   ('os=L', 83),
#   ('0%2C+&ciudad=', 82),
#   ('t&password=', 81),
#   ('o&password=', 81),
#   ('%40t', 81),
#   ('re=B', 81),
#   ('jsp/asf-logo-wide HTTP/1.1', 80),
#   ('GET tienda1/publico/anadir.jsp?id=1&nombre=Queso+Manchego&precio=85&cantidad=',
#    80),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Vino+Rioja&precio=39&cantidad=',
#    80),
#   ('jsp.O', 80),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Queso+Manchego&precio=39&cantidad=',
#    80),
#   ('o&apellidos=B', 80),
#   ('GET tienda1/publico/anadir.jsp?id=1&nombre=Vino+Rioja&precio=100&cantidad=',
#    80),
#   ('il=l', 80),
#   ('%2F%2', 79),
#   ('%2F&cantidad=', 79),
#   ('ca&nombre=', 79),
#   ('&pwd=a', 79),
#   ('s&email=s', 79),
#   ('GET tienda1/publico/anadir.jsp?id=2&nombre=Jam%F3n+Ib%E9rico&precio=85&cantidad=',
#    79),
#   ('il=a', 79),
#   ('breA=', 78),
#   ('&apellidos=P', 78),
#   ('il=k', 78),
#   ('o&email=m', 77),
#   ('e&apellidos=', 77),
#   ('ar&nombre=', 76),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Vino+Rioja&precio=39&cantidad=',
#    76),
#   ('in=e', 76),
#   ('2%2C+&ciudad=', 76),
#   ('%EDa&', 76),
#   ('il=h', 76),
#   ('odoA=insertar&precio=', 75),
#   ('.htm', 75),
#   ('+S%2FN%2C+&ciudad=', 75),
#   ('GET tienda1/publico/anadir.jsp?id=3&nombre=Queso+Manchego&precio=100&cantidad=',
#    75),
#   ('7+&ciudad=', 75),
#   ('jsp/4861362529278789730 HTTP/1.1', 74),
#   ...]}

# %%
with open('./res/url_stopword.pkl', 'rb') as f:
    stopword_list = pickle.load(f)
    
stopword_list
# Out:
# [('istr', 2610),
#  ('GET ', 2261),
#  ('tien', 1772),
#  ('enda', 1764),
#  ('GET t', 1761),
#  ('tienda', 1756),
#  ('GET tienda1', 1741),
#  ('GET tienda1/', 1731),
#  (' HTTP/1.1', 1703),
#  ('.jsp', 1690),
#  ('logi', 1555),
#  ('stro', 1537),
#  ('login', 1532),
#  ('&login=', 1476),
#  ('tro&', 1459),
#  ('=registro&login=', 1407),
#  ('&ntc=', 1403),
#  ('ncia', 1292),
#  ('cion', 1266),
#  ('ccion', 1226),
#  ('elli', 1218),
#  ('apell', 1213),
#  ('&direccion=', 1211),
#  ('apelli', 1206),
#  ('&apellidos', 1199),
#  ('&apellidos=', 1192),
#  ('&dni=', 1192),
#  ('provi', 1185),
#  ('&cp=', 1184),
#  ('&provincia=', 1178),
#  ('iudad', 1167),
#  ('%2C+', 1156),
#  ('&ciudad=', 1155),
#  ('nombre', 1146),
#  ('stra', 1130),
#  ('&nombre=', 1126),
#  ('&email=', 1109),
#  ('istra', 1097),
#  ('r HTTP/1.1', 1085),
#  ('strar', 1059),
#  ('&B1=', 1054),
#  ('=Registrar HTTP/1.1', 1053),
#  ('passw', 1036),
#  ('&B1=Registrar HTTP/1.1', 1031),
#  ('word', 1030),
#  ('swor', 1030),
#  ('&password=', 1023),
#  ('r.jsp?', 917),
#  ('a&ntc=', 896),
#  ('ar.j', 888),
#  ('ar.jsp?', 882),
#  ('blic', 847),
#  ('GET tienda1/publico/', 833),
#  ('tar.', 819),
#  ('itar', 819),
#  ('edit', 819),
#  ('GET tienda1/miembros/', 814),
#  ('ditar.', 811),
#  ('GET tienda1/miembros/editar.jsp?modo', 804),
#  ('GET tienda1/miembros/editar.jsp?modo=', 781),
#  ('GET tienda1/miembros/editar.jsp?modo=registro', 767),
#  ('GET tienda1/miembros/editar.jsp?modo=registro&login', 759),
#  ('GET tienda1/miembros/editar.jsp?modo=registro&login=', 742),
#  ('tro.', 710),
#  ('GET tienda1/publico/registro.jsp?modo', 703),
#  ('GET tienda1/publico/registro.jsp?modo=', 686),
#  ('GET tienda1/publico/registro.jsp?modo=registro', 673),
#  ('GET tienda1/publico/registro.jsp?modo=registro&login', 657),
#  ('&direccion=C', 645),
#  ('GET tienda1/publico/registro.jsp?modo=registro&login=', 629),
#  ('+&ciudad=', 504),
#  ('a&cp=', 433),
#  ('%2C+1', 414),
#  ('+de+', 369),
#  ('&direccion=C%2F+', 363),
#  ('0&provincia=', 359),
#  ('a&apellidos=', 349),
#  ('&cp=0', 309),
#  ('o&apellidos=', 282),
#  ('&cp=1', 267),
#  ('alle', 249),
#  ('%2C+&ciudad=', 245),
#  ('a&email=', 244),
#  ('%252', 235),
#  ('&ntc=1', 221),
#  ('a&nombre=', 210),
#  ('&cp=4', 210),
#  ('+De+', 209),
#  ('illa', 208),
#  ('tc=5', 204),
#  ('o&nombre=', 203),
#  ('&cp=3', 195),
#  ('&ntc=5', 194),
#  ('=Calle+', 191),
#  ('%40c', 187),
#  ('&direccion=Calle+', 184),
#  ('%F3n', 184),
#  ('&dni=1', 182),
#  ('a%2C+', 180),
#  ('&apellidos=M', 178),
#  ('n%40', 177),
#  ('o&cp=', 177),
#  ('ia=B', 175),
#  ('%253', 174),
#  ('&apellidos=C', 172),
#  ('il=s', 166),
#  ('%F3n&', 165),
#  ('ni=3', 159),
#  ('%F1a', 155),
#  ('ni=9', 154),
#  ('&cp=2', 153),
#  ('s&email=', 150),
#  ('ra&ntc=', 150),
#  ('a&ntc=1', 150),
#  ('s&ntc=', 149),
#  ('&email=s', 144),
#  ('ria&', 143),
#  ('e%40', 142),
#  ('&dni=3', 141),
#  ('ad=S', 138),
#  ('ni=5', 136),
#  ('9&B1=Registrar HTTP/1.1', 136),
#  ('s%2C+', 136),
#  ('tc=4', 135),
#  ('&direccion=P', 133),
#  ('o&email=', 132),
#  ('urgo', 132),
#  ('a&password=', 131),
#  ('=Val', 130),
#  ('r&nombre=', 129),
#  ('a+de+', 128),
#  ('&dni=5', 128),
#  ('&nombre=A', 127),
#  ('%40e', 127),
#  ('&ntc=7', 127),
#  ('tc=8', 127),
#  ('arra', 126),
#  ('F&ciudad=', 125),
#  ('a&ntc=5', 125),
#  ('urgos', 125),
#  ('a%40', 123),
#  ('ona&', 123),
#  ('4&B1=Registrar HTTP/1.1', 121),
#  ('&ntc=4', 121),
#  ('samp', 120),
#  ('alen', 120),
#  ('n&apellidos=', 119),
#  ('Burgos', 119),
#  ('sp HTTP/1.1', 117),
#  ('+San', 117),
#  ('.com', 117),
#  ('n&password=', 115),
#  ('ni=7', 115),
#  ('enci', 115),
#  ('s&apellidos=', 114),
#  ('&ntc=8', 114),
#  ('%40a', 113),
#  ('a&cp=0', 113),
#  ('1&provincia=', 113),
#  ('3&provincia=', 113),
#  ('&dni=9', 113),
#  ('os=A', 112),
#  ('Burgos&', 112),
#  ('=Burg', 112),
#  ('o%2C+', 110),
#  ('+del', 110),
#  ('Cast', 110),
#  ('e&password=', 109),
#  ('ona&ntc=', 109),
#  ('&ntc=2', 109),
#  ('+de+l', 109),
#  ('74%2', 109),
#  ('encia', 107),
#  ('aman', 106),
#  ('.com.', 105),
#  ('2&provincia=', 105),
#  ('ni=0', 105),
#  ('ente', 104),
#  ('a&cp=1', 103),
#  ('6&B1=Registrar HTTP/1.1', 102),
#  ('ia=V', 102),
#  ('r%40', 102),
#  ('1&B1=Registrar HTTP/1.1', 101),
#  ('tc=6', 99),
#  ('in=m', 99),
#  ('&dni=7', 98),
#  ('anta', 98),
#  ('%40m', 98),
#  ('%40t', 98),
#  ('nca&', 98),
#  ('3&B1=Registrar HTTP/1.1', 97),
#  ('illo', 97),
#  ('9&provincia=', 97),
#  ('anca', 97),
#  ('in=s', 96),
#  ('s+de+', 96),
#  ('ia&apellidos=', 96),
#  ('a%2C+1', 95),
#  ('y%40', 95),
#  ('ni=8', 95),
#  ('%F3n&n', 95),
#  ('s&dni=', 93),
#  ('re=N', 93),
#  ('l%40', 93),
#  ('lla&', 93),
#  ('8&B1=Registrar HTTP/1.1', 91),
#  ('e&nombre=', 91),
#  ('il=b', 91),
#  ('nca&ntc=', 91),
#  ('lama', 91),
#  ('&cp=09', 91),
#  ('2&B1=Registrar HTTP/1.1', 89),
#  ('ia=T', 89),
#  ('erra', 88),
#  ('+S%2FN', 88),
#  ('+del+', 88),
#  ('m HTTP/1.1', 87),
#  ('=Sal', 87),
#  ('+De+L', 86),
#  ('tc=0', 85),
#  ('.htm', 85),
#  ('ad=P', 85),
#  ('alencia', 85),
#  ('2569', 85),
#  ('ad=V', 84),
#  ('5&B1=Registrar HTTP/1.1', 84),
#  ('%3D%2', 84),
#  ('laman', 84),
#  ('ria&ntc=', 84),
#  ('es/s', 83),
#  ('&dni=6', 83),
#  ('a&ntc=2', 83),
#  ('example', 82),
#  ('in=c', 82),
#  ('8&provincia=', 82),
#  ('cia&', 82),
#  ('=Cas', 82),
#  ('rago', 81),
#  ('a&cp=4', 81),
#  ('D&ciudad=', 81),
#  ('na&apellidos=', 80),
#  ('0&B1=Registrar HTTP/1.1', 79),
#  ('in=b', 79),
#  ('=Car', 79),
#  ('s%40', 78),
#  ('samples/', 78),
#  ('oria', 78),
#  ('os=B', 77),
#  ('G&ciudad=', 77),
#  ('ia=G', 77),
#  ('&apellidos=Ma', 77),
#  ('2F%2', 77),
#  ('anca&ntc=', 77),
#  ('alamanca', 77),
#  ('%3C%2', 76),
#  ('amples/s', 75),
#  ('os=S', 75),
#  ('ni=2', 75),
#  ('cript', 74),
#  ('H&ciudad=', 74),
#  ('il=m', 74),
#  ('a&ntc=7', 74),
#  ('a&ntc=4', 74),
#  ('io&apellidos=', 73),
#  ('il=c', 73),
#  ('via&', 73),
#  ('%40p', 73),
#  ('er%40', 72),
#  ('+de+la+', 72),
#  ('l HTTP/1.1', 71),
#  ('r&password=', 71),
#  ('rd=a', 71),
#  ('ia=Val', 71),
#  ('ni=4', 71),
#  ('=Sala', 71),
#  ('a&ntc=8', 70),
#  ('7&B1=Registrar HTTP/1.1', 70),
#  ('.asp HTTP/1.1', 70),
#  ('=Sor', 70),
#  ('ero&', 69),
#  ('o&dni=', 69),
#  ('ia=L', 69),
#  ('ntra', 69),
#  ('E%256', 68),
#  ('C&ciudad=', 68),
#  ('cia&ntc=', 68),
#  ('re=L', 68),
#  ('examples', 67),
#  ('E&ciudad=', 67),
#  ('ment', 66),
#  ('&ntc=6', 66),
#  ('+&ciudad=C', 66),
#  ('s%2C+1', 66),
#  ('rd=c', 65),
#  ('J&direccion=', 65),
#  ('%40l', 65),
#  ('in=d', 64),
#  ('o%40', 64),
#  ('i%40', 64),
#  ('u&dni=', 64),
#  ('tc=9', 64),
#  ('6&provincia=', 64),
#  ('B&direccion=', 64),
#  ('a%F1', 64),
#  ('u%F1', 64),
#  ('s&cp=0', 63),
#  ('ad=B', 63),
#  ('ad=M', 63),
#  ('on=A', 63),
#  ('=Bar', 63),
#  ('Mont', 63),
#  ('via&ntc=', 63),
#  ('illa&', 63),
#  ('nta+', 63),
#  ('id&ntc=', 63),
#  ('%40s', 62),
#  ('%F1o', 62),
#  ('a&cp=2', 61),
#  ('ar&nombre=', 61),
#  ('re=R', 61),
#  ('Y&direccion=', 61),
#  ('%EDn', 61),
#  ('=Cast', 61),
#  ('orre', 60),
#  ('m&dni=', 60),
#  ('3%3F', 60),
#  ('os=P', 59),
#  ('ia=A', 59),
#  ('=Vil', 59),
#  ('es&cp=', 59),
#  ('ia=Za', 58),
#  ('l&apellidos=', 58),
#  ('8%2C+', 58),
#  ('&direccion=Pa', 58),
#  ('%EDa', 57),
#  ('4&provincia=', 57),
#  ('+San+', 56),
#  ('B&ciudad=', 56),
#  ('a&apellidos=C', 56),
#  ('z&email=', 56),
#  ('Villa', 56),
#  ('&ciudad=Al', 56),
#  ('l&ntc=', 56),
#  ('Samples/', 55),
#  ('g&dni=', 55),
#  ('&direccion=Pl', 55),
#  ('L&direccion=', 55),
#  ('7&provincia=', 54),
#  ('a&cp=3', 54),
#  ('+Mon', 53),
#  ('rd=p', 53),
#  ('+Cor', 53),
#  ('te&n', 53),
#  ('5&provincia=', 52),
#  ('os=G', 52),
#  ('onte', 52),
#  ('%3FF&ciudad=', 52),
#  ('entr', 52),
#  ('=Valen', 52),
#  ('ET s', 51),
#  ('tc=3', 51),
#  ('l&email=', 51),
#  ('os%2C+', 51),
#  ('d%3D', 51),
#  ('E&direccion=', 51),
#  ('s&cp=1', 51),
#  ('/examples', 51),
#  ('scri', 51),
#  ('adri', 51),
#  ('http', 50),
#  ('o%2C+1', 50),
#  ('re=T', 50),
#  ('n&email=', 50),
#  ('aste', 50),
#  ('GET tienda1/miembros/editar.jsp?modo=registro&login=m', 50),
#  ('r&email=', 50),
#  ('00&provincia=', 50),
#  ('eruel', 50),
#  ('iron', 50),
#  ('%40i', 50),
#  ('cookie', 49),
#  ('o&password=', 49),
#  ('B%256', 49),
#  ('no&apellidos=', 49),
#  ('era&', 49),
#  ('%40v', 49),
#  ('+&ciudad=Ca', 49),
#  ('&direccion=C%2F+C', 49),
#  ('u%F1a', 49),
#  ('os=T', 48),
#  ('i&email=', 48),
#  ('ia=M', 48),
#  ('los+', 48),
#  ('enti', 48),
#  ('e&dni=', 47),
#  ('%253A', 47),
#  ('alla', 47),
#  ('re=M', 47),
#  ('R&direccion=', 47),
#  ('n&dni=', 47),
#  ('9090', 47),
#  ('c&dni=', 47),
#  ('=Mad', 47),
#  ('%F3n&ntc=', 47),
#  ('loca', 46),
#  ('2C+3', 46),
#  ('il=h', 46),
#  ('n%2C+', 46),
#  ('2C+5', 46),
#  ('%27%2', 45),
#  ('a+De+', 45),
#  ('ster', 45),
#  ('ml HTTP/1.1', 45),
#  ('7%2C+', 45),
#  ('+&ciudad=A', 45),
#  ('+Mont', 45),
#  ('Nava', 45),
#  ('=San+', 45),
#  ('da&apellidos=', 45),
#  ('+Del', 45),
#  ('tica', 44),
#  ('script', 44),
#  ('a&email=s', 44),
#  ('=Ter', 44),
#  ('acio', 44),
#  ('y&dni=', 44),
#  ('adrid', 44),
#  ('ada&', 44),
#  ('ora&ntc=', 44),
#  ('s&apellidos=C', 44),
#  ('erta', 43),
#  ('o&apellidos=M', 43),
#  ('r&dni=', 43),
#  ('a&ntc=6', 43),
#  ('%3FH&ciudad=', 43),
#  ('+%27', 43),
#  ('=Tor', 43),
#  ('tell', 43),
#  ('+S%2FN%2C+', 43),
#  ('l%F3', 43),
#  ('Giron', 43),
#  ('es%2', 43),
#  ('%250', 42),
#  ('erna', 42),
#  ('i&password=', 42),
#  ('illo&', 42),
#  ('o&cp=0', 42),
#  ('=Mar', 42),
#  ('on=M', 42),
#  ('0&provincia=B', 42),
#  ('on%40', 42),
#  ('T&direccion=C', 42),
#  ('%40g', 42),
#  ('+Cas', 42),
#  ('e+Ca', 42),
#  ('%2C+13', 42),
#  ('2C+9', 41),
#  ('V&direccion=', 41),
#  ('a%F1a', 41),
#  ('arce', 41),
#  ('2%2C+', 41),
#  ('on=Av', 41),
#  ('X&direccion=', 41),
#  ('uela', 41),
#  ('a&apellidos=M', 41),
#  ('=Santa+', 41),
#  ('3A%2', 40),
#  ('in=h', 40),
#  ('in=t', 40),
#  ('era+', 40),
#  ('Z&direccion=', 40),
#  ('o&cp=1', 40),
#  ('ra&ntc=5', 40),
#  ('e+La', 40),
#  ('=Villa', 40),
#  ('ina&', 40),
#  ('il=g', 39),
#  ('+Mar', 39),
#  ('2C+6', 39),
#  ('rderParser', 39),
#  ('a+de+l', 39),
#  ('t&email=', 39),
#  ('6%2C+', 39),
#  ('rid&', 39),
#  ('=Madr', 39),
#  ('arri', 38),
#  ('re=C', 38),
#  ('ares', 38),
#  ('ino&', 38),
#  ('=Pal', 38),
#  ('re=G', 38),
#  ('a+del+', 38),
#  ('o&cp=3', 38),
#  ('ia=Valencia', 38),
#  ('s&cp=2', 38),
#  ('re=B', 38),
#  ('as&email=', 38),
#  ('+Sant', 38),
#  ('nte&', 38),
#  ('n&nombre=', 38),
#  ('lian', 38),
#  ('ta&email=', 38),
#  ('ana&', 38),
#  ('in=l', 37),
#  ('+La+', 37),
#  ('il=d', 37),
#  ('+Del+', 37),
#  ('host', 37),
#  ('=Pas', 37),
#  ('ros%', 37),
#  ('l+Ca', 37),
#  ('%27%3', 36),
#  ('A&ciudad=', 36),
#  ('=Nava', 36),
#  ('admini', 36),
#  ('%29%', 36),
#  ('n+De', 36),
#  ('ria&apellidos=', 36),
#  ('t%40', 36),
#  ('anti', 36),
#  ('=Tra', 36),
#  ('ia=P', 36),
#  ('l&dni=', 36),
#  ('e&ntc=', 36),
#  ('=092', 36),
#  ('e%F1', 36),
#  ('1%3F', 36),
#  ('3F%2', 35),
#  ('samples/s', 35),
#  ('e&apellidos=', 35),
#  ('ia=Teruel&ntc=', 35),
#  ('/examples/', 35),
#  ('il=a', 35),
#  ('Q&direccion=', 35),
#  ('da&ntc=', 35),
#  ('%40co', 35),
#  ('%40ma', 35),
#  ('lles', 35),
#  ('&direccion=Cam', 35),
#  ('ru%F1a&', 35),
#  ('ell%', 35),
#  ('ierra', 35),
#  ('e%F3', 35),
#  ('in%40', 35),
#  ('icas', 35),
#  ('rand', 35),
#  ('Camp', 35),
#  ('%253C', 34),
#  ('rd=e', 34),
#  ('lado', 34),
#  ('%2C+12', 34),
#  ('3%2C+', 34),
#  ('in=k', 34),
#  ('rd=d', 34),
#  ('e+San', 34),
#  ('0&provincia=Sa', 34),
#  ('ad=R', 34),
#  ('ad=H', 34),
#  ('%E9&', 34),
#  ('Los+', 34),
#  ('&direccion=Car', 34),
#  ('arra&ntc=', 34),
#  ('ia&apellidos=C', 34),
#  ('o&cp=4', 33),
#  ('2C+7', 33),
#  ('1%2C+', 33),
#  ('/samp', 33),
#  ('os=R', 33),
#  ('ntes', 33),
#  ('+De+La', 33),
#  ('tion', 32),
#  ('r%ED', 32),
#  ('ia=%', 32),
#  ('%253D', 32),
#  ('ador', 32),
#  ('er&email=', 32),
#  ('ad=T', 32),
#  ('aler', 32),
#  ('H&direccion=', 32),
#  ('os%2C+1', 32),
#  ('=Madrid&ntc=', 32),
#  ('%3C%21--%23', 31),
#  ('%3C%2F', 31),
#  ('s&password=', 31),
#  ('il=r', 31),
#  ('ra&nombre=', 31),
#  ('ator', 31),
#  ('2C+4', 31),
#  ('in=j', 31),
#  ('ia=Hue', 31),
#  ('esca', 31),
#  ('il=l', 31),
#  ('w&dni=', 31),
#  ('A&direccion=', 31),
#  ('te&nombre=', 31),
#  ('z&dni=', 31),
#  ('os=V', 31),
#  ('F&direccion=', 31),
#  ('aciar', 30),
#  ('amor', 30),
#  ('trat', 30),
#  ('a1/i', 30),
#  ('re=S', 30),
#  ('1&provincia=S', 30),
#  ('andr', 30),
#  ('0&provincia=C', 30),
#  ('res+', 30),
#  ('er&password=', 30),
#  ('acion', 30),
#  ('es%2C+', 30),
#  ('M&direccion=', 30),
#  ('Torre', 30),
#  ('bert', 30),
#  ('re=I', 30),
#  ('G&direccion=', 30),
#  ('os=Ar', 30),
#  ('esia', 30),
#  ('5%2C+', 30),
#  ('rave', 30),
#  ('a+de+la', 30),
#  ('&cp=10', 30),
#  ('2%3F', 30),
#  ('%29%3', 29),
#  ('cookie%', 29),
#  ('o&nombre=A', 29),
#  ('/order', 29),
#  ('0%2C+', 29),
#  ('=Gra', 29),
#  ('s&cp=4', 29),
#  ('dela', 29),
#  ('villa', 29),
#  ('rd=s', 29),
#  ('B&direccion=C%2F+', 29),
#  ('anad', 29),
#  ('agon', 29),
#  ('4%2C+', 29),
#  ('=Hues', 29),
#  ('n&apellidos=M', 29),
#  ('h&dni=', 29),
#  ('es+de+', 29),
#  ('esto', 29),
#  ('3+&ciudad=', 29),
#  ('&dni=17', 29),
#  ('&nombre=Al', 29),
#  ('0&provincia=Se', 29),
#  ('&cp=092', 29),
#  ('t&dni=', 29),
#  ('%2F%', 28),
#  ('ia=Palencia', 28),
#  ('256E%2574%252E%256', 28),
#  ('an&password=', 28),
#  ('http://localhost:', 28),
#  ('GET tienda1/publico/registro.jsp?modo=registro&login=m', 28),
#  ('rio&', 28),
#  ('la&cp=1', 28),
#  ('%40f', 28),
#  ('r&nombre=A', 28),
#  ('ledo', 28),
#  ('os=Sa', 28),
#  ('n&cp=', 28),
#  ('a&cp=08', 28),
#  ('n%40a', 28),
#  ('llos', 28),
#  ('=Giron', 28),
#  ('aya&', 28),
#  ('+Car', 28),
#  ('adal', 28),
#  ('%2C+16', 28),
#  ('lla&cp=0', 28),
#  ('=Torr', 28),
#  ('&cp=18', 28),
#  ('+Sie', 28),
#  ('=Zar', 28),
#  ('73&provincia=', 28),
#  ('erra&cp=', 28),
#  ('s&apellidos=M', 28),
#  ('e+de+', 28),
#  ('D%256', 27),
#  ('ET CFIDE/administra', 27),
#  ('in=p', 27),
#  ('re=Ma', 27),
#  ('o+De+', 27),
#  ('+Los+', 27),
#  ('on=L', 27),
#  ('edo&', 27),
#  ('%3FG&ciudad=', 27),
#  ('nill', 27),
#  ('ara&', 27),
#  ('=174', 27),
#  ('Coru', 27),
#  ('d=Pa', 27),
#  ('3&provincia=Se', 27),
#  ('=Caste', 27),
#  ('rato', 27),
#  ('jsp.', 26),
#  ('.htm HTTP/1.1', 26),
#  ('lica', 26),
#  ('jsp HTTP/1.1', 26),
#  ('rist', 26),
#  ('A&nombre=', 26),
#  ('rar.jsp?', 26),
#  ('W&direccion=', 26),
#  ('d&password=', 26),
#  ('igue', 26),
#  ('K&direccion=', 26),
#  ('3C%252F', 26),
#  ('20&provincia=', 26),
#  ('8%2C+&ciudad=', 26),
#  ('rd=r', 26),
#  ('ina&apellidos=', 26),
#  ('es&email=', 25),
#  ('co/entrar', 25),
#  ('d%3D%22', 25),
#  ('%27%3B', 25),
#  ('re=D', 25),
#  ('il=p', 25),
#  ('e&email=', 25),
#  ('%253E', 25),
#  ('s+del+', 25),
#  ('ia=Madrid&ntc=', 25),
#  ('%EDn&', 25),
#  ('re=H', 25),
#  ('ad=Val', 25),
#  ('os=To', 25),
#  ('el&apellidos=', 25),
#  ('ad=Villa', 25),
#  ('ad=Be', 25),
#  ('6909030637832563290.jsp', 24),
#  ('15%2', 24),
#  ('script%', 24),
#  ('%3D%27', 24),
#  ('ana&apellidos=', 24),
#  ('2561%256', 24),
#  ('t&password=', 24),
#  ('guer', 24),
#  ('il=f', 24),
#  ('alert%2', 24),
#  ('arcel', 24),
#  ('/samples/', 24),
#  ('=Gua', 24),
#  ('2%2C+&ciudad=', 24),
#  ('%F3n&nombre=', 24),
#  ('7%2C+&ciudad=', 24),
#  ('80&provincia=', 24),
#  ('4+&ciudad=', 24),
#  ('ente&', 24),
#  ('&pwd=', 23),
#  ('a1/imagenes/', 23),
#  ('odoA=', 23),
#  ('os=F', 23),
#  ('in=a', 23),
#  ('in=r', 23),
#  ('i&apellidos=', 23),
#  ('2C+L', 23),
#  ('ia=Vall', 23),
#  ('asti', 23),
#  ('D&direccion=', 23),
#  ('3&provincia=C', 23),
#  ('GET tienda1/miembros/editar.jsp?modo=registro&login=ma', 23),
#  ('re=P', 23),
#  ('il=e', 23),
#  ('%E9n', 23),
#  ('re=No', 23),
#  ('r&dni=1', 23),
#  ('ilia', 23),
#  ('a+de+la+', 23),
#  ('Port', 23),
#  ('allad', 23),
#  ('iano', 23),
#  ('J&direccion=C%2F+', 23),
#  ('L&direccion=C%2F+', 23),
#  ('ro&nombre=', 23),
#  ('=Ave', 23),
#  ('co/vaciar.jsp?', 22),
#  ('.html HTTP/1.1', 22),
#  ('.cfm HTTP/1.1', 22),
#  ('2C+2', 22),
#  ('ad=G', 22),
#  ('cp=50', 22),
#  ('ia=Huesca&ntc=', 22),
#  ('il=k', 22),
#  ('e%40c', 22),
#  ('r&apellidos=', 22),
#  ('2C+S%2FN', 22),
#  ('a+De+L', 22),
#  ('in=v', 22),
#  ('ell&', 22),
#  ('lich', 22),
#  ('%2522', 22),
#  ('ener', 22),
#  ('C&direccion=', 22),
#  ('N&direccion=', 22),
#  ('iber', 22),
#  ('ragon', 22),
#  ('ra&cp=0', 22),
#  ('a+Ri', 22),
#  ('=Mon', 22),
#  ('in=f', 22),
#  ('%F3&', 22),
#  ('er%E', 22),
#  ('idad', 22),
#  ('n&dni=1', 22),
#  ('in=ba', 22),
#  ('ssan', 22),
#  ('0&provincia=Salamanca&ntc=', 22),
#  ('9%2C+', 22),
#  ('n%40c', 22),
#  ('os=D', 22),
#  ('ra&ntc=1', 22),
#  ('1&provincia=Burgos&ntc=', 22),
#  ('ano&', 22),
#  ('+11%3F', 22),
#  ('arrag', 22),
#  ('S&direccion=', 22),
#  ('java', 21),
#  ('as%2C+', 21),
#  ('do&n', 21),
#  ('eSamples/', 21),
#  ('ia=Girona&ntc=', 21),
#  ('Samples/s', 21),
#  ('rd=t', 21),
#  ('D%250', 21),
#  ('IPT%', 21),
#  ('ca&nombre=', 21),
#  ('/examples/s', 21),
#  ('ia=Zamora&ntc=', 21),
#  ('%40b', 21),
#  ('os=Al', 21),
#  ('Gran', 21),
#  ('s&dni=5', 21),
#  ('9%253', 21),
#  ('ller', 21),
#  ('=Torre', 21),
#  ('on=G', 21),
#  ('res&', 21),
#  ('0&provincia=Burgos&ntc=', 21),
#  ('la%2', 21),
#  ('ia=A+Coru%F1a&ntc=', 21),
#  ('os&cp=1', 21),
#  ('a+Cr', 21),
#  ('ardi', 21),
#  ('tell%', 21),
#  ('ria&apellidos=C', 21),
#  ('ez&email=', 21),
#  ('eral', 21),
#  ('s&ntc=8', 21),
#  ('a%40t', 21),
#  ('l%F3n&', 21),
#  ('ria&ntc=1', 21),
#  ('&cp=19', 21),
#  ('ario&', 21),
#  ('y%40t', 21),
#  ('l%2C+', 21),
#  ('=Marc', 21),
#  ('do%2C+', 21),
#  ('ette', 21),
#  ('uente', 21),
#  ('elle', 21),
#  ('vent', 21),
#  ('o&cp=09', 21),
#  ('%40z', 21),
#  ('s&apellidos=Ma', 21),
#  ('amon', 21),
#  ('n+De+', 21),
#  ('ando', 21),
#  ('=446', 21),
#  ('i%F3', 21),
#  ('%F3n&apellidos=', 21),
#  ('on=S', 21),
#  ('l&ntc=5', 21),
#  ('r%40c', 21),
#  ('leta', 21),
#  ('%40n', 21),
#  ('rd=9', 21),
#  ('+Rio', 21),
#  ('eta&email=', 21),
#  ('2&provincia=C', 21),
#  ('s&ntc=1', 21),
#  ('+De+A', 21),
#  ('ntin', 21),
#  ('ro%2C+', 21),
#  ('d=So', 21),
#  ('e%40e', 21),
#  ('%2C+&ciudad=Al', 21),
#  ('asta', 21),
#  ('a+S%2FN', 21),
#  ('+Cam', 21),
#  ('g&dni=5', 21),
#  ('e%2C+1', 21),
#  ('t%F3', 21),
#  ('ella', 21),
#  ('o&apellidos=C', 21),
#  ('ente+', 21),
#  ('0&provincia=Soria&ntc=', 21),
#  ('ia=Vizcaya&ntc=', 21),
#  ('&ciudad=Ar', 21),
#  ('quil', 21),
#  ('es&apellidos=', 21),
#  ('ona&ntc=1', 21),
#  ('28%2', 20),
#  ('%3B+', 20),
#  ('&dni=4', 20),
#  ('%2528', 20),
#  ('trator/', 20),
#  ('GET tienda1/publico/autenticar.jsp?modo=', 20),
#  ('rar&login=', 20),
#  ('8%256', 20),
#  ('0%3A', 20),
#  ('ia=Al', 20),
#  ('file', 20),
#  ('a&dni=', 20),
#  ('ad=Pa', 20),
#  ('&dni=15', 20),
#  ('+De+Los+', 20),
#  ('via&ntc=5', 20),
#  ('avar', 20),
#  ('o%40c', 20),
#  ('h%40', 20),
#  ('s+de+la+', 20),
#  ('s&ntc=7', 20),
#  ('es%2C+1', 20),
#  ('lina&', 20),
#  ('os+de+', 20),
#  ('+%27%25', 19),
#  ('%22+', 19),
#  ('in=e', 19),
#  ('y&password=', 19),
#  ('+De+La+', 19),
#  ('do=entrar', 19),
#  ('30&provincia=', 19),
#  ('e%F1a', 19),
#  ('a&cp=09', 19),
#  ('%27a', 19),
#  ('l&password=', 19),
#  ('a&nombre=A', 19),
#  ('+3%3F', 19),
#  ('rd=0', 19),
#  ('os=L', 19),
#  ('ginA=', 18),
#  ('P&direccion=', 18),
#  ('%2F%2', 18),
#  ('re=E', 18),
#  ('2C+8', 18),
#  ('+S%2FN+', 18),
#  ('O&nombre=', 18),
#  ('5&nombre=', 18),
#  ('/orderParser', 18),
#  ('E&direccion=C%2F+', 18),
#  ('arre', 18),
#  ('eres', 18),
#  ('re=Na', 18),
#  ('ld HTTP/1.1', 17),
#  ('nc HTTP/1.1', 17),
#  ('co/entrar.jsp?', 17),
#  ('id%3D', 17),
#  ('+%270%', 17),
#  ('il=t', 17),
#  ('/samples/s', 17),
#  ('on&password=', 17),
#  ('en&apellidos=', 17),
#  ('o&cp=2', 17),
#  ('in=w', 17),
#  ('tro%', 17),
#  ('a+Ca', 17),
#  ('ad=F', 17),
#  ('rd=re', 17),
#  ('%EDa&', 17),
#  ('0%2C+&ciudad=', 17),
#  ('+Monte', 17),
#  ('document.', 16),
#  ('ET iis', 16),
#  ('%3D%221', 16),
#  ('256D%2570%256', 16),
#  ('256C%2565%252F%2563%256', 16),
#  ('256C%252E%2563%256', 16),
#  ('2564%256F%2563%2575%256', 16),
#  ('256B%2569%2565%2573%2574%2565%256', 16),
#  ('serv', 16),
#  ('odoA=registro&login=', 16),
#  ('anza', 16),
#  ('%2C%2', 16),
#  ('on=R', 16),
#  ('t.asp HTTP/1.1', 16),
#  ('k&password=', 16),
#  ('erve', 16),
#  ('a&cp=10', 16),
#  ('on=Avenida+', 16),
#  ('os&cp=3', 16),
#  ('i%F1o', 16),
#  ('B%253C', 16),
#  ('10&provincia=', 16),
#  ('os=Ro', 16),
#  ('-F&ciudad=', 16),
#  ('es&cp=2', 16),
#  ('0&nombre=', 16),
#  ('ad=Mo', 16),
#  ('mente', 16),
#  ('il=ma', 16),
#  ('ia=Vallado', 16),
#  ('ente&nombre=', 16),
#  ...]

# %%
stopwords = [i[0] for i in stopword_list]
stopwords
# Out:
# ['istr',
#  'GET ',
#  'tien',
#  'enda',
#  'GET t',
#  'tienda',
#  'GET tienda1',
#  'GET tienda1/',
#  ' HTTP/1.1',
#  '.jsp',
#  'logi',
#  'stro',
#  'login',
#  '&login=',
#  'tro&',
#  '=registro&login=',
#  '&ntc=',
#  'ncia',
#  'cion',
#  'ccion',
#  'elli',
#  'apell',
#  '&direccion=',
#  'apelli',
#  '&apellidos',
#  '&apellidos=',
#  '&dni=',
#  'provi',
#  '&cp=',
#  '&provincia=',
#  'iudad',
#  '%2C+',
#  '&ciudad=',
#  'nombre',
#  'stra',
#  '&nombre=',
#  '&email=',
#  'istra',
#  'r HTTP/1.1',
#  'strar',
#  '&B1=',
#  '=Registrar HTTP/1.1',
#  'passw',
#  '&B1=Registrar HTTP/1.1',
#  'word',
#  'swor',
#  '&password=',
#  'r.jsp?',
#  'a&ntc=',
#  'ar.j',
#  'ar.jsp?',
#  'blic',
#  'GET tienda1/publico/',
#  'tar.',
#  'itar',
#  'edit',
#  'GET tienda1/miembros/',
#  'ditar.',
#  'GET tienda1/miembros/editar.jsp?modo',
#  'GET tienda1/miembros/editar.jsp?modo=',
#  'GET tienda1/miembros/editar.jsp?modo=registro',
#  'GET tienda1/miembros/editar.jsp?modo=registro&login',
#  'GET tienda1/miembros/editar.jsp?modo=registro&login=',
#  'tro.',
#  'GET tienda1/publico/registro.jsp?modo',
#  'GET tienda1/publico/registro.jsp?modo=',
#  'GET tienda1/publico/registro.jsp?modo=registro',
#  'GET tienda1/publico/registro.jsp?modo=registro&login',
#  '&direccion=C',
#  'GET tienda1/publico/registro.jsp?modo=registro&login=',
#  '+&ciudad=',
#  'a&cp=',
#  '%2C+1',
#  '+de+',
#  '&direccion=C%2F+',
#  '0&provincia=',
#  'a&apellidos=',
#  '&cp=0',
#  'o&apellidos=',
#  '&cp=1',
#  'alle',
#  '%2C+&ciudad=',
#  'a&email=',
#  '%252',
#  '&ntc=1',
#  'a&nombre=',
#  '&cp=4',
#  '+De+',
#  'illa',
#  'tc=5',
#  'o&nombre=',
#  '&cp=3',
#  '&ntc=5',
#  '=Calle+',
#  '%40c',
#  '&direccion=Calle+',
#  '%F3n',
#  '&dni=1',
#  'a%2C+',
#  '&apellidos=M',
#  'n%40',
#  'o&cp=',
#  'ia=B',
#  '%253',
#  '&apellidos=C',
#  'il=s',
#  '%F3n&',
#  'ni=3',
#  '%F1a',
#  'ni=9',
#  '&cp=2',
#  's&email=',
#  'ra&ntc=',
#  'a&ntc=1',
#  's&ntc=',
#  '&email=s',
#  'ria&',
#  'e%40',
#  '&dni=3',
#  'ad=S',
#  'ni=5',
#  '9&B1=Registrar HTTP/1.1',
#  's%2C+',
#  'tc=4',
#  '&direccion=P',
#  'o&email=',
#  'urgo',
#  'a&password=',
#  '=Val',
#  'r&nombre=',
#  'a+de+',
#  '&dni=5',
#  '&nombre=A',
#  '%40e',
#  '&ntc=7',
#  'tc=8',
#  'arra',
#  'F&ciudad=',
#  'a&ntc=5',
#  'urgos',
#  'a%40',
#  'ona&',
#  '4&B1=Registrar HTTP/1.1',
#  '&ntc=4',
#  'samp',
#  'alen',
#  'n&apellidos=',
#  'Burgos',
#  'sp HTTP/1.1',
#  '+San',
#  '.com',
#  'n&password=',
#  'ni=7',
#  'enci',
#  's&apellidos=',
#  '&ntc=8',
#  '%40a',
#  'a&cp=0',
#  '1&provincia=',
#  '3&provincia=',
#  '&dni=9',
#  'os=A',
#  'Burgos&',
#  '=Burg',
#  'o%2C+',
#  '+del',
#  'Cast',
#  'e&password=',
#  'ona&ntc=',
#  '&ntc=2',
#  '+de+l',
#  '74%2',
#  'encia',
#  'aman',
#  '.com.',
#  '2&provincia=',
#  'ni=0',
#  'ente',
#  'a&cp=1',
#  '6&B1=Registrar HTTP/1.1',
#  'ia=V',
#  'r%40',
#  '1&B1=Registrar HTTP/1.1',
#  'tc=6',
#  'in=m',
#  '&dni=7',
#  'anta',
#  '%40m',
#  '%40t',
#  'nca&',
#  '3&B1=Registrar HTTP/1.1',
#  'illo',
#  '9&provincia=',
#  'anca',
#  'in=s',
#  's+de+',
#  'ia&apellidos=',
#  'a%2C+1',
#  'y%40',
#  'ni=8',
#  '%F3n&n',
#  's&dni=',
#  're=N',
#  'l%40',
#  'lla&',
#  '8&B1=Registrar HTTP/1.1',
#  'e&nombre=',
#  'il=b',
#  'nca&ntc=',
#  'lama',
#  '&cp=09',
#  '2&B1=Registrar HTTP/1.1',
#  'ia=T',
#  'erra',
#  '+S%2FN',
#  '+del+',
#  'm HTTP/1.1',
#  '=Sal',
#  '+De+L',
#  'tc=0',
#  '.htm',
#  'ad=P',
#  'alencia',
#  '2569',
#  'ad=V',
#  '5&B1=Registrar HTTP/1.1',
#  '%3D%2',
#  'laman',
#  'ria&ntc=',
#  'es/s',
#  '&dni=6',
#  'a&ntc=2',
#  'example',
#  'in=c',
#  '8&provincia=',
#  'cia&',
#  '=Cas',
#  'rago',
#  'a&cp=4',
#  'D&ciudad=',
#  'na&apellidos=',
#  '0&B1=Registrar HTTP/1.1',
#  'in=b',
#  '=Car',
#  's%40',
#  'samples/',
#  'oria',
#  'os=B',
#  'G&ciudad=',
#  'ia=G',
#  '&apellidos=Ma',
#  '2F%2',
#  'anca&ntc=',
#  'alamanca',
#  '%3C%2',
#  'amples/s',
#  'os=S',
#  'ni=2',
#  'cript',
#  'H&ciudad=',
#  'il=m',
#  'a&ntc=7',
#  'a&ntc=4',
#  'io&apellidos=',
#  'il=c',
#  'via&',
#  '%40p',
#  'er%40',
#  '+de+la+',
#  'l HTTP/1.1',
#  'r&password=',
#  'rd=a',
#  'ia=Val',
#  'ni=4',
#  '=Sala',
#  'a&ntc=8',
#  '7&B1=Registrar HTTP/1.1',
#  '.asp HTTP/1.1',
#  '=Sor',
#  'ero&',
#  'o&dni=',
#  'ia=L',
#  'ntra',
#  'E%256',
#  'C&ciudad=',
#  'cia&ntc=',
#  're=L',
#  'examples',
#  'E&ciudad=',
#  'ment',
#  '&ntc=6',
#  '+&ciudad=C',
#  's%2C+1',
#  'rd=c',
#  'J&direccion=',
#  '%40l',
#  'in=d',
#  'o%40',
#  'i%40',
#  'u&dni=',
#  'tc=9',
#  '6&provincia=',
#  'B&direccion=',
#  'a%F1',
#  'u%F1',
#  's&cp=0',
#  'ad=B',
#  'ad=M',
#  'on=A',
#  '=Bar',
#  'Mont',
#  'via&ntc=',
#  'illa&',
#  'nta+',
#  'id&ntc=',
#  '%40s',
#  '%F1o',
#  'a&cp=2',
#  'ar&nombre=',
#  're=R',
#  'Y&direccion=',
#  '%EDn',
#  '=Cast',
#  'orre',
#  'm&dni=',
#  '3%3F',
#  'os=P',
#  'ia=A',
#  '=Vil',
#  'es&cp=',
#  'ia=Za',
#  'l&apellidos=',
#  '8%2C+',
#  '&direccion=Pa',
#  '%EDa',
#  '4&provincia=',
#  '+San+',
#  'B&ciudad=',
#  'a&apellidos=C',
#  'z&email=',
#  'Villa',
#  '&ciudad=Al',
#  'l&ntc=',
#  'Samples/',
#  'g&dni=',
#  '&direccion=Pl',
#  'L&direccion=',
#  '7&provincia=',
#  'a&cp=3',
#  '+Mon',
#  'rd=p',
#  '+Cor',
#  'te&n',
#  '5&provincia=',
#  'os=G',
#  'onte',
#  '%3FF&ciudad=',
#  'entr',
#  '=Valen',
#  'ET s',
#  'tc=3',
#  'l&email=',
#  'os%2C+',
#  'd%3D',
#  'E&direccion=',
#  's&cp=1',
#  '/examples',
#  'scri',
#  'adri',
#  'http',
#  'o%2C+1',
#  're=T',
#  'n&email=',
#  'aste',
#  'GET tienda1/miembros/editar.jsp?modo=registro&login=m',
#  'r&email=',
#  '00&provincia=',
#  'eruel',
#  'iron',
#  '%40i',
#  'cookie',
#  'o&password=',
#  'B%256',
#  'no&apellidos=',
#  'era&',
#  '%40v',
#  '+&ciudad=Ca',
#  '&direccion=C%2F+C',
#  'u%F1a',
#  'os=T',
#  'i&email=',
#  'ia=M',
#  'los+',
#  'enti',
#  'e&dni=',
#  '%253A',
#  'alla',
#  're=M',
#  'R&direccion=',
#  'n&dni=',
#  '9090',
#  'c&dni=',
#  '=Mad',
#  '%F3n&ntc=',
#  'loca',
#  '2C+3',
#  'il=h',
#  'n%2C+',
#  '2C+5',
#  '%27%2',
#  'a+De+',
#  'ster',
#  'ml HTTP/1.1',
#  '7%2C+',
#  '+&ciudad=A',
#  '+Mont',
#  'Nava',
#  '=San+',
#  'da&apellidos=',
#  '+Del',
#  'tica',
#  'script',
#  'a&email=s',
#  '=Ter',
#  'acio',
#  'y&dni=',
#  'adrid',
#  'ada&',
#  'ora&ntc=',
#  's&apellidos=C',
#  'erta',
#  'o&apellidos=M',
#  'r&dni=',
#  'a&ntc=6',
#  '%3FH&ciudad=',
#  '+%27',
#  '=Tor',
#  'tell',
#  '+S%2FN%2C+',
#  'l%F3',
#  'Giron',
#  'es%2',
#  '%250',
#  'erna',
#  'i&password=',
#  'illo&',
#  'o&cp=0',
#  '=Mar',
#  'on=M',
#  '0&provincia=B',
#  'on%40',
#  'T&direccion=C',
#  '%40g',
#  '+Cas',
#  'e+Ca',
#  '%2C+13',
#  '2C+9',
#  'V&direccion=',
#  'a%F1a',
#  'arce',
#  '2%2C+',
#  'on=Av',
#  'X&direccion=',
#  'uela',
#  'a&apellidos=M',
#  '=Santa+',
#  '3A%2',
#  'in=h',
#  'in=t',
#  'era+',
#  'Z&direccion=',
#  'o&cp=1',
#  'ra&ntc=5',
#  'e+La',
#  '=Villa',
#  'ina&',
#  'il=g',
#  '+Mar',
#  '2C+6',
#  'rderParser',
#  'a+de+l',
#  't&email=',
#  '6%2C+',
#  'rid&',
#  '=Madr',
#  'arri',
#  're=C',
#  'ares',
#  'ino&',
#  '=Pal',
#  're=G',
#  'a+del+',
#  'o&cp=3',
#  'ia=Valencia',
#  's&cp=2',
#  're=B',
#  'as&email=',
#  '+Sant',
#  'nte&',
#  'n&nombre=',
#  'lian',
#  'ta&email=',
#  'ana&',
#  'in=l',
#  '+La+',
#  'il=d',
#  '+Del+',
#  'host',
#  '=Pas',
#  'ros%',
#  'l+Ca',
#  '%27%3',
#  'A&ciudad=',
#  '=Nava',
#  'admini',
#  '%29%',
#  'n+De',
#  'ria&apellidos=',
#  't%40',
#  'anti',
#  '=Tra',
#  'ia=P',
#  'l&dni=',
#  'e&ntc=',
#  '=092',
#  'e%F1',
#  '1%3F',
#  '3F%2',
#  'samples/s',
#  'e&apellidos=',
#  'ia=Teruel&ntc=',
#  '/examples/',
#  'il=a',
#  'Q&direccion=',
#  'da&ntc=',
#  '%40co',
#  '%40ma',
#  'lles',
#  '&direccion=Cam',
#  'ru%F1a&',
#  'ell%',
#  'ierra',
#  'e%F3',
#  'in%40',
#  'icas',
#  'rand',
#  'Camp',
#  '%253C',
#  'rd=e',
#  'lado',
#  '%2C+12',
#  '3%2C+',
#  'in=k',
#  'rd=d',
#  'e+San',
#  '0&provincia=Sa',
#  'ad=R',
#  'ad=H',
#  '%E9&',
#  'Los+',
#  '&direccion=Car',
#  'arra&ntc=',
#  'ia&apellidos=C',
#  'o&cp=4',
#  '2C+7',
#  '1%2C+',
#  '/samp',
#  'os=R',
#  'ntes',
#  '+De+La',
#  'tion',
#  'r%ED',
#  'ia=%',
#  '%253D',
#  'ador',
#  'er&email=',
#  'ad=T',
#  'aler',
#  'H&direccion=',
#  'os%2C+1',
#  '=Madrid&ntc=',
#  '%3C%21--%23',
#  '%3C%2F',
#  's&password=',
#  'il=r',
#  'ra&nombre=',
#  'ator',
#  '2C+4',
#  'in=j',
#  'ia=Hue',
#  'esca',
#  'il=l',
#  'w&dni=',
#  'A&direccion=',
#  'te&nombre=',
#  'z&dni=',
#  'os=V',
#  'F&direccion=',
#  'aciar',
#  'amor',
#  'trat',
#  'a1/i',
#  're=S',
#  '1&provincia=S',
#  'andr',
#  '0&provincia=C',
#  'res+',
#  'er&password=',
#  'acion',
#  'es%2C+',
#  'M&direccion=',
#  'Torre',
#  'bert',
#  're=I',
#  'G&direccion=',
#  'os=Ar',
#  'esia',
#  '5%2C+',
#  'rave',
#  'a+de+la',
#  '&cp=10',
#  '2%3F',
#  '%29%3',
#  'cookie%',
#  'o&nombre=A',
#  '/order',
#  '0%2C+',
#  '=Gra',
#  's&cp=4',
#  'dela',
#  'villa',
#  'rd=s',
#  'B&direccion=C%2F+',
#  'anad',
#  'agon',
#  '4%2C+',
#  '=Hues',
#  'n&apellidos=M',
#  'h&dni=',
#  'es+de+',
#  'esto',
#  '3+&ciudad=',
#  '&dni=17',
#  '&nombre=Al',
#  '0&provincia=Se',
#  '&cp=092',
#  't&dni=',
#  '%2F%',
#  'ia=Palencia',
#  '256E%2574%252E%256',
#  'an&password=',
#  'http://localhost:',
#  'GET tienda1/publico/registro.jsp?modo=registro&login=m',
#  'rio&',
#  'la&cp=1',
#  '%40f',
#  'r&nombre=A',
#  'ledo',
#  'os=Sa',
#  'n&cp=',
#  'a&cp=08',
#  'n%40a',
#  'llos',
#  '=Giron',
#  'aya&',
#  '+Car',
#  'adal',
#  '%2C+16',
#  'lla&cp=0',
#  '=Torr',
#  '&cp=18',
#  '+Sie',
#  '=Zar',
#  '73&provincia=',
#  'erra&cp=',
#  's&apellidos=M',
#  'e+de+',
#  'D%256',
#  'ET CFIDE/administra',
#  'in=p',
#  're=Ma',
#  'o+De+',
#  '+Los+',
#  'on=L',
#  'edo&',
#  '%3FG&ciudad=',
#  'nill',
#  'ara&',
#  '=174',
#  'Coru',
#  'd=Pa',
#  '3&provincia=Se',
#  '=Caste',
#  'rato',
#  'jsp.',
#  '.htm HTTP/1.1',
#  'lica',
#  'jsp HTTP/1.1',
#  'rist',
#  'A&nombre=',
#  'rar.jsp?',
#  'W&direccion=',
#  'd&password=',
#  'igue',
#  'K&direccion=',
#  '3C%252F',
#  '20&provincia=',
#  '8%2C+&ciudad=',
#  'rd=r',
#  'ina&apellidos=',
#  'es&email=',
#  'co/entrar',
#  'd%3D%22',
#  '%27%3B',
#  're=D',
#  'il=p',
#  'e&email=',
#  '%253E',
#  's+del+',
#  'ia=Madrid&ntc=',
#  '%EDn&',
#  're=H',
#  'ad=Val',
#  'os=To',
#  'el&apellidos=',
#  'ad=Villa',
#  'ad=Be',
#  '6909030637832563290.jsp',
#  '15%2',
#  'script%',
#  '%3D%27',
#  'ana&apellidos=',
#  '2561%256',
#  't&password=',
#  'guer',
#  'il=f',
#  'alert%2',
#  'arcel',
#  '/samples/',
#  '=Gua',
#  '2%2C+&ciudad=',
#  '%F3n&nombre=',
#  '7%2C+&ciudad=',
#  '80&provincia=',
#  '4+&ciudad=',
#  'ente&',
#  '&pwd=',
#  'a1/imagenes/',
#  'odoA=',
#  'os=F',
#  'in=a',
#  'in=r',
#  'i&apellidos=',
#  '2C+L',
#  'ia=Vall',
#  'asti',
#  'D&direccion=',
#  '3&provincia=C',
#  'GET tienda1/miembros/editar.jsp?modo=registro&login=ma',
#  're=P',
#  'il=e',
#  '%E9n',
#  're=No',
#  'r&dni=1',
#  'ilia',
#  'a+de+la+',
#  'Port',
#  'allad',
#  'iano',
#  'J&direccion=C%2F+',
#  'L&direccion=C%2F+',
#  'ro&nombre=',
#  '=Ave',
#  'co/vaciar.jsp?',
#  '.html HTTP/1.1',
#  '.cfm HTTP/1.1',
#  '2C+2',
#  'ad=G',
#  'cp=50',
#  'ia=Huesca&ntc=',
#  'il=k',
#  'e%40c',
#  'r&apellidos=',
#  '2C+S%2FN',
#  'a+De+L',
#  'in=v',
#  'ell&',
#  'lich',
#  '%2522',
#  'ener',
#  'C&direccion=',
#  'N&direccion=',
#  'iber',
#  'ragon',
#  'ra&cp=0',
#  'a+Ri',
#  '=Mon',
#  'in=f',
#  '%F3&',
#  'er%E',
#  'idad',
#  'n&dni=1',
#  'in=ba',
#  'ssan',
#  '0&provincia=Salamanca&ntc=',
#  '9%2C+',
#  'n%40c',
#  'os=D',
#  'ra&ntc=1',
#  '1&provincia=Burgos&ntc=',
#  'ano&',
#  '+11%3F',
#  'arrag',
#  'S&direccion=',
#  'java',
#  'as%2C+',
#  'do&n',
#  'eSamples/',
#  'ia=Girona&ntc=',
#  'Samples/s',
#  'rd=t',
#  'D%250',
#  'IPT%',
#  'ca&nombre=',
#  '/examples/s',
#  'ia=Zamora&ntc=',
#  '%40b',
#  'os=Al',
#  'Gran',
#  's&dni=5',
#  '9%253',
#  'ller',
#  '=Torre',
#  'on=G',
#  'res&',
#  '0&provincia=Burgos&ntc=',
#  'la%2',
#  'ia=A+Coru%F1a&ntc=',
#  'os&cp=1',
#  'a+Cr',
#  'ardi',
#  'tell%',
#  'ria&apellidos=C',
#  'ez&email=',
#  'eral',
#  's&ntc=8',
#  'a%40t',
#  'l%F3n&',
#  'ria&ntc=1',
#  '&cp=19',
#  'ario&',
#  'y%40t',
#  'l%2C+',
#  '=Marc',
#  'do%2C+',
#  'ette',
#  'uente',
#  'elle',
#  'vent',
#  'o&cp=09',
#  '%40z',
#  's&apellidos=Ma',
#  'amon',
#  'n+De+',
#  'ando',
#  '=446',
#  'i%F3',
#  '%F3n&apellidos=',
#  'on=S',
#  'l&ntc=5',
#  'r%40c',
#  'leta',
#  '%40n',
#  'rd=9',
#  '+Rio',
#  'eta&email=',
#  '2&provincia=C',
#  's&ntc=1',
#  '+De+A',
#  'ntin',
#  'ro%2C+',
#  'd=So',
#  'e%40e',
#  '%2C+&ciudad=Al',
#  'asta',
#  'a+S%2FN',
#  '+Cam',
#  'g&dni=5',
#  'e%2C+1',
#  't%F3',
#  'ella',
#  'o&apellidos=C',
#  'ente+',
#  '0&provincia=Soria&ntc=',
#  'ia=Vizcaya&ntc=',
#  '&ciudad=Ar',
#  'quil',
#  'es&apellidos=',
#  'ona&ntc=1',
#  '28%2',
#  '%3B+',
#  '&dni=4',
#  '%2528',
#  'trator/',
#  'GET tienda1/publico/autenticar.jsp?modo=',
#  'rar&login=',
#  '8%256',
#  '0%3A',
#  'ia=Al',
#  'file',
#  'a&dni=',
#  'ad=Pa',
#  '&dni=15',
#  '+De+Los+',
#  'via&ntc=5',
#  'avar',
#  'o%40c',
#  'h%40',
#  's+de+la+',
#  's&ntc=7',
#  'es%2C+1',
#  'lina&',
#  'os+de+',
#  '+%27%25',
#  '%22+',
#  'in=e',
#  'y&password=',
#  '+De+La+',
#  'do=entrar',
#  '30&provincia=',
#  'e%F1a',
#  'a&cp=09',
#  '%27a',
#  'l&password=',
#  'a&nombre=A',
#  '+3%3F',
#  'rd=0',
#  'os=L',
#  'ginA=',
#  'P&direccion=',
#  '%2F%2',
#  're=E',
#  '2C+8',
#  '+S%2FN+',
#  'O&nombre=',
#  '5&nombre=',
#  '/orderParser',
#  'E&direccion=C%2F+',
#  'arre',
#  'eres',
#  're=Na',
#  'ld HTTP/1.1',
#  'nc HTTP/1.1',
#  'co/entrar.jsp?',
#  'id%3D',
#  '+%270%',
#  'il=t',
#  '/samples/s',
#  'on&password=',
#  'en&apellidos=',
#  'o&cp=2',
#  'in=w',
#  'tro%',
#  'a+Ca',
#  'ad=F',
#  'rd=re',
#  '%EDa&',
#  '0%2C+&ciudad=',
#  '+Monte',
#  'document.',
#  'ET iis',
#  '%3D%221',
#  '256D%2570%256',
#  '256C%2565%252F%2563%256',
#  '256C%252E%2563%256',
#  '2564%256F%2563%2575%256',
#  '256B%2569%2565%2573%2574%2565%256',
#  'serv',
#  'odoA=registro&login=',
#  'anza',
#  '%2C%2',
#  'on=R',
#  't.asp HTTP/1.1',
#  'k&password=',
#  'erve',
#  'a&cp=10',
#  'on=Avenida+',
#  'os&cp=3',
#  'i%F1o',
#  'B%253C',
#  '10&provincia=',
#  'os=Ro',
#  '-F&ciudad=',
#  'es&cp=2',
#  '0&nombre=',
#  'ad=Mo',
#  'mente',
#  'il=ma',
#  'ia=Vallado',
#  'ente&nombre=',
#  ...]

# %%
arr = []

for signature in signatures.values():
	for sign in signature:
		if sign[0] not in stopwords:
			print(sign)
			arr.append(sign)
# Out:
# ('public', 48684)
# ('.jsp HTTP/1.1', 45904)
# ('GET tienda1/publico', 26444)
# ('POST tienda1/publico/', 22210)
# ('mbros', 20590)
# ('/miembros', 20560)
# ('enes', 18716)
# ('gene', 18674)
# ('mage', 18674)
# ('GET tienda1/miembros', 15105)
# ('a1/imagenes', 12472)
# ('o.jsp', 10129)
# ('loba', 8391)
# ('a1/global', 8361)
# ('ir.jsp', 7987)
# ('carr', 7399)
# ('rito', 7308)
# ('carri', 7308)
# ('carrito', 7278)
# ('icar', 6741)
# ('tent', 6735)
# ('gar.', 6597)
# ('agar', 6597)
# ('tos.', 6252)
# ('tos.jsp', 6218)
# ('GET tienda1/miembros/imagenes/', 6172)
# ('nadir', 5921)
# ('GET tienda1/publico/a', 5918)
# ('acia', 5783)
# ('stic', 5770)
# ('iar.', 5762)
# ('ciar', 5762)
# ('teri', 5724)
# ('arac', 5714)
# ('risti', 5712)
# ('cara', 5712)
# ('stica', 5710)
# ('ract', 5710)
# ('recio', 5330)
# ('eccion', 5313)
# ('GET tienda1/publico/p', 5295)
# ('do=registro', 5040)
# ('tro&login=', 5037)
# ('do=registro&login=', 4996)
# ('=Reg', 4814)
# ('B1=Registrar HTTP/1.1', 4785)
# ('pell', 4674)
# ('idos', 4651)
# ('lido', 4642)
# ('rovi', 4273)
# ('inde', 4189)
# ('/index.jsp', 4154)
# ('o.jpg HTTP/1.1', 4024)
# ('POST tienda1/publico/anadir.jsp HTTP/1.1', 3379)
# ('POST tienda1/miembros/editar.jsp HTTP/1.1', 3361)
# ('co/registro.jsp HTTP/1.1', 3361)
# ('POST tienda1/publico/autenticar.jsp HTTP/1.1', 3359)
# ('GET tienda1/publico/autenticar.jsp', 3346)
# ('POST tienda1/publico/pagar.jsp HTTP/1.1', 3342)
# ('GET tienda1/publico/autenticar.jsp?modo', 3270)
# ('POST tienda1/publico/registro.jsp HTTP/1.1', 3263)
# ('GET tienda1/publico/pagar.jsp', 3225)
# ('rar&', 3213)
# ('GET tienda1/publico/pagar.jsp?modo', 3158)
# ('GET tienda1/publico/autenticar.jsp?modo=entrar', 3146)
# ('=entrar&login=', 3102)
# ('GET tienda1/publico/autenticar.jsp?modo=entrar&login', 3101)
# ('GET tienda1/publico/pagar.jsp?modo=', 3027)
# ('GET tienda1/publico/pagar.jsp?modo=insertar', 2963)
# ('POST tienda1/publico/caracteristicas.jsp HTTP/1.1', 2950)
# ('POST tienda1/publico/vaciar.jsp HTTP/1.1', 2916)
# ('POST tienda1/publico/entrar.jsp HTTP/1.1', 2894)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio', 2893)
# ('GET tienda1/publico/vaciar.jsp', 2816)
# ('erro', 2773)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=', 2747)
# ('GET tienda1/publico/caracteristicas.jsp', 2730)
# ('GET tienda1/publico/entrar.jsp', 2721)
# ('logo', 2710)
# ('=Entra', 2639)
# ('GET tienda1/publico/registro.jsp', 2636)
# ('%F1ad', 2612)
# ('=Entrar HTTP/1.1', 2609)
# ('cial', 2599)
# ('ales+', 2598)
# ('A%F1a', 2581)
# ('+al+', 2581)
# ('&B1=Entrar HTTP/1.1', 2578)
# ('inco', 2575)
# ('rede', 2575)
# ('encial', 2566)
# ('iales', 2566)
# ('corr', 2566)
# ('&B1=A%F1adir+al+carrito HTTP/1.1', 2551)
# ('GET tienda1/miembros/editar.jsp', 2549)
# ('mber', 2535)
# ('GET tienda1/publico/anadir.jsp', 2512)
# ('cant', 2489)
# ('GET tienda1/publico/vaciar.jsp?B2=', 2291)
# ('GET tienda1/publico/entrar.jsp?errorMsg=', 2214)
# ('GET tienda1/publico/caracteristicas.jsp?id=', 2202)
# ('GET tienda1/publico/vaciar.jsp?B2=Vaciar+carrito', 2182)
# ('ros.', 2120)
# ('GET tienda1/publico/entrar.jsp?errorMsg=Credenciales+incorrectas', 2097)
# ('astro', 2093)
# ('sali', 2092)
# ('itos', 2085)
# ('ros.jsp', 2084)
# ('titu', 2083)
# ('esti', 2081)
# ('estr', 2081)
# ('GET tienda1/miembros/index.jsp', 2076)
# ('los.', 2069)
# ('zara', 2068)
# ('GET tienda1/publico/carrito', 2066)
# ('os/salir.jsp', 2062)
# ('co/miembros', 2061)
# ('rati', 2058)
# ('ditos.jsp', 2056)
# ('os/fotos.jsp', 2055)
# ('a1/global/titulo.jsp', 2052)
# ('stil', 2052)
# ('uest', 2051)
# ('a1/global/menum.jsp', 2049)
# ('ito.', 2048)
# ('duct', 2047)
# ('ctos', 2047)
# ('a1/global/credit', 2045)
# ('ono.', 2038)
# ('os.c', 2037)
# ('GET tienda1/miembros/imagenes/castro.j', 2033)
# ('ros.jsp HTTP/1.1', 2026)
# ('a1/index.jsp HTTP/1.1', 2021)
# ('a1/imagenes/2.gif HTTP/1.1', 2021)
# ('a1/imagenes/3.gif HTTP/1.1', 2021)
# ('a1/imagenes/nuestratierra.jpg HTTP/1.1', 2021)
# ('os/fotos.jsp HTTP/1.1', 2020)
# ('os/salir.jsp HTTP/1.1', 2020)
# ('a1/imagenes/1.gif HTTP/1.1', 2020)
# ('a1/imagenes/cmenbul.gif HTTP/1.1', 2020)
# ('a1/imagenes/logo.gif HTTP/1.1', 2020)
# ('ito.jsp HTTP/1.1', 2017)
# ('ditos.jsp HTTP/1.1', 2017)
# ('o/productos.jsp HTTP/1.1', 2017)
# ('GET tienda1/publico/entrar.jsp?errorMsg=Credenciales+incorrectas HTTP/1.1', 2008)
# ('GET tienda1/publico/vaciar.jsp?B2=Vaciar+carrito HTTP/1.1', 2008)
# ('GET tienda1/miembros/index.jsp HTTP/1.1', 2008)
# ('a1/global/menum.jsp HTTP/1.1', 2007)
# ('a1/global/titulo.jsp HTTP/1.1', 2007)
# ('a1/global/estilos.css HTTP/1.1', 2007)
# ('GET tienda1/miembros/imagenes/ogono.jpg HTTP/1.1', 2007)
# ('GET tienda1/miembros/imagenes/zarauz.jpg HTTP/1.1', 2007)
# ('GET tienda1/miembros/imagenes/castro.jpg HTTP/1.1', 1980)
# ('GET tienda1/publico/carrito.jsp HTTP/1.1', 1964)
# ('a1/global/creditos.jsp HTTP/1.1', 1949)
# ('GET tienda1/publico/productos.jsp HTTP/1.1', 1857)
# ('&direccion=Ca', 1671)
# ('GET tienda1/imagenes/logo.gif HTTP/1.1', 1595)
# ('GET tienda1/imagenes/nuestratierra.jpg HTTP/1.1', 1595)
# ('GET tienda1/index.jsp HTTP/1.1', 1594)
# ('GET tienda1/imagenes/1.gif HTTP/1.1', 1594)
# ('GET tienda1/imagenes/2.gif HTTP/1.1', 1594)
# ('GET tienda1/imagenes/3.gif HTTP/1.1', 1594)
# ('GET tienda1/imagenes/cmenbul.gif HTTP/1.1', 1594)
# ('GET tienda1/miembros/fotos.jsp HTTP/1.1', 1553)
# ('GET tienda1/miembros/salir.jsp HTTP/1.1', 1552)
# ('Calle', 1514)
# ('alle+', 1486)
# ('&direccion=Calle', 1425)
# ('asar', 1343)
# ('=Pasa', 1338)
# ('off&', 1291)
# ('1 HTTP/1.1', 1280)
# ('=off&B1=Entrar HTTP/1.1', 1262)
# ('&remember=off&B1=Entrar HTTP/1.1', 1231)
# ('s&cp=', 1193)
# ('=Con', 1159)
# ('&B1=Confirmar HTTP/1.1', 1094)
# ('GET tienda1/publico/caracteristicas.jsp?id=2', 1080)
# ('co/miembros.jsp HTTP/1.1', 1080)
# ('GET tienda1/publico/caracteristicas.jsp?id=2 HTTP/1.1', 1036)
# ('GET tienda1/publico/caracteristicas.jsp?id=1', 1024)
# ('&nombre=J', 992)
# ('GET tienda1/publico/caracteristicas.jsp?id=1 HTTP/1.1', 978)
# ('+Rioja&', 921)
# ('&nombre=Vi', 920)
# ('GET tienda1/publico/anadir.jsp?id=3', 872)
# ('ino+', 868)
# ('ico&', 840)
# ('rico', 838)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre', 831)
# ('Vino', 831)
# ('100&', 816)
# ('=39&', 803)
# ('%F3n+', 799)
# ('nche', 791)
# ('ego&', 790)
# ('=85&', 779)
# ('rico&', 778)
# ('+Man', 770)
# ('&nombre=Jam', 770)
# ('b%E9', 770)
# ('co&p', 769)
# ('o+Ma', 761)
# ('=Que', 761)
# ('anche', 760)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre', 744)
# ('&provincia=C', 655)
# ('ad=C', 651)
# ('&ntc=3', 642)
# ('&ntc=9', 618)
# ('&ntc=0', 584)
# ('&apellidos=B', 541)
# ('re=A', 525)
# ('ide.', 525)
# ('ad=A', 491)
# ('+S%2', 489)
# ('&email=b', 484)
# ('=San', 482)
# ('a&ntc=3', 472)
# ('&provincia=S', 459)
# ('GET tienda1/publico/vaciar.jsp?B2A=Vaciar+carrito HTTP/1.1', 448)
# ('&provincia=G', 444)
# ('&password=c', 442)
# ('GET tienda1/publico/entrar.jsp?errorMsgA=Credenciales+incorrectas HTTP/1.1', 440)
# ('&email=m', 423)
# ('a&ntc=9', 416)
# ('&dni=2', 411)
# ('Sant', 380)
# ('69%2', 359)
# ('2574', 352)
# ('San+', 351)
# ('a&ntc=0', 348)
# ('e&pwd=', 341)
# ('&provincia=L', 324)
# ('/ HTTP/1.1', 322)
# ('ad=Ca', 308)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=1', 305)
# ('7&B1=A%F1adir+al+carrito HTTP/1.1', 304)
# ('5&B1=A%F1adir+al+carrito HTTP/1.1', 303)
# ('ad=Sa', 302)
# ('e+Sa', 299)
# ('del+', 292)
# ('n&pwd=', 288)
# ('s&cp=3', 285)
# ('4&B1=A%F1adir+al+carrito HTTP/1.1', 274)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=8', 273)
# ('1&B1=A%F1adir+al+carrito HTTP/1.1', 272)
# ('ad=Vi', 272)
# ('arag', 272)
# ('a&remember=off&B1=Entrar HTTP/1.1', 271)
# ('lencia', 270)
# ('a&remember=on&B1=Entrar HTTP/1.1', 266)
# ('6&B1=A%F1adir+al+carrito HTTP/1.1', 266)
# ('1&nombre=Qu', 266)
# ('e+la', 261)
# ('ad=San', 256)
# ('o&remember=off&B1=Entrar HTTP/1.1', 255)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=3', 248)
# ('jsp/asf-logo-wide.', 246)
# ('9&B1=A%F1adir+al+carrito HTTP/1.1', 244)
# ('1&nombre=J', 243)
# ('a&apellidos=B', 241)
# ('o&remember=on&B1=Entrar HTTP/1.1', 239)
# ('ad=Vil', 239)
# ('=Burgo', 237)
# ('0&B1=A%F1adir+al+carrito HTTP/1.1', 232)
# ('+la+', 231)
# ('ad=2', 229)
# ('GET tienda1/publico/caracteristicas.jsp?idA=1 HTTP/1.1', 227)
# ('8&B1=A%F1adir+al+carrito HTTP/1.1', 226)
# ('C HTTP/1.1', 226)
# ('GET tienda1/publico/caracteristicas.jsp?idA=2 HTTP/1.1', 220)
# ('ad=3', 220)
# ('.Old HTTP/1.1', 219)
# ('0 HTTP/1.1', 218)
# ('%F1a&', 214)
# ('252E%256', 212)
# ('io=2', 211)
# ('Juan', 211)
# ('ad=1', 210)
# ('nte&n', 210)
# ('enca', 209)
# ('io=7', 208)
# ('3&B1=A%F1adir+al+carrito HTTP/1.1', 205)
# ('io=5', 202)
# ('e HTTP/1.1', 202)
# ('e+la+', 201)
# ('ad=8', 199)
# ('in=ma', 198)
# ('ad=4', 196)
# ('ad=5', 196)
# ('.java HTTP/1.1', 191)
# ('er&p', 187)
# ('.bak HTTP/1.1', 186)
# ('2&B1=A%F1adir+al+carrito HTTP/1.1', 185)
# ('+Val', 184)
# ('a+De', 184)
# ('=Nav', 184)
# ('.inc HTTP/1.1', 183)
# ('ntan', 183)
# ('=Cam', 183)
# ('ET a', 180)
# ('an%40', 180)
# ('ad=7', 179)
# ('uenca&', 179)
# ('ad=9', 178)
# ('arcelona', 178)
# ('io=4', 173)
# ('ad=Sant', 171)
# ('ad=Al', 170)
# ('7&B1=Pasar+por+caja HTTP/1.1', 169)
# ('io=6', 167)
# ('~ HTTP/1.1', 162)
# ('&apellidos=A', 162)
# ('cioA=', 161)
# ('.BAK HTTP/1.1', 159)
# ('a+del', 159)
# ('.Bak HTTP/1.1', 156)
# ('%2C+10', 154)
# ('io=9', 153)
# ('da1.', 152)
# ('9&B1=Pasar+por+caja HTTP/1.1', 152)
# ('&apellidos=Ca', 152)
# ('e&cp=', 152)
# ('ra&ntc=3', 151)
# ('e+Val', 151)
# ('ad=6', 150)
# ('&cp=05', 149)
# ('1%40', 149)
# ('jara', 148)
# ('rra&', 148)
# ('2&B1=Pasar+por+caja HTTP/1.1', 146)
# ('=cha', 146)
# ('4&B1=Pasar+por+caja HTTP/1.1', 145)
# ('0&provincia=S', 145)
# ('6&B1=Confirmar HTTP/1.1', 144)
# ('/4861362529278789730 HTTP/1.1', 143)
# ('%2F&', 142)
# ('0&provincia=G', 142)
# ('a1/asf-logo-wide.', 141)
# ('5&B1=Confirmar HTTP/1.1', 140)
# ('5&B1=Pasar+por+caja HTTP/1.1', 138)
# ('a&pwd=', 134)
# ('/6909030637832563290.jsp HTTP/1.1', 134)
# ('ia&ntc=9', 131)
# ('=mar', 128)
# ('rt%2', 127)
# ('n%40e', 126)
# ('8&B1=Pasar+por+caja HTTP/1.1', 123)
# ('&pwd=p', 123)
# ('%2C+11', 123)
# ('nca&ntc=5', 123)
# ('s+del', 123)
# ('ona&ntc=0', 122)
# ('&pwd=c', 121)
# ('e+San+', 121)
# ('ora&', 121)
# ('3n&nombre=', 121)
# ('llo&', 120)
# ('mente&', 120)
# ('=car', 120)
# ('1&B1=Pasar+por+caja HTTP/1.1', 119)
# ('%E9n&', 119)
# ('s%2C+13', 119)
# ('&cp=24', 119)
# ('nder', 119)
# ('iana&', 119)
# ('e+Sant', 119)
# ('3&B1=Confirmar HTTP/1.1', 118)
# ('a&email=m', 118)
# ('on=Sa', 118)
# ('0&B1=Pasar+por+caja HTTP/1.1', 117)
# ('jsp/6909030637832563290.jsp', 116)
# ('6&B1=Pasar+por+caja HTTP/1.1', 116)
# ('an&p', 111)
# ('4&B1=Confirmar HTTP/1.1', 110)
# ('ET asf-logo-wide.', 108)
# ('2&B1=Confirmar HTTP/1.1', 108)
# ('252E%2563%256', 105)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Jam%F3n+Ib%E9rico&precio=100&cantidad=', 104)
# ('0&provincia=L', 104)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Queso+Manchego&precio=39&cantidad=', 102)
# ('%3FA&ciudad=', 102)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Vino+Rioja&precio=85&cantidad=', 101)
# ('ande', 99)
# ('/4861362529278789730.', 98)
# ('s&email=m', 98)
# ('ert%2', 98)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Jam%F3n+Ib%E9rico&precio=100&cantidad=', 96)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Vino+Rioja&precio=100&cantidad=', 96)
# ('arro', 96)
# ('T&direccion=', 96)
# ('ar%2', 95)
# ('ET _', 95)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Vino+Rioja&precio=100&cantidad=', 95)
# ('admin', 95)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Vino+Rioja&precio=39&cantidad=', 95)
# ('&email=c', 94)
# ('r&dni=9', 94)
# ('&pwd=e', 94)
# ('e+La+', 94)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Vino+Rioja&precio=85&cantidad=', 93)
# ('7&B1=Confirmar HTTP/1.1', 93)
# ('%40h', 93)
# ('os=E', 93)
# ('1&B1=Confirmar HTTP/1.1', 92)
# ('er%2', 92)
# ('ena&', 92)
# ('orte', 92)
# ('&email=ma', 92)
# ('port', 92)
# ('anue', 92)
# ('9&provincia=B', 92)
# ('amples/', 91)
# ('a&email=b', 91)
# ('8&B1=Confirmar HTTP/1.1', 91)
# ('ares+', 91)
# ('n%2C+1', 91)
# ('mont', 91)
# ('=Pla', 91)
# ('V&direccion=C%2F', 91)
# ('%2C+19', 91)
# ('=248', 91)
# ('=Zam', 91)
# ('+10%', 90)
# ('m%F3n&', 90)
# ('=Santa', 90)
# ('&cp=43', 90)
# ('=443', 90)
# ('nt&p', 90)
# ('nare', 90)
# ('ana%', 90)
# ('lare', 90)
# ('intor', 90)
# ('da&ntc=9', 90)
# ('uera', 90)
# ('onta', 90)
# ('nte&nombre=', 90)
# ('on%2', 90)
# ('k%40', 90)
# ('&pwd=d', 90)
# ('ca&ntc=3', 90)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Jam%F3n+Ib%E9rico&precio=85&cantidad=', 89)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Jam%F3n+Ib%E9rico&precio=39&cantidad=', 89)
# ('%40la', 89)
# ('s%2C+16', 89)
# ('ad=Cast', 89)
# ('Vall', 89)
# ('Q&direccion=C%2F+', 89)
# ('K&direccion=C', 89)
# ('on=San', 89)
# ('Quint', 89)
# ('ona&ntc=2', 89)
# ('Castel', 89)
# ('4&provincia=C', 88)
# ('Alba', 88)
# ('o&dni=4', 88)
# ('nda&apellidos=', 88)
# ('ernand', 88)
# ('en%40', 87)
# ('=Alb', 87)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Vino+Rioja&precio=85&cantidad=', 85)
# ('0&B1=Confirmar HTTP/1.1', 85)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Queso+Manchego&precio=100&cantidad=', 84)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Queso+Manchego&precio=85&cantidad=', 83)
# ('9&B1=Confirmar HTTP/1.1', 83)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Queso+Manchego&precio=100&cantidad=', 83)
# ('3&B1=Pasar+por+caja HTTP/1.1', 83)
# ('jsp/asf-logo-wide HTTP/1.1', 80)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Queso+Manchego&precio=85&cantidad=', 80)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Vino+Rioja&precio=39&cantidad=', 80)
# ('jsp.O', 80)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Queso+Manchego&precio=39&cantidad=', 80)
# ('o&apellidos=B', 80)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Vino+Rioja&precio=100&cantidad=', 80)
# ('%2F&cantidad=', 79)
# ('&pwd=a', 79)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Jam%F3n+Ib%E9rico&precio=85&cantidad=', 79)
# ('o&email=m', 77)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Vino+Rioja&precio=39&cantidad=', 76)
# ('odoA=insertar&precio=', 75)
# ('+S%2FN%2C+&ciudad=', 75)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Queso+Manchego&precio=100&cantidad=', 75)
# ('7+&ciudad=', 75)
# ('jsp/4861362529278789730 HTTP/1.1', 74)
# ('22Paros%2', 74)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Jam%F3n+Ib%E9rico&precio=39&cantidad=', 74)
# ('jsp/asf-logo-wide.gif/ HTTP/1.1', 73)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Jam%F3n+Ib%E9rico&precio=100&cantidad=', 73)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Queso+Manchego&precio=39&cantidad=', 73)
# ('28Paros%2', 72)
# ('cia&ntc=9', 72)
# ('e&password=c', 72)
# ('4%2C+&ciudad=', 72)
# ('GET tienda1/publico/anadir.jsp?id=2&nombre=Jam%F3n+Ib%E9rico&precio=39&cantidad=', 70)
# ('GET tienda1/publico/anadir.jsp?id=3&nombre=Queso+Manchego&precio=85&cantidad=', 70)
# ('ico.', 69)
# ('a&password=c', 69)
# ('=Valencia', 69)
# ('in=mar', 68)
# ('2520', 67)
# ('jsp/asf-logo-wide.gif HTTP/1.1', 66)
# ('GET tienda1/publico/anadir.jsp?id=1&nombre=Jam%F3n+Ib%E9rico&precio=85&cantidad=', 66)
# ('9&provincia=L', 66)
# ('bob%', 65)
# ('e%40s', 65)
# ('%3FC&ciudad=', 64)
# ('cia&ntc=6', 64)
# ('Q&direccion=Calle+', 64)
# ('ia&ntc=1', 64)
# ('ona&ntc=3', 64)
# ('to%2', 63)
# ('+%2F%', 63)
# ('s&ntc=0', 63)
# ('s&ntc=3', 63)
# ('C&direccion=Calle+', 63)
# ('ad=Cam', 63)
# ('ierro', 63)
# ('y%40e', 63)
# ('X&direccion=Ca', 63)
# ('ntana', 63)
# ('y&pwd=', 62)
# ('d=re', 62)
# ('i%F1', 62)
# ('n&apellidos=B', 62)
# ('e&remember=off&B1=Entrar HTTP/1.1', 62)
# ('9&provincia=Ba', 62)
# ('n&dni=8', 62)
# ('4%2C+1', 62)
# ('omer', 62)
# ('ia&ntc=0', 62)
# ('r&remember=off&B1=Entrar HTTP/1.1', 61)
# ('r%40s', 61)
# ('&direccion=Pla', 61)
# ('er%2C+', 61)
# ('ra&apellidos=', 61)
# ('16&B1=Registrar HTTP/1.1', 61)
# ('r&pwd=', 61)
# ('a&apellidos=Ba', 61)
# ('anda', 61)
# ('ctor', 61)
# ('vila', 61)
# ('ra&ntc=0', 61)
# ('ad=Co', 61)
# ('ranc', 61)
# ('m&dni=0', 61)
# ('d=in', 61)
# ('+1%3F', 61)
# ('V&direccion=Calle+', 61)
# ('ardo', 61)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=10', 61)
# ('lla+', 61)
# ('ira&', 61)
# ('g&dni=3', 61)
# ('ley%40', 61)
# ('L&direccion=P', 61)
# ('13&B1=Registrar HTTP/1.1', 61)
# ('l&ntc=8', 61)
# ('=Tol', 61)
# ('+FROM+', 60)
# ('ito%', 60)
# ('252B', 60)
# ('ia%2C+', 60)
# ('nca&ntc=3', 60)
# ('ado+', 60)
# ('6&provincia=G', 60)
# ('rana', 60)
# ('Z&direccion=Calle+', 60)
# ('+Per', 60)
# ('1&provincia=Ba', 60)
# ('6&provincia=B', 60)
# ('land', 60)
# ('os&cp=0', 60)
# ('&dni=34', 60)
# ('os=Es', 60)
# ('nton', 60)
# ('in=do', 60)
# ('&cp=31', 60)
# ('ad=Caste', 60)
# ('nca&ntc=0', 60)
# ('&direccion=Calle+P', 60)
# ('ar&password=', 60)
# ('=Santi', 60)
# ('in=car', 60)
# ('l&cp=0', 60)
# ('=236', 60)
# ('amen', 60)
# ('arta', 60)
# ('anca&ntc=5', 60)
# ('re=Mai', 60)
# ('15&B1=A%F1adir+al+carrito HTTP/1.1', 60)
# ('rofe', 60)
# ('6&provincia=C', 60)
# ('ra&ntc=8', 60)
# ('&direccion=Pl.+', 60)
# ('ia&ntc=7', 60)
# ('&pwd=0', 60)
# ('%40d', 60)
# ('2C+23', 60)
# ('u%F1a&', 60)
# ('&ntc=22', 60)
# ('la&apellidos=', 60)
# ('59032', 60)
# ('R&nombre=', 60)
# ('9L&direccion=', 60)
# ('i%40c', 60)
# ('r&cp=0', 60)
# ('Toledo', 60)
# ('a&cp=43', 60)
# ('ca&ntc=7', 60)
# ('am%F3n&', 60)
# ('cia&nombre=', 60)
# ('enza&', 60)
# ('ia=Zaragoza&ntc=7', 60)
# ('r&dni=0', 60)
# ('emente', 60)
# ('nares', 60)
# ('acios', 60)
# ('+Pintor+', 60)
# ('tori', 60)
# ('la&cp=4', 60)
# ('on&pwd=', 60)
# ('e&dni=5', 60)
# ('a&nombre=J', 60)
# ('&direccion=C%2F+P', 60)
# ('s&cp=37', 60)
# ('e&nombre=Ja', 60)
# ('na&apellidos=B', 60)
# ('51&B1=Registrar HTTP/1.1', 60)
# ('%40so', 60)
# ('ad=Villan', 60)
# ('19&provincia=', 60)
# ('onte&', 60)
# ('57&B1=A%F1adir+al+carrito HTTP/1.1', 60)
# ('ante&', 60)
# ('+Torr', 60)
# ('desi', 60)
# ('rga&', 60)
# ('r+de+la+', 60)
# ('ad=Pal', 60)
# ('in=me', 60)
# ('cate', 60)
# ('ner&', 60)
# ('a&nombre=V', 60)
# ('=carr', 60)
# ('ontan', 60)
# ('ad=Santa', 59)
# ('=Can', 59)
# ('on=San+', 59)
# ('ender', 59)
# ('eric', 59)
# ('n+de+', 59)
# ('=Castell', 59)
# ('arel', 59)
# ('=Quint', 59)
# ('ey&p', 59)
# ('M&direccion=Calle+', 59)
# ('el&apellidos=B', 59)
# ('0&provincia=Gua', 59)
# ('ernande', 59)
# ('=372', 59)
# ('ura&', 59)
# ('web.', 59)
# ('an+De+', 59)
# ('%F3n&ntc=0', 59)
# ('0&provincia=Burgos&ntc=7', 59)
# ('nca&ntc=2', 59)
# ('antabria', 59)
# ('ca&ntc=9', 59)
# ('n&ntc=8', 59)
# ('er%40a', 59)
# ('estu', 59)
# ('5&provincia=B', 59)
# ('ia&apellidos=M', 59)
# ('rri&email=', 59)
# ('na&apellidos=M', 59)
# ('s&ntc=9', 59)
# ('eres&', 59)
# ('a&ntc=87', 59)
# ('a&cp=05', 59)
# ('9&provincia=G', 59)
# ('jsp/6909030637832563290.jsp HTTP/1.1', 58)
# ('=mcc', 58)
# ('e3%40', 58)
# ('que+', 58)
# ('in=cha', 58)
# ('re=Si', 58)
# ('s&cp=33', 58)
# ('il=chan', 58)
# ('=Alba', 58)
# ('s&cp=34', 58)
# ('256E%2574%252', 56)
# ('2568%256F%2573%2574%252', 55)
# ('3Aurl%2', 54)
# ('.nsf HTTP/1.1', 53)
# ('256C%252', 53)
# ('ET CFIDE/administrator/', 53)
# ('252E%2563%256F%256F%256', 52)
# ('a1/asf-logo-wide.gif HTTP/1.1', 51)
# ('252E%2565%257', 51)
# ('a1/asf-logo-wide.gif/ HTTP/1.1', 49)
# ('jsp/asf-logo-wide.gif/.', 49)
# ('GET tienda1/publico/entrar.jsp?errorMsg=%', 47)
# ('&direccion=A', 47)
# ('r&remember=on&B1=Entrar HTTP/1.1', 46)
# ('odoA=entrar&login=', 46)
# ('jsp/4861362529278789730.', 45)
# ('&password=e', 45)
# ('.gif.', 45)
# ('ad=San+', 45)
# ('a1/asf-logo-wide HTTP/1.1', 44)
# ('3E.parosproxy.org', 44)
# ('.jpg/', 44)
# ('s&email=b', 44)
# ('e&remember=on&B1=Entrar HTTP/1.1', 44)
# ('%27+', 43)
# ('o&email=b', 43)
# ('jsp.Old HTTP/1.1', 42)
# ('re=Al', 42)
# ('GET tienda1/publico/vaciar.jsp?B2=%', 41)
# ('s&pwd=', 41)
# ('22Paros%2522%2529%253', 41)
# ('paros%2522%252', 41)
# ('o&apellidos=A', 41)
# ('2564%256F%2563%257', 40)
# ('2575%256', 40)
# ('jsp.java HTTP/1.1', 39)
# ('28Paros%2529%253C%252F', 39)
# ('2FscrIPT%253E', 39)
# ('2FSCRIPT%253E', 39)
# ('%22%3', 39)
# ('a&apellidos=P', 39)
# ('a&email=c', 39)
# ('ET asf-logo-wide HTTP/1.1', 38)
# ('%3CSCRipt%3Ealert%28', 38)
# ('a&apellidos=A', 38)
# ('5+&ciudad=', 38)
# ('%3FE&ciudad=', 38)
# ('A&direccion=C%2F+', 38)
# ('W&direccion=Calle+', 38)
# ('ET asf-logo-wide.gif/ HTTP/1.1', 37)
# ('3F HTTP/1.1', 37)
# ('i&pwd=', 37)
# ('jsp.old HTTP/1.1', 36)
# ('ET _vti_', 36)
# ('%3D1', 36)
# ('%22%2', 36)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=85', 36)
# ('8+&ciudad=', 36)
# ('rd=b', 36)
# ('ET asf-logo-wide.gif HTTP/1.1', 35)
# ('jsp.Inc HTTP/1.1', 35)
# ('%E9s', 35)
# ('en&password=', 35)
# ('in=mi', 35)
# ('style%', 34)
# ('n%2Fc', 34)
# ('a%40c', 34)
# ('n&password=c', 34)
# ('n&cp=4', 34)
# ('in=la', 34)
# ('+Can', 34)
# ('1&provincia=L', 34)
# ('o&pwd=', 34)
# ('r&dni=5', 34)
# ('jsp/ HTTP/1.1', 33)
# ('%3C%2FscrIPT%3E', 33)
# ('an&pwd=', 33)
# ('7&provincia=C', 33)
# ('ello', 33)
# ('8&provincia=C', 33)
# ('re=Y', 33)
# ('edro', 33)
# ('T&direccion=Calle+', 33)
# ('a+Ma', 33)
# ('GET tienda1/publico/anadir.jsp?idA=', 32)
# ('%2F&B1=Entrar HTTP/1.1', 32)
# ('0&provincia=T', 32)
# ('n&cp=0', 32)
# ('D&direccion=Calle+', 32)
# ('0+&ciudad=', 32)
# ('n&cp=2', 32)
# ('in&password=', 32)
# ('4&nombre=', 32)
# ('t&dni=6', 32)
# ('r%EDa&', 32)
# ('cia&ntc=0', 32)
# ('in=ja', 32)
# ('in=pa', 32)
# ('rrer', 32)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=39', 32)
# ('11&B1=Registrar HTTP/1.1', 32)
# ('in=ro', 32)
# ('ia=Zaragoza&ntc=1', 32)
# ('e&dni=4', 32)
# ('il=ka', 32)
# ('aldo', 32)
# ('r&dni=3', 32)
# ('chin', 32)
# ('58&B1=Registrar HTTP/1.1', 32)
# ('ad=3&', 32)
# ('n%40p', 32)
# ('a+de+C', 32)
# ('4&provincia=S', 32)
# ('+S%2FN+&ciudad=', 32)
# ('l&dni=8', 32)
# ('ad=39&B1=A%F1adir+al+carrito HTTP/1.1', 32)
# ('ucha', 32)
# ('6&remember=off&B1=Entrar HTTP/1.1', 32)
# ('0131', 32)
# ('+%2F%2', 31)
# ('le%3D%22', 31)
# ('io&apellidos=B', 31)
# ('o&dni=0', 31)
# ('1&provincia=C', 31)
# ('S&direccion=Calle+', 31)
# ('in=al', 31)
# ('2C+S%2FN%2C+&ciudad=', 31)
# ('F&direccion=C%2F+', 31)
# ('2&provincia=S', 31)
# ('ie&pwd=', 31)
# ('cia&ntc=3', 31)
# ('arin', 31)
# ('F&direccion=Calle+', 31)
# ('m&dni=1', 31)
# ('in=mo', 31)
# ('9&provincia=S', 31)
# ('t&dni=3', 31)
# ('ndro', 31)
# ('on=T', 31)
# ('ad=Santi', 31)
# ('e&dni=8', 31)
# ('re=Ra', 31)
# ('re=Fa', 31)
# ('le&password=', 31)
# ('os=Re', 31)
# ('Z&direccion=P', 31)
# ('arab', 31)
# ('illa+', 31)
# ('49&B1=Registrar HTTP/1.1', 31)
# ('&cp=23', 31)
# ('e&dni=3', 31)
# ('el&p', 31)
# ('sta&', 31)
# ('entid', 31)
# ('ones', 31)
# ('s%2C+10', 31)
# ('il=ri', 31)
# ('12&provincia=', 31)
# ('%EDn&apellidos=', 31)
# ('ie&password=c', 31)
# ('%EDas', 31)
# ('da&ntc=6', 31)
# ('inas', 31)
# ('ls&email=', 31)
# ('J&direccion=Pl', 31)
# ('n+Juan+', 31)
# ('w&dni=3', 31)
# ('10%2C+&ciudad=', 31)
# ('tera', 31)
# ('n&dni=4', 31)
# ('2109', 31)
# ('eta+', 31)
# ('ley%40e', 31)
# ('i&cp=4', 31)
# ('i&password=c', 31)
# ('%F3n&ntc=5', 31)
# ('87&B1=A%F1adir+al+carrito HTTP/1.1', 31)
# ('15&B1=Confirmar HTTP/1.1', 31)
# ('edo+', 31)
# ('as&cp=4', 31)
# ('3667', 31)
# ('rada&', 31)
# ('a&ntc=248', 31)
# ('in=o', 31)
# ('ar&cp=4', 31)
# ('olino', 31)
# ('3&provincia=G', 31)
# ('ado&', 31)
# ('arti', 31)
# ('n&dni=6', 31)
# ('59&B1=Pasar+por+caja HTTP/1.1', 31)
# ('ia=Zamora&ntc=3', 31)
# ('er&pwd=', 31)
# ('il=al', 31)
# ('ano+', 31)
# ('%E1r', 31)
# ('iano&', 31)
# ('io=52', 31)
# ('arqu', 31)
# ('ona&ntc=6', 31)
# ('7C HTTP/1.1', 30)
# ('B1=%', 30)
# ('jsp.B', 30)
# ('0%253CSCRipt%253Ealert%2528', 30)
# ('ito%2', 30)
# ('ad=Car', 30)
# ('%3FB&ciudad=', 30)
# ('n&apellidos=A', 30)
# ('t&pwd=', 30)
# ('in=le', 30)
# ('a&password=a', 30)
# ('amar', 30)
# ('T&direccion=C%2F+', 30)
# ('e&pwd=e', 30)
# ('21&B1=Registrar HTTP/1.1', 30)
# ('42&B1=Registrar HTTP/1.1', 30)
# ('re=Ar', 30)
# ('8&provincia=S', 30)
# ('H&direccion=C%2F+', 30)
# ('ad=2&', 30)
# ('re=Sa', 30)
# ('91&B1=Registrar HTTP/1.1', 30)
# ('ille', 30)
# ('=Gui', 30)
# ('5&provincia=S', 30)
# ('l&dni=6', 30)
# ('lio&apellidos=', 30)
# ('on=F', 30)
# ('6&provincia=Granad', 30)
# ('in=ho', 30)
# ('llin', 30)
# ('o&password=c', 30)
# ('ad=Bo', 30)
# ('32&B1=Registrar HTTP/1.1', 30)
# ('des&', 30)
# ('on%40e', 30)
# ('.com.a', 30)
# ('86&B1=Registrar HTTP/1.1', 30)
# ('in=to', 30)
# ('os=La', 30)
# ('s%40t', 30)
# ('l&apellidos=C', 30)
# ('ienes', 30)
# ('in=fi', 30)
# ('i&email=b', 30)
# ('s&cp=46', 30)
# ('27&B1=Registrar HTTP/1.1', 30)
# ('u&dni=8', 30)
# ('a&dni=8', 30)
# ('dor&', 30)
# ('nca&ntc=4', 30)
# ('Alco', 30)
# ('s&password=c', 30)
# ('+Vil', 30)
# ('rd=A', 30)
# ('ad=75&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('in=ar', 30)
# ('ad=28&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('in=che', 30)
# ('a&apellidos=Co', 30)
# ('-E&ciudad=', 30)
# ('61&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('la&email=', 30)
# ('ard%', 30)
# ('da&ntc=8', 30)
# ('equi', 30)
# ('mart', 30)
# ('e&dni=2', 30)
# ('9%2C+12', 30)
# ('02&B1=Registrar HTTP/1.1', 30)
# ('e&pwd=p', 30)
# ('in=be', 30)
# ('il=pe', 30)
# ('elos.', 30)
# ('l&dni=4', 30)
# ('66&B1=Confirmar HTTP/1.1', 30)
# ('le&pwd=', 30)
# ('52&B1=Pasar+por+caja HTTP/1.1', 30)
# ('eran', 30)
# ('&direccion=C%2F+G', 30)
# ('37C&direccion=', 30)
# ('nga.', 30)
# ('20&provincia=S', 30)
# ('nca&ntc=7', 30)
# ('os=Esp', 30)
# ('&dni=46', 30)
# ('estro', 30)
# ('es&email=s', 30)
# ('ad=To', 30)
# ('2&provincia=G', 30)
# ('ada&ntc=2', 30)
# ('rencia', 30)
# ('ng&password=', 30)
# ('estic', 30)
# ('r&dni=6', 30)
# ('sa&apellidos=', 30)
# ('rd=in', 30)
# ('elis', 30)
# ('e%2C+', 30)
# ('ner&password=', 30)
# ('&dni=09', 30)
# ('an%40e', 30)
# ('odela', 30)
# ('03&B1=Confirmar HTTP/1.1', 30)
# ('ad=Castell', 30)
# ('s&email=ma', 30)
# ('m&dni=06', 30)
# ('il=ho', 30)
# ('e&apellidos=C', 30)
# ('+Ter', 30)
# ('70&provincia=C', 30)
# ('&dni=24', 30)
# ('k&dni=7', 30)
# ('ad=Re', 30)
# ('56&B1=Registrar HTTP/1.1', 30)
# ('ra%2C+11', 30)
# ('r&dni=2', 30)
# ('os&cp=191', 30)
# ('56&B1=Pasar+por+caja HTTP/1.1', 30)
# ('o&nombre=Vi', 30)
# ('4156', 30)
# ('in=tr', 30)
# ('in=mc', 30)
# ('i%40s', 30)
# ('re=Ed', 30)
# ('e+Pa', 30)
# ('ia=Ja%E9n&ntc=9', 30)
# ('o%2C+13', 30)
# ('n&dni=0', 30)
# ('in=bo', 30)
# ('canta', 30)
# ('ling', 30)
# ('tierre', 30)
# ('a&cp=33', 30)
# ('56&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('arell', 30)
# ('an%2C+1', 30)
# ('ll%E', 30)
# ('n&email=s', 30)
# ('B&direccion=Calle+', 30)
# ('rd=4', 30)
# ('os=Pa', 30)
# ('ad=Con', 30)
# ('in=no', 30)
# ('c&dni=0', 30)
# ('os=Pi', 30)
# ('g&dni=6', 30)
# ('n&dni=5', 30)
# ('nter', 30)
# ('2%2C+1', 30)
# ('riel', 30)
# ('l&apellidos=Madri', 30)
# ('+Hernandez', 30)
# ('devel', 30)
# ('r&dni=93', 30)
# ('S&direccion=Pl', 30)
# ('a+De+G', 30)
# ('i%2C+', 30)
# ('ld%40', 30)
# ('n.com.', 30)
# ('9076', 30)
# ('as+del+', 30)
# ('ey&cp=3721', 30)
# ('19&provincia=L', 30)
# ('amente&n', 30)
# ('as%2C+16', 30)
# ('ona&ntc=035', 30)
# ('landa&apellidos=', 30)
# ('badal', 30)
# ('&dni=042', 30)
# ('4249', 30)
# ('alba', 30)
# ('a+del+R', 30)
# ('nte&ntc=2', 30)
# ('11214', 30)
# ('li&p', 30)
# ('o&nombre=Ja', 30)
# ('os=Vin', 30)
# ('ana&cp=2', 30)
# ('&apellidos=Calle+', 30)
# ('quet', 30)
# ('e+Vall', 30)
# ('6722', 30)
# ('2373', 30)
# ('1ceo&nombre=', 30)
# ('e+Valencia', 30)
# ('e+Do', 30)
# ('+161', 30)
# ('ia=%C1vila&ntc=67', 30)
# ('=269', 30)
# ('av%E', 30)
# ('villo', 30)
# ('i%40n', 30)
# ('1P&direccion=P', 30)
# ('go+1', 30)
# ('+107+&ciudad=', 30)
# ('gos&cp=1', 30)
# ('5990', 30)
# ('toan', 30)
# ('n&dni=86', 30)
# ('ardo+', 30)
# ('+de+Val', 30)
# ('orra', 30)
# ('ras&cp=0', 30)
# ('doli', 30)
# ('rey&password=', 30)
# ('&apellidos=Cas', 30)
# ('l%40m', 30)
# ('i&dni=8', 30)
# ('30&provincia=Barcelona&ntc=5', 30)
# ('=ale', 30)
# ('ante&remember=off&B1=Entrar HTTP/1.1', 30)
# ('02&B1=Confirmar HTTP/1.1', 30)
# ('ange', 30)
# ('rena&apellidos=', 30)
# ('do+Gu', 30)
# ('l&dni=2', 30)
# ('a%2C+18', 30)
# ('alvi', 30)
# ('villar', 30)
# ('r&cp=34', 30)
# ('a&apellidos=Cal', 30)
# ('ad=Ba', 30)
# ('=2366', 30)
# ('55&B1=Confirmar HTTP/1.1', 30)
# ('+Campos&cp=02', 30)
# ('=648', 30)
# ('a&email=se', 30)
# ('4&provincia=L', 30)
# ('as&apellidos=M', 30)
# ('r&email=s', 30)
# ('p&dni=5', 30)
# ('9S&direccion=C%2F+', 30)
# ('alegr', 30)
# ('uard', 30)
# ('da&cp=1', 30)
# ('&pwd=04', 30)
# ('am&p', 30)
# ('re=Mair', 30)
# ('sche', 30)
# ('as&cp=19', 30)
# ('p&dni=6', 30)
# ('=Valde', 30)
# ('3&provincia=S', 30)
# ('orri', 30)
# ('A&direccion=Ca', 30)
# ('ra+Bar', 30)
# ('ierra&', 30)
# ('a&cp=344', 30)
# ('ia=Navarra&ntc=3', 30)
# ('ria+', 30)
# ('9%40c', 30)
# ('3137', 30)
# ('monte&', 30)
# ('e&cp=17', 30)
# ('is&p', 30)
# ('2682', 30)
# ('lis&', 30)
# ('iego&', 30)
# ('y%40i', 30)
# ('0&provincia=Cuenca&ntc=0', 30)
# ('t0&nombre=', 30)
# ('i&apellidos=Ba', 30)
# ('n&pwd=o', 30)
# ('el&apellidos=Ba', 30)
# ('i&dni=3', 30)
# ('9530', 30)
# ('jar+', 30)
# ('ad=Nava', 30)
# ('ia=A+Coru%F1a&ntc=8', 30)
# ('6825', 30)
# ('a&apellidos=Bar', 30)
# ('=monte', 30)
# ('+180', 30)
# ('te&cp=2', 30)
# ('4298', 30)
# ('ib&p', 30)
# ('io=60', 30)
# ('25&B1=Pasar+por+caja HTTP/1.1', 30)
# ('la&nombre=', 30)
# ('co&email=', 30)
# ('s%40m', 30)
# ('ia=Ourense&ntc=2', 30)
# ('64&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('cass', 30)
# ('l&email=bar', 30)
# ('2181', 30)
# ('&direccion=C%2F+Po', 30)
# ('is&apellidos=', 30)
# ('+Lau', 30)
# ('ann&', 30)
# ('y%40mu', 30)
# ('L&direccion=Pl.+', 30)
# ('ra&cp=43', 30)
# ('ia=Zaragoza&ntc=73', 30)
# ('69231', 30)
# ('ad=15&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('h&pwd=', 30)
# ('re=Da', 30)
# ('ira&apellidos=C', 30)
# ('a%40professionalhost.', 30)
# ('s&cp=31', 30)
# ('0&provincia=Salamanca&ntc=5', 30)
# ('u&email=bar', 30)
# ('aspa', 30)
# ('les+de+', 30)
# ('e+Vald', 30)
# ('5&provincia=L', 30)
# ('da&ntc=95', 30)
# ('a+Bas', 30)
# ('2C+23%2C+', 30)
# ('ra&ntc=2', 30)
# ('9898', 30)
# ('215&B1=Registrar HTTP/1.1', 30)
# ('=Gas', 30)
# ('asco', 30)
# ('%40lam', 30)
# ('b&dni=5', 30)
# ('2C+3-', 30)
# ('8210', 30)
# ('e&pwd=t', 30)
# ('rd=7r', 30)
# ('ana&apellidos=B', 30)
# ('o&dni=2', 30)
# ('+Torre', 30)
# ('la+de+', 30)
# ('a&cp=171', 30)
# ('cia&ntc=95', 30)
# ('in=po', 30)
# ('ortel', 30)
# ('eremo', 30)
# ('=Cir', 30)
# ('ra&email=m', 30)
# ('ango', 30)
# ('ado+Del', 30)
# ('14&provincia=Cuenca&ntc=8', 30)
# ('3841', 30)
# ('ta+B', 30)
# ('rica', 30)
# ('1966', 30)
# ('e+Be', 30)
# ('cia&ntc=22', 30)
# ('a%40muevetuweb.', 30)
# ('9L&direccion=Calle+', 30)
# ('ila&ntc=1', 30)
# ('d=ce', 30)
# ('ki&p', 30)
# ('hett', 30)
# ('os=Z', 30)
# ('ner%40', 30)
# ('e%F1e', 30)
# ('jo&cp=4', 30)
# ('=481', 30)
# ('7971', 30)
# ('ons+', 30)
# ('+Cama', 30)
# ('inte', 30)
# ('ernet.', 30)
# ('&cp=48', 30)
# ('8850', 30)
# ('n&apellidos=Bo', 30)
# ('arai', 30)
# ('da&email=', 30)
# ('r&dni=07', 30)
# ('Tierra', 30)
# ('ad=21&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('5%40', 30)
# ('ad=Ti', 30)
# ('1984', 30)
# ('re=Am', 30)
# ('.cn&dni=9', 30)
# ('590320', 30)
# ('in=na', 30)
# ('e&email=m', 30)
# ('ad=Puebl', 30)
# ('verde', 30)
# ('ia=Zamora&ntc=5', 30)
# ('0989', 30)
# ('an&apellidos=Mont', 30)
# ('y&email=', 30)
# ('Q&direccion=C%2F+E', 30)
# ('a&pwd=p', 30)
# ('i%40en', 30)
# ('78W&direccion=', 30)
# ('ela&', 30)
# ('=192', 30)
# ('va&ntc=2', 30)
# ('lica&', 30)
# ('&dni=19', 30)
# ('8247', 30)
# ('icci', 30)
# ('3%2C+1%3FC&ciudad=', 30)
# ('=093', 30)
# ('9&provincia=Cuenca&ntc=8', 30)
# ('514&', 30)
# ('da&nombre=J', 30)
# ('las+', 30)
# ('o&cp=29', 30)
# ('9&provincia=Barcelona&ntc=8', 30)
# ('3483', 30)
# ('o&apellidos=Munta', 30)
# ('an%4092', 30)
# ('r&dni=4', 30)
# ('ena&cp=2', 30)
# ('ia=Tarragona&ntc=0', 30)
# ('o&dni=42', 30)
# ('450&provincia=Guadalajara&ntc=3', 30)
# ('%EDn+', 30)
# ('u&dni=0', 30)
# ('=014', 30)
# ('Calle+De+La+', 30)
# ('+7%3FD&ciudad=', 30)
# ('s&cp=371', 30)
# ('&provincia=Guadalajara&ntc=7', 30)
# ('ero&apellidos=', 30)
# ('+Francisco+', 30)
# ('87&B1=Registrar HTTP/1.1', 30)
# ('ica&nombre=', 30)
# ('am&apellidos=', 30)
# ('an%40m', 30)
# ('ad=Villas', 30)
# ('ca+de+', 30)
# ('ia=Le%F3n&ntc=0', 30)
# ('io=73', 30)
# ('relli', 30)
# ('8193', 30)
# ('V&direccion=Pl', 30)
# ('1&provincia=Burgos&ntc=55', 30)
# ('spark', 30)
# ('z&dni=6', 30)
# ('G&direccion=C%2F+', 30)
# ('ad=Villanueva+de+', 30)
# ('o&cp=248', 30)
# ('4836&', 30)
# ('6&provincia=Cuenca&ntc=5', 30)
# ('2584', 30)
# ('y&dni=6', 30)
# ('8137', 30)
# ('ad=Ru', 30)
# ('dera&', 30)
# ('36&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('2&pwd=p', 30)
# ('atore', 30)
# ('ura&email=s', 30)
# ('=fulm', 30)
# ('aris.', 30)
# ('.fr&dni=9', 30)
# ('6229', 30)
# ('1379', 30)
# ('igua+', 30)
# ('a%40ma', 30)
# ('.ly&dni=4', 30)
# ('ana&cp=0', 30)
# ('2C+31%2C+1', 30)
# ('ad=Sant+', 30)
# ('orell', 30)
# ('%F1a&email=', 30)
# ('.af&dni=7', 30)
# ('+Ant', 30)
# ('onio&', 30)
# ('5622', 30)
# ('errada', 30)
# ('ra&ntc=44', 30)
# ('1636', 30)
# ('io=27', 30)
# ('uente&n', 30)
# ('=437', 30)
# ('3736', 30)
# ('Salva', 30)
# ('vado', 30)
# ('or%2C+', 30)
# ('+10%3FF&ciudad=', 30)
# ('4972', 30)
# ('r%40so', 30)
# ('e+San+S', 30)
# ('a&cp=40', 30)
# ('a&ntc=78', 30)
# ('n&pwd=at', 30)
# ('re=Ka', 30)
# ('os=Juanhuix&email=b', 30)
# ('+11-', 30)
# ('183&', 30)
# ('7836', 30)
# ('re=Mad', 30)
# ('adon', 30)
# ('ona&apellidos=', 30)
# ('es%40', 30)
# ('g&dni=2', 30)
# ('panari', 30)
# ('io&cp=4', 30)
# ('a&dni=4', 30)
# ('+Tenza&email=', 30)
# ('g&dni=34', 30)
# ('zaci', 30)
# ('urop', 30)
# ('uentes', 30)
# ('anueva+de+Santa', 30)
# ('l&ntc=0', 30)
# ('4034', 30)
# ('ritar', 30)
# ('nio&apellidos=', 30)
# ('os=Tu', 30)
# ('ingo', 30)
# ('an+A', 30)
# ('z%2C+10', 30)
# ('uente+', 30)
# ('&cp=051', 30)
# ('nt&password=', 30)
# ('d=74', 30)
# ('r&apellidos=Mi', 30)
# ('.ga&dni=2', 30)
# ('illo&cp=0', 30)
# ('in=carr', 30)
# ('porte', 30)
# ('an%40a', 30)
# ('e&dni=52', 30)
# ('on=El', 30)
# ('=Eli', 30)
# ('=341', 30)
# ('in=y', 30)
# ('rio&apellidos=', 30)
# ('aus+', 30)
# ('s%40h', 30)
# ('2C+l', 30)
# ('97&provincia=', 30)
# ('ia=Zaragoza&ntc=5', 30)
# ('5253', 30)
# ('o&nombre=Qu', 30)
# ('liana&apellidos=', 30)
# ('osas', 30)
# ('ober', 30)
# ('74834', 30)
# ('ser&', 30)
# ('rina&nombre=', 30)
# ('&direccion=Calle+Pintor+Juan+', 30)
# ('145&', 30)
# ('d=68', 30)
# ('il=pi', 30)
# ('ia=Toledo&ntc=52', 30)
# ('2756', 30)
# ('in=za', 30)
# ('rd=des', 30)
# ('ilare', 30)
# ('t&email=b', 30)
# ('os&ntc=3', 30)
# ('nares+', 30)
# ('=hen', 30)
# ('+Juan+De+', 30)
# ('e+Juan', 30)
# ('elic', 30)
# ('cent&p', 30)
# ('ara&ntc=1', 30)
# ('k%40co', 30)
# ('lares+', 30)
# ('e+Re', 30)
# ('99&B1=Registrar HTTP/1.1', 30)
# ('orbo', 30)
# ('%40comercio', 30)
# ('1482', 30)
# ('8272', 30)
# ('lo%2C+1', 30)
# ('ierro&', 30)
# ('o&cp=49', 30)
# ('l&ntc=9', 30)
# ('ett%40co', 30)
# ('llo&cp=2', 30)
# ('4971', 30)
# ('dio&apellidos=', 30)
# ('%40portaldesign.', 30)
# ('t&dni=4', 30)
# ('4863', 30)
# ('3&provincia=Burgos&ntc=8', 30)
# ('lie&password=', 30)
# ('ina&apellidos=C', 30)
# ('ana+', 30)
# ('ico.m', 30)
# ('&dni=35', 30)
# ('5294', 30)
# ('+Estr', 30)
# ('%F3n&cp=3', 30)
# ('50&provincia=L', 30)
# ('ugo&', 30)
# ('o&ntc=1', 30)
# ('34&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('on&pwd=e', 30)
# ('9&remember=off&B1=Entrar HTTP/1.1', 30)
# ('17&B1=Pasar+por+caja HTTP/1.1', 30)
# ('in=mel', 30)
# ('emente&nombre=', 30)
# ('stre', 30)
# ('a&dni=3', 30)
# ('l%2C+143', 30)
# ('cia&nombre=Vi', 30)
# ('ctori', 30)
# ('il=go', 30)
# ('y%40p', 30)
# ('acere', 30)
# ('V&direccion=C%2F+R', 30)
# ('o+de+M', 30)
# ('+de+Mirra%2C+', 30)
# ('7467', 30)
# ('23&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('a&cp=22', 30)
# ('311&provincia=Burgos&ntc=7', 30)
# ('erin', 30)
# ('ino&apellidos=M', 30)
# ('iencia', 30)
# ('lici', 30)
# ('l&dni=70', 30)
# ('ad=J', 30)
# ('2532', 30)
# ('ra&ntc=52', 30)
# ('ad=57&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('d=59', 30)
# ('=253', 30)
# ('llo+', 30)
# ('ta&email=bo', 30)
# ('besch%40co', 30)
# ('79631', 30)
# ('la%2C+', 30)
# ('ra&ntc=09', 30)
# ('27790', 30)
# ('cona', 30)
# ('De+Las+', 30)
# ('as%2C+196+&ciudad=', 30)
# ('%F1ada', 30)
# ('da+del', 30)
# ('o&cp=3742', 30)
# ('a&ntc=76', 30)
# ('bana', 30)
# ('io=71', 30)
# ('io&apellidos=Ca', 30)
# ('Carri', 30)
# ('rino', 30)
# ('i%40co', 30)
# ('coche', 30)
# ('P&direccion=Cam', 30)
# ('as%2C+14', 30)
# ('650&provincia=', 30)
# ('1%40s', 30)
# ('8568', 30)
# ('ieta', 30)
# ('uerta+', 30)
# ('&ntc=77', 30)
# ('5790', 30)
# ('46&B1=Confirmar HTTP/1.1', 30)
# ('li&apellidos=', 30)
# ('os=N', 30)
# ('8102', 30)
# ('7&provincia=Ba', 30)
# ('e9&password=', 30)
# ('il=lo', 30)
# ('lora', 30)
# ('ont%E1n', 30)
# ('ar&cp=0', 30)
# ('ia=Zaragoza&ntc=3', 30)
# ('=34&B1=Confirmar HTTP/1.1', 30)
# ('in=mare', 30)
# ('rella', 30)
# ('in%40a', 30)
# ('ro%2C+1', 30)
# ('arroy', 30)
# ('a&cp=092', 30)
# ('id&ntc=5', 30)
# ('rita&', 30)
# ('lin&apellidos=', 30)
# ('1%40es', 30)
# ('no.m', 30)
# ('s&cp=44', 30)
# ('Sego', 30)
# ('barri', 30)
# ('&dni=170', 30)
# ('s%2C+12', 30)
# ('4%2C+10', 30)
# ('o&cp=06', 30)
# ('%E0&', 30)
# ('in=senderow&password=', 30)
# ('AR&nombre=', 30)
# ('7908', 30)
# ('&ntc=94', 30)
# ('in=dor', 30)
# ('ilba', 30)
# ('3F&direccion=', 30)
# ('ras+', 30)
# ('5940', 30)
# ('ans+', 30)
# ('h%40a', 30)
# ('70&B1=Registrar HTTP/1.1', 30)
# ('in=rei', 30)
# ('ll%F3n&nombre=', 30)
# ('o+Ser', 30)
# ('na&email=mar', 30)
# ('on=De+', 30)
# ('ns+Zu', 30)
# ('+Puert', 30)
# ('ad=Ra', 30)
# ('81&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('osel', 30)
# ('j&dni=9', 30)
# ('=949', 30)
# ('on%2C+14', 30)
# ('l&cp=01', 30)
# ('ada&ntc=91', 30)
# ('&pwd=cambu', 30)
# ('72&B1=Pasar+por+caja HTTP/1.1', 30)
# ('alib', 30)
# ('%E1n&', 30)
# ('an%40h', 30)
# ('a&dni=1', 30)
# ('ada&cp=2', 30)
# ('a%40n', 30)
# ('natura', 30)
# ('7J&direccion=Calle+', 30)
# ('ralt', 30)
# ('ar%2C+', 30)
# ('o&cp=443', 30)
# ('1478', 30)
# ('%F3n&remember=on&B1=Entrar HTTP/1.1', 30)
# ('=Rep', 30)
# ('a+10', 30)
# ('k&dni=1', 30)
# ('+Igl', 30)
# ('anco', 30)
# ('=455', 30)
# ('ia=Teruel&ntc=2', 30)
# ('251&B1=Registrar HTTP/1.1', 30)
# ('to&remember=off&B1=Entrar HTTP/1.1', 30)
# ('incl', 30)
# ('mente&nombre=Jaazael&apellidos=', 30)
# ('lber', 30)
# ('e+Santan', 30)
# ('a&cp=06', 30)
# ('onso', 30)
# ('%40ca', 30)
# ('E&direccion=Calle+', 30)
# ('e%F1a&cp=4', 30)
# ('ia=Zaragoza&ntc=6', 30)
# ('50&B1=Registrar HTTP/1.1', 30)
# ('eda&cp=443', 30)
# ('38&provincia=Ba', 30)
# ('yola', 30)
# ('e&pwd=d', 30)
# ('da&remember=off&B1=Entrar HTTP/1.1', 30)
# ('l&dni=1', 30)
# ('719&', 30)
# ('taci', 30)
# ('a&apellidos=Be', 30)
# ('s&dni=8', 30)
# ('1%3FA&ciudad=', 30)
# ('68&provincia=', 30)
# ('&pwd=du', 30)
# ('14&B1=Pasar+por+caja HTTP/1.1', 30)
# ('re=Gen', 30)
# ('rg%40c', 30)
# ('=wal', 30)
# ('endr', 30)
# ('ga&email=', 30)
# ('&dni=18', 30)
# ('la&ntc=4', 30)
# ('in=ga', 30)
# ('51&B1=Pasar+por+caja HTTP/1.1', 30)
# ('2V&direccion=Calle+', 30)
# ('dra+', 30)
# ('1%40p', 30)
# ('era%2C+', 30)
# ('ad=Bio', 30)
# ('60928', 30)
# ('81&B1=Registrar HTTP/1.1', 30)
# ('90&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('in&pwd=', 30)
# ('rd=7ar', 30)
# ('oras.', 30)
# ('l&dni=5', 30)
# ('e+Con', 30)
# ('ozal', 30)
# ('n+del+', 30)
# ('ia=Zaragoza&ntc=2', 30)
# ('%40as', 30)
# ('bi&dni=0', 30)
# ('les%2C+19', 30)
# ('a&password=co', 30)
# ('r%40e', 30)
# ('es%2C+137', 30)
# ('3%3FA&ciudad=', 30)
# ('o&ntc=6', 30)
# ('4859', 30)
# ('rto&', 30)
# ('re=So', 30)
# ('ia%2C+1', 30)
# ('6&provincia=Barcelona&ntc=3', 30)
# ('=394', 30)
# ('.pr&dni=7', 30)
# ('C&direccion=Plaza+', 30)
# ('lari', 30)
# ('nas&', 30)
# ('anes%2C+13', 30)
# ('%E9n+de+', 30)
# ('ta&cp=47', 30)
# ('7959', 30)
# ('l%E9', 30)
# ('t+La', 30)
# ('erico', 30)
# ('o+Momp', 30)
# ('y&password=c', 30)
# ('ad=Camin', 30)
# ('&cp=247', 30)
# ('17&provincia=G', 30)
# ('consu', 30)
# ('sult', 30)
# ('remi', 30)
# ('omber', 30)
# ('=Luc', 30)
# ('Card', 30)
# ('s&cp=05', 30)
# ('ar&password=c', 30)
# ('osa+', 30)
# ('a+Fontan', 30)
# ('anet', 30)
# ('mobi', 30)
# ('X&direccion=C%2F+A', 30)
# ('na&cp=3', 30)
# ('22&provincia=', 30)
# ('am%F3n&nombre=', 30)
# ('ber%', 30)
# ('i%40discotecateatre.', 30)
# ('ar+de+la+', 30)
# ('rden', 30)
# ('954&B1=Registrar HTTP/1.1', 30)
# ('ta&password=', 30)
# ('rd=man', 30)
# ('orno', 30)
# ('n&email=b', 30)
# ('o&dni=8', 30)
# ('=851', 30)
# ('M&direccion=Calle+Ca', 30)
# ('ico+', 30)
# ('ria&ntc=7', 30)
# ('o&email=mu', 30)
# ('vela', 30)
# ('zaragoza', 30)
# ('D&direccion=Cami', 30)
# ('er%2C+10', 30)
# ('isuerga&cp=3', 30)
# ('216&B1=Registrar HTTP/1.1', 30)
# ('ad=Alm', 30)
# ('ina&cp=0', 30)
# ('Queral', 30)
# ('ad=Quintana%', 30)
# ('%E9lez', 30)
# ('&cp=4731', 30)
# ('813&B1=Registrar HTTP/1.1', 30)
# ('z&dni=7', 30)
# ('3E&direccion=', 30)
# ('593&', 30)
# ('08&B1=Pasar+por+caja HTTP/1.1', 30)
# ('=Anton', 30)
# ('nio+U', 30)
# ('+6%3FD&ciudad=', 30)
# ('ad=Z', 30)
# ('ronte', 30)
# ('ia=Huesca&ntc=11', 30)
# ('v&dni=56', 30)
# ('el&ntc=5', 30)
# ('arad', 30)
# ('Merce', 30)
# ('lava', 30)
# ('=rom', 30)
# ('+Pere', 30)
# ('os%2C+16', 30)
# ('=Alme', 30)
# ('a&ntc=31', 30)
# ('bran', 30)
# ('anaria', 30)
# ('.do&dni=1', 30)
# ('1342', 30)
# ('aval%', 30)
# ('ad=84&B1=A%F1adir+al+carrito HTTP/1.1', 30)
# ('y&pwd=c', 30)
# ('ambr', 30)
# ('g&dni=15', 30)
# ('ra&ntc=61', 30)
# ('in=jo', 30)
# ('ohan', 30)
# ('ia&apellidos=B', 30)
# ('C&direccion=C%2F+Mar', 30)
# ('cos+', 30)
# ('ad=Pala', 30)
# ('era&cp=2', 30)
# ('rio&remember=on&B1=Entrar HTTP/1.1', 30)
# ('60&B1=Pasar+por+caja HTTP/1.1', 30)
# ('aver', 30)
# ('alacios', 30)
# ('la&cp=47', 30)
# ('s&ntc=2', 30)
# ('ia=Teruel&ntc=8', 30)
# ('6250', 30)
# ('d=bo', 29)
# ('407&B1=Pasar+por+caja HTTP/1.1', 29)
# ('ull+', 29)
# ('l&email=s', 29)
# ('atge+', 29)
# ('ad=Santa+', 29)
# ('%E7a', 29)
# ('ana&cp=16', 29)
# ('ona&ntc=046', 29)
# ('assi', 29)
# ('erman', 29)
# ('29&B1=Pasar+por+caja HTTP/1.1', 29)
# ('n&apellidos=Mar', 29)
# ('4765', 29)
# ('32%2C+&ciudad=', 29)
# ('4&provincia=Cuenca&ntc=9', 29)
# ('se&password=', 29)
# ('lera', 29)
# ('nade', 29)
# ('her%40a', 29)
# ('5263', 29)
# ('u&pwd=', 29)
# ('as&email=m', 29)
# ('+13%3FH&ciudad=', 29)
# ('era&cp=1', 29)
# ('0&provincia=Barcelona&ntc=2', 29)
# ('=far', 29)
# ('lano', 29)
# ('os&cp=41', 29)
# ('ussi', 29)
# ('&dni=64', 29)
# ('ravin', 29)
# ('n&ntc=6', 29)
# ('01657', 29)
# ('360&', 29)
# ('re=Is', 29)
# ('ia.g', 29)
# ('1W&direccion=', 29)
# ('aque+', 29)
# ('10&provincia=Girona&ntc=7', 29)
# ('=1858', 29)
# ('=alf', 29)
# ('en%40a', 29)
# ('estudi', 29)
# ('+Riu+', 29)
# ('+13-', 29)
# ('russ', 29)
# ('uenga', 29)
# ('R&direccion=Pl', 29)
# ('na&cp=05', 29)
# ('0&provincia=Ca', 29)
# ('ad=16&B1=A%F1adir+al+carrito HTTP/1.1', 29)
# ('Sola', 29)
# ('r&email=b', 29)
# ('+Castro&', 29)
# ('60&B1=Registrar HTTP/1.1', 29)
# ('ther', 29)
# ('s&dni=0', 29)
# ('ia=Navarra&ntc=9', 29)
# ('0476', 29)
# ('ia=Ja%E9n&ntc=8', 29)
# ('r&nombre=Qu', 29)
# ('e3%40m', 29)
# ('orca', 29)
# ('a.com.', 29)
# ('os+del+', 29)
# ('o&cp=12', 29)
# ('310&provincia=', 29)
# ('ia=Murcia&ntc=8', 29)
# ('9336', 29)
# ('rd=at', 29)
# ('ine&', 29)
# ('eras&email=', 29)
# ('+196%2C+', 29)
# ('0691', 29)
# ('ff&p', 29)
# ('re=Sil', 29)
# ('arra+', 29)
# ('t%40e', 29)
# ('ndel', 29)
# ('3657', 29)
# ('on=San+Pe', 29)
# ('owen', 29)
# ('&pwd=4', 29)
# ('n&dni=7', 29)
# ('=mcco', 29)
# ('um&pwd=', 29)
# ('bia&apellidos=', 29)
# ('a+75', 29)
# ('&provincia=Cantabria&ntc=6', 29)
# ('vina', 29)
# ('ragu', 29)
# ('x&dni=7', 29)
# ('cia&ntc=641', 29)
# ('0439', 29)
# ('847&B1=Pasar+por+caja HTTP/1.1', 29)
# ('ila&apellidos=', 29)
# ('erlin', 29)
# ('ro&dni=3', 29)
# ('4115', 29)
# ('t%40la', 29)
# ('Q&direccion=Calle+San+', 29)
# ('as&cp=33', 29)
# ('ia=Navarra&ntc=4', 29)
# ('67&B1=A%F1adir+al+carrito HTTP/1.1', 29)
# ('7&remember=on&B1=Entrar HTTP/1.1', 29)
# ('GET tienda1/publico/pagar.jsp?modo=insertar&precio=100', 29)
# ('005&B1=Pasar+por+caja HTTP/1.1', 29)
# ('in=bas', 29)
# ('%E9&apellidos=', 29)
# ('=ste', 29)
# ('.com.t', 29)
# ('79837', 29)
# ('C&direccion=Calle+Sant', 29)
# ('2&provincia=Burgos&ntc=0', 29)
# ('rd=ex', 29)
# ('os+de+B', 29)
# ('via&ntc=9', 29)
# ('24&B1=Registrar HTTP/1.1', 29)
# ('abia', 29)
# ('iana&nombre=', 29)
# ('ray%40c', 29)
# ('5%2C+11', 29)
# ('1&provincia=Barcelona&ntc=9', 29)
# ('+Bur', 29)
# ('c&dni=9', 29)
# ('8907', 29)
# ('0293', 29)
# ('chad', 29)
# ('atien', 29)
# ('llaz', 29)
# ('s&dni=4', 29)
# ('0460', 29)
# ('1L&direccion=Calle+', 29)
# ('Mari', 29)
# ('1374', 29)
# ('460&provincia=', 29)
# ('ad=44', 29)
# ('re=Bal', 29)
# ('direct', 29)
# ('&dni=71', 29)
# ('eira', 29)
# ('64%2C+', 29)
# ('m%E9n&', 29)
# ('da&apellidos=M', 29)
# ('E&remember=on&B1=Entrar HTTP/1.1', 29)
# ('8954', 29)
# ('7%2C+12', 29)
# ('ad=Alfa', 29)
# ('0&provincia=La+Rioja&ntc=1', 29)
# ('aile', 29)
# ('1&pwd=', 29)
# ('il=chang', 29)
# ('ad=Mu', 29)
# ('2&provincia=La+Rioja&ntc=3', 29)
# ('67&B1=Registrar HTTP/1.1', 29)
# ('il=u', 29)
# ('h&dni=70', 29)
# ('rina&cp=2', 29)
# ('rago&', 29)
# ('erol', 29)
# ('ales&cp=4', 29)
# ('Z&direccion=Calle+Sa', 29)
# ('5&provincia=Burgos&ntc=9', 29)
# ('enni', 29)
# ('f&dni=8', 29)
# ('nca&ntc=37', 29)
# ('table', 29)
# ('ista', 29)
# ('1%40r', 29)
# ('+Padre+', 29)
# ('es&cp=45', 29)
# ('id&ntc=3', 29)
# ('5447', 29)
# ('0479', 29)
# ('co&nombre=', 29)
# ('as%2C+13', 29)
# ('4732', 29)
# ('K&direccion=C%2F+', 29)
# ('ndera', 29)
# ('80&provincia=C%E1ceres&ntc=60', 29)
# ('4260', 29)
# ('192&provincia=', 29)
# ('ia=Madrid&ntc=0', 29)
# ('4331', 29)
# ('ad=10&B1=A%F1adir+al+carrito HTTP/1.1', 29)
# ('lina&apellidos=', 29)
# ('564&B1=Registrar HTTP/1.1', 29)
# ('nda&apellidos=C', 29)
# ('enia', 29)
# ('+35+', 29)
# ('cia&apellidos=M', 29)
# ('avente', 29)
# ('te%40s', 29)
# ('9499', 29)
# ('arros&cp=34', 29)
# ('anca&ntc=2', 29)
# ('in=te', 29)
# ('d=90', 29)
# ('os=Val', 29)
# ('n%40al', 29)
# ('ia=Albacete&ntc=3', 29)
# ('63&B1=Registrar HTTP/1.1', 29)
# ('orme', 29)
# ('ra.c', 29)
# ('Gand', 29)
# ('60&provincia=Burgos&ntc=7', 29)
# ('os=Ge', 29)
# ('.ro&dni=4', 29)
# ('4993', 29)
# ('5828', 29)
# ('eda&apellidos=C', 29)
# ('zales+', 29)
# ('%40evelin.', 29)
# ('5N&direccion=', 29)
# ('60&provincia=C', 29)
# ('l&ntc=1', 29)
# ('32385', 29)
# ('ad=9&B1=A%F1adir+al+carrito HTTP/1.1', 29)
# ('in=char', 29)
# ('isse', 29)
# ('iana&apellidos=M', 29)
# ('3Q&direccion=C%2F+', 29)
# ('antic', 29)
# ('o&cp=191', 29)
# ('9&provincia=Guadalajara&ntc=9', 29)
# ('erri&email=', 29)
# ('u&dni=9', 29)
# ('la&ntc=870', 29)
# ('479&B1=Registrar HTTP/1.1', 29)
# ('r%F3n&', 29)
# ('4208', 29)
# ('acel', 29)
# ('evilla&ntc=7', 29)
# ('andy', 29)
# ('orrey', 29)
# ('l&dni=02', 29)
# ('l&cp=45', 29)
# ('8&provincia=Guadalajara&ntc=3', 29)
# ('0768', 29)
# ('nca&ntc=6', 29)
# ('0&nombre=Vi', 29)
# ('a%40f', 29)
# ('carta', 29)
# ('a&cp=45', 29)
# ('74&B1=Pasar+por+caja HTTP/1.1', 29)
# ('alli', 29)

# %%
print(len(arr))
# Out:
# 2035
