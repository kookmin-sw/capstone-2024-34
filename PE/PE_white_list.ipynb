# %%
# import module

import pickle
import os
from tqdm import tqdm

from GIPS.core.feature_extractor import extract_string
from GIPS.core.MV2 import MV2
from GIPS.core.JIG import JIG
from GIPS.core.SG2 import SG2 
from GIPS.core.AWL import AWL

# %%
# preprocessing

with open('./datasets/pkl/benign_md5.pkl', 'rb') as f:
    benign_list = pickle.load(f)
    
benign_list[: 10]
# Out:
# ['74db80ed2730af4c13f906940ce3cbb0',
#  'f921fa214cdd02fb064f977ea1389e42',
#  'e1058f3fcb36755feb9b6c098e3954f0',
#  'ddefdbb3e88d0ce0a623f92bdb69b020',
#  'ad8b3fa73ea964a6c17cb0c0d6029c50',
#  '9be6386206be19c741aeae34b1af8c90',
#  '70f58da1960e7311101d92973008b1e0',
#  '1abdf6bfbc01a93e775ba1c0b409e7e2',
#  'cfa80ad59abfcaa79b7e9a76d1fc2625',
#  'eb089d184db2d1da31e4e29503ae0bc0']

# %%
# benign pe file path

benign_path = "./datasets/ben/"

# %%
benign_strings = []

for path in tqdm(benign_list):
    res = extract_string(os.path.join(benign_path, path))
    benign_strings.append(res)
    
benign_strings[: 10][: 5]
# Out:
# 100%|██████████| 29909/29909 [09:02<00:00, 55.17it/s]
# [{'                          ',
#   "        <requestedExecutionLevel level='asInvoker' uiAccess='false' />",
#   '      </requestedPrivileges>',
#   '      <requestedPrivileges>',
#   '    </security>',
#   '    <security>',
#   '  </trustInfo>',
#   '  <trustInfo xmlns="urn:schemas-microsoft-com:asm.v3">',
#   ' !"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`ABCDEFGHIJKLMNOPQRSTUVWXYZ{|}~',
#   ' !"#$%&\'()*+,-./0123456789:;<=>?@abcdefghijklmnopqrstuvwxyz[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~',
#   ' A_A^A\\',
#   ' A_A^A\\_^',
#   ' A_A^A]A\\_',
#   ' A_A^_',
#   " Base Class Array'",
#   ' Base Class Descriptor at (',
#   " Class Hierarchy Descriptor'",
#   " Complete Object Locator'",
#   ' H3E H3E',
#   " Type Descriptor'",
#   ' delete',
#   ' delete[]',
#   ' new[]',
#   ' t38S<u',
#   '!,X< w',
#   '!This program cannot be run in DOS mode.',
#   '"e?<<<<<<l?',
#   '%GoU?*',
#   '&?PPPPPPP?',
#   "'D8l$@",
#   '(DigiCert SHA2 Assured ID Code Signing CA',
#   '(DigiCert SHA2 Assured ID Code Signing CA0',
#   '(DigiCert SHA2 Assured ID Timestamping CA',
#   '(DigiCert SHA2 Assured ID Timestamping CA0',
#   '(T?j?Y',
#   '(null)',
#   ')>6{1n',
#   ')t$0fE',
#   ')|$ fE',
#   ')|B?d!',
#   '*StO9>T',
#   "+f)>0'",
#   ',http://crl3.digicert.com/sha2-assured-ts.crl02',
#   ',http://crl4.digicert.com/sha2-assured-ts.crl0',
#   '.00cfg',
#   '.>PJ;I:qE>',
#   '.?AUIAtlMemMgr@ATL@@',
#   '.?AUIAtlStringMgr@ATL@@',
#   '.?AVCAtlException@ATL@@',
#   '.?AVCAtlStringMgr@ATL@@',
#   '.?AVCWin32Heap@ATL@@',
#   '.?AVbad_alloc@std@@',
#   '.?AVbad_array_new_length@std@@',
#   '.?AVbad_exception@std@@',
#   '.?AVexception@std@@',
#   '.?AVtype_info@@',
#   '.CRT$XCA',
#   '.CRT$XCL',
#   '.CRT$XCU',
#   '.CRT$XCZ',
#   '.CRT$XIA',
#   '.CRT$XIC',
#   '.CRT$XIZ',
#   '.CRT$XLA',
#   '.CRT$XLZ',
#   '.CRT$XPA',
#   '.CRT$XPX',
#   '.CRT$XPXA',
#   '.CRT$XPZ',
#   '.CRT$XTA',
#   '.CRT$XTZ',
#   '.data$r',
#   '.edata',
#   '.gfids',
#   '.gfids$x',
#   '.gfids$y',
#   '.i?0@I',
#   '.idata$2',
#   '.idata$3',
#   '.idata$4',
#   '.idata$5',
#   '.idata$6',
#   '.pdata',
#   '.rdata',
#   '.rdata$T',
#   '.rdata$r',
#   '.rdata$zzzdbg',
#   '.rsrc$01',
#   '.rsrc$02',
#   '.rtc$IAA',
#   '.rtc$IZZ',
#   '.rtc$TAA',
#   '.rtc$TZZ',
#   '.text$di',
#   '.text$mn',
#   '.text$mn$00',
#   '.text$x',
#   '.text$yd',
#   '.tls$ZZZ',
#   '.xJ>Hf',
#   '.xdata',
#   '.xdata$x',
#   '/2GG>!B',
#   '/>58d%',
#   '/http://crl3.digicert.com/sha2-assured-cs-g1.crl05',
#   '/http://crl4.digicert.com/sha2-assured-cs-g1.crl0L',
#   '0><[cZUg^>',
#   '0A_A^A\\',
#   '0A_A^A\\_^',
#   '0A_A^A]',
#   '0A_A^A]A\\_',
#   '0A_A^A]A\\_^[',
#   '0A_A^A]A\\_^]',
#   '0A_A^_',
#   '0A_A^_^]',
#   '0X8b?~',
#   '1#QNAN',
#   '1#SNAN',
#   '131022120000Z',
#   '160107120000Z',
#   '190225000000Z',
#   '191001000000Z',
#   '200907120904Z0+',
#   '20200907120904Z',
#   '220216120000Z0R1',
#   '281022120000Z0r1',
#   '301017000000Z0L1',
#   '310107120000Z0r1',
#   '3>N;kU',
#   '3Dconnexion SAM0',
#   '3Dconnexion SAM1',
#   '4http://crl3.digicert.com/DigiCertAssuredIDRootCA.crl0O',
#   '4http://crl3.digicert.com/DigiCertAssuredIDRootCA.crl0P',
#   '4http://crl4.digicert.com/DigiCertAssuredIDRootCA.crl0:',
#   '7http://cacerts.digicert.com/DigiCertAssuredIDRootCA.crt0',
#   '8Q<u;H',
#   '8aMbF$',
#   '93u,9s',
#   ":>t6k'",
#   ';H9>&X',
#   ';^Xu&H',
#   '</assembly>',
#   "<?xml version='1.0' encoding='UTF-8' standalone='yes'?>",
#   "<assembly xmlns='urn:schemas-microsoft-com:asm.v1' manifestVersion='1.0'>",
#   '<htr<jtb<lt6<tt&<wt',
#   '=imb;D',
#   '>jtm}S',
#   '?)tuf97tf',
#   '?7zQ6$',
#   '?UUUUUU',
#   '@.data',
#   '@.reloc',
#   '@.rsrc',
#   '@8l$8t',
#   '@8q<u;H',
#   '@8s%t(',
#   '@8|$PtE',
#   '@8|$PtG',
#   '@8|$^t',
#   '@A_A^A]A\\_',
#   '@A_A^_',
#   '@HcC(H',
#   '@SUVWATAVAWH',
#   '@SVWATAUAVAWH',
#   '@UATAUAVAWH',
#   '@UATAVH',
#   '@UAVAWH',
#   '@USVWATAUAVAWH',
#   '@UVWAVAW',
#   '@UVWAVAWH',
#   '@VWATAVAWH',
#   '@b;zO]',
#   'A03>A|',
#   'A81t@@8r',
#   'A86taH',
#   'ABCDEFGHIJKLMNOPQRSTUVWXYZ',
#   'ADVAPI32.dll',
#   'AUAVAWH',
#   'A^_^[]',
#   'A_A^A\\',
#   'A_A^A\\_]',
#   'A_A^A\\_^',
#   'A_A^A\\_^][',
#   'A_A^A]A\\]',
#   'A_A^A]A\\_',
#   'A_A^A]A\\_^[]',
#   'A_A^A]A\\_^]',
#   'A_A^_^]',
#   'August',
#   'B(I9A(',
#   'BC?>6t9^',
#   'Bhttp://cacerts.digicert.com/DigiCertSHA2AssuredIDCodeSigningCA.crt0',
#   'C:\\Users\\jenkins\\home\\workspace\\3DxWinCore-branches-17-7-0\\driver\\dll\\mwmtrans\\bin\\win64x64\\release\\mwmtrans.pdb',
#   'CA< t(<#t',
#   'CWD>~3',
#   'ChangeWindowMessageFilter',
#   'Chttp://cacerts.digicert.com/DigiCertSHA2AssuredIDTimestampingCA.crt0',
#   'CloseHandle',
#   'CloseServiceHandle',
#   'CorExitProcess',
#   'CreateEventW',
#   'CreateFileW',
#   'CreateThread',
#   'CreateToolhelp32Snapshot',
#   'CreateWindowExW',
#   'D W?{W',
#   'D$0H;G',
#   'D$0HcH',
#   'D$8H9D$(v',
#   'D$8H;D$Hv',
#   'D$@H;G',
#   'D$XD8p',
#   'D$XD90}',
#   'D82u&H',
#   'D8d$Ht',
#   'D8d$ht',
#   'D8d$pt',
#   'D8l$@t',
#   'D8l$ht',
#   'D8t$Ht',
#   'December',
#   'DefWindowProcW',
#   'DeleteCriticalSection',
#   'DigiCert Assured ID Root CA0',
#   'DigiCert Inc1',
#   'DigiCert, Inc.1$0"',
#   'EncodePointer',
#   'EnterCriticalSection',
#   'EnumProcessModules',
#   'ExitProcess',
#   'F>qUxv',
#   'February',
#   'FindClose',
#   'FindFirstFileExA',
#   'FindNextFileA',
#   'FindResourceExW',
#   'FindResourceW',
#   'FlsAlloc',
#   'FlsFree',
#   'FlsGetValue',
#   'FlsSetValue',
#   'FlushFileBuffers',
#   'FormatMessageW',
#   'FreeEnvironmentStringsW',
#   'FreeLibrary',
#   'Friday',
#   'GetACP',
#   'GetAsyncKeyState',
#   'GetCPInfo',
#   'GetCommandLineA',
#   'GetCommandLineW',
#   'GetConsoleCP',
#   'GetConsoleMode',
#   'GetCurrentPackageId',
#   'GetCurrentProcess',
#   'GetCurrentProcessId',
#   'GetCurrentThreadId',
#   'GetEnvironmentStringsW',
#   'GetExitCodeThread',
#   'GetFileType',
#   'GetLastError',
#   'GetLogicalDrives',
#   'GetModuleBaseNameW',
#   'GetModuleFileNameA',
#   'GetModuleHandleExW',
#   'GetModuleHandleW',
#   'GetOEMCP',
#   'GetProcAddress',
#   'GetProcessHeap',
#   'GetProcessImageFileNameW',
#   'GetStartupInfoW',
#   'GetStdHandle',
#   'GetStringTypeW',
#   'GetSystemTimeAsFileTime',
#   'GetUserNameA',
#   'GetWindowTextW',
#   'GetWindowThreadProcessId',
#   'H!D$ E',
#   'H!T$0D',
#   'H;xXu9',
#   'HA_A]A\\_^[',
#   'HH:mm:ss',
#   'H[><y5',
#   'HeapAlloc',
#   'HeapDestroy',
#   'HeapFree',
#   'HeapReAlloc',
#   'HeapSize',
#   'I9}(t9H',
#   'I_RpcGetBuffer',
#   'Il?333333c?',
#   'InSendMessageEx',
#   'InitializeConditionVariable',
#   'InitializeCriticalSectionAndSpinCount',
#   'InitializeCriticalSectionEx',
#   'InitializeSListHead',
#   'InterlockedFlushSList',
#   'IsDebuggerPresent',
#   'IsProcessorFeaturePresent',
#   'IsValidCodePage',
#   'IsWindow',
#   'J/nz<cn7',
#   'January',
#   'K&>.yC',
#   'KERNEL32.dll',
#   'K~Je#>!',
#   'L!|$(L!',
#   'L$ SUVWH',
#   'L$ SVWH',
#   'L$ WATAUAVAWH',
#   'L$&@8t$&t0@8q',
#   'L$0H;K',
#   'L$D;L$T',
#   'L$P+L$8',
#   'L$P+L$H',
#   "L9&u'H",
#   'L9`8tA',
#   'L?UUUUUUU?',
#   'LCMapStringEx',
#   'LCMapStringW',
#   'LHcL$PH',
#   'LcA<E3',
#   'LeaveCriticalSection',
#   'LoadCursorW',
#   'LoadLibraryExW',
#   'LoadResource',
#   'LocaleNameToLCID',
#   'LockResource',
#   'MM/dd/yy',
#   'MWMTRANS.dll',
#   'Magellan3DController',
#   'Monaco1',
#   'Monday',
#   'MultiByteToWideChar',
#   'N>O=I9',
#   'NAN(IND)',
#   'NAN(SNAN)',
#   'NdrConvert',
#   'NdrFixedArrayMarshall',
#   'NdrServerInitializeNew',
#   'November',
#   'October',
#   'OpenProcess',
#   'OpenSCManagerW',
#   'OpenServiceW',
#   'OutputDebugStringW',
#   'P>q_Y~',
#   'PSAPI.DLL',
#   'PathStripPathW',
#   'PostMessageW',
#   'Process32FirstW',
#   'Process32NextW',
#   'ProcessIdToSessionId',
#   'Q5rHg,>',
#   'QueryDosDeviceW',
#   'QueryPerformanceCounter',
#   'QueryServiceStatus',
#   'RPCRT4.dll',
#   'RaiseException',
#   'RegisterClassW',
#   'RegisterWindowMessageW',
#   'ReplyMessage',
#   'ResetEvent',
#   'RpcRaiseException',
#   'RpcServerListen',
#   'RpcServerRegisterIf',
#   'RpcServerUseProtseqEpW',
#   'RtlCaptureContext',
#   'RtlLookupFunctionEntry',
#   'RtlPcToFileHeader',
#   'RtlUnwindEx',
#   'RtlVirtualUnwind',
#   'S,, <Zw',
#   'S>$hkDh$h>[2',
#   'SHLWAPI.dll',
#   'SVWATAUAVAWH',
#   'SVWATAUAWH',
#   'Saturday',
#   'SendMessageW',
#   'September',
#   'SetEvent',
#   'SetFilePointerEx',
#   'SetLastError',
#   'SetStdHandle',
#   'SetUnhandledExceptionFilter',
#   'SetWindowLongPtrW',
#   'SizeofResource',
#   'SleepConditionVariableCS',
#   'StartServiceW',
#   'Sunday',
#   'TIMESTAMP-SHA256-2019-10-150',
#   'TerminateProcess',
#   'TerminateThread',
#   'Thursday',
#   'TlsAlloc',
#   'TlsFree',
#   'TlsGetValue',
#   'TlsSetValue',
#   'Tuesday',
#   'U9|$(t',
#   'UA>N0Wl',
#   'UATAUAVAWH',
#   'UAVAWH',
#   'USER32.dll',
#   'USVWATAUAVAWH',
#   'USVWAVH',
#   'UUUUUU',
#   'UVWATAUAVAWH',
#   'UVWAVAWH',
#   'UWATAVAWH',
#   'UdTransCloseHdl',
#   'UdTransFlush',
#   'UdTransGetInfo',
#   'UdTransInit',
#   'UdTransIsValidHdl',
#   'UdTransSendEvent',
#   'UdTransSendSync',
#   'UdTransServiceRequest',
#   'UdTransTerm',
#   'UnhandledExceptionFilter',
#   'Unknown exception',
#   'V3"/"6',
#   'V6E>`"(5',
#   'VWATAVAW',
#   'VWATAVAWH',
#   'WATAUAVAWH',
#   'WAVAWH',
#   'WD8l$@t',
#   'WTSGetActiveConsoleSessionId',
#   'WaitForSingleObjectEx',
#   'WakeAllConditionVariable',
#   'Wednesday',
#   'WideCharToMultiByte',
#   'WriteConsoleW',
#   'WriteFile',
#   'Y>kX>M',
#   'YBDwC9',
#   'Zod(^?',
#   '[*ncd>0',
#   '[aOni*{',
#   '\\$ UVWATAUAVAWH',
#   '\\$ UVWAVAWH',
#   '\\$@@8=%',
#   '\\$xHc{',
#   '])6M>&',
#   '__based(',
#   '__cdecl',
#   '__clrcall',
#   '__eabi',
#   '__fastcall',
#   '__pascal',
#   '__ptr64',
#   '__restrict',
#   '__stdcall',
#   '__thiscall',
#   '__unaligned',
#   '__vectorcall',
#   '_oD>Kg',
#   '`.rdata',
#   '`A_A^A]A\\_^]',
#   '`A_A^_^]',
#   "`copy constructor closure'",
#   "`default constructor closure'",
#   "`dynamic atexit destructor for '",
#   "`dynamic initializer for '",
#   "`eh vector constructor iterator'",
#   "`eh vector copy constructor iterator'",
#   "`eh vector destructor iterator'",
#   "`eh vector vbase constructor iterator'",
#   "`eh vector vbase copy constructor iterator'",
#   '`h````',
#   '`h`hhh',
#   "`local static guard'",
#   "`local static thread guard'",
#   "`local vftable constructor closure'",
#   "`local vftable'",
#   "`managed vector constructor iterator'",
#   "`managed vector copy constructor iterator'",
#   "`managed vector destructor iterator'",
#   "`omni callsig'",
#   "`placement delete closure'",
#   "`placement delete[] closure'",
#   "`scalar deleting destructor'",
#   "`string'",
#   "`typeof'",
#   "`udt returning'",
#   "`vbase destructor'",
#   "`vbtable'",
#   "`vcall'",
#   "`vector constructor iterator'",
#   "`vector copy constructor iterator'",
#   "`vector deleting destructor'",
#   "`vector destructor iterator'",
#   "`vector vbase constructor iterator'",
#   "`vector vbase copy constructor iterator'",
#   "`vftable'",
#   "`virtual displacement map'",
#   'abcdefghijklmnopqrstuvwxyz',
#   'bad allocation',
#   'bad array new length',
#   'bad exception',
#   'bp(=>?g',
#   "c [1>H'",
#   'c?FA@s}',
#   'd?000000`?',
#   'dddd, MMMM dd, yyyy',
#   'e0A_A^A]A\\]',
#   'f;S8tDH;C',
#   'f;\\$(r',
#   'f;\\$0r',
#   'f;\\$Tr',
#   'f;\\$ds',
#   'f;\\$ps',
#   'f;\\$ts',
#   'fA;0t)fA98t',
#   'fA;8utI',
#   'fD94Fu',
#   'fD9<Bu',
#   'fD9<Zu',
#   'fD9t$b',
#   'ffffff',
#   'fffffff',
#   "fnVa')",
#   'gfffffffH',
#   'gz8wT@',
#   'hA_A^A]A\\_^[]',
#   'http://ocsp.digicert.com0C',
#   'http://ocsp.digicert.com0N',
#   'http://ocsp.digicert.com0O',
#   'http://www.3dconnexion.com/ 0',
#   'https://www.digicert.com/CPS0',
#   'iMy?|k',
#   'j>>A?1',
#   'kE>fvw',
#   'l$ VWATAVAWH',
#   'l$ WAVAWH',
#   'n03>Pu',
#   'nan(ind)',
#   'nan(snan)',
#   'ncalrpc',
#   'operator',
#   'operator "" ',
#   'p1f3q>',
#   'pA_A^A]A\\_^[',
#   'pA_A^A]A\\_^]',
#   'qS>g?h3',
#   'r 9_ t',
#   'r#f;\\$\\s',
#   'r#f;\\$hs',
#   'r&f;\\$\\s',
#   'r*f;\\$hs#',
#   'r7f;\\$L',
#   'r7f;\\$X',
#   'r:f;\\$L',
#   'r>f;\\$X',
#   'rKf;\\$<',
#   'rKf;\\$H',
#   'rNf;\\$<',
#   'rRf;\\$H',
#   'r_f;\\$,',
#   'r_f;\\$8',
#   'rbf;\\$,',
#   'restrict(',
#   'rff;\\$8',
#   'ri9V vdH',
#   'rsf;\\$ ',
#   'rsf;\\$(',
#   'rvf;\\$ ',
#   'rzf;\\$(',
#   's4+sP+',
#   't$ UWATAVAWH',
#   't$ WATAUAVAWH',
#   't$ WAVAWH',
#   't)D8l$@t',
#   't@@8{<t',
#   'tB@8{<t',
#   'u3HcH<H',
#   'uf!T$(H!T$ ',
#   'uzKs@>',
#   'v2!L.2',
#   'www.digicert.com1$0"',
#   'www.digicert.com110/',
#   'x ATAVAWH',
#   'xpxxxx',
#   'xwpwpp',
#   'y0f98u',
#   'y\\PD>!',
#   'zY;>u:m',
#   '|$ ATAVAWH',
#   '|$ AVH',
#   '|$ UATAUAVAWH',
#   '|b=})>',
#   '~ $s%r'},
#  {'runtime/internal/sys.GoosNetbsd',
#   'golang.org/x/sys/windows.UTC_E_API_RESULT_UNAVAILABLE',
#   'golang.org/x/sys/windows.HTTP_E_STATUS_GATEWAY_TIMEOUT',
#   '!*internal/reflectlite.sliceHeader',
#   '~y{zzz',
#   'IID_IEnumMoniker',
#   'golang.org/x/sys/windows.SPAPI_E_DEVINST_ALREADY_EXISTS',
#   'modSqrt3Mod4Prime',
#   'regexp/syntax/prog.go',
#   'runtime.call64',
#   'golang.org/x/sys/windows.OSS_MORE_BUF',
#   'runtime/sys_windows_amd64.s',
#   'syscall.SW_SHOW',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.NetIfAdminStatusTesting',
#   'golang.org/x/sys/windows.ERROR_DS_EXISTS_IN_POSS_SUP',
#   'golang.org/x/sys/windows.E_ELEVATED_ACTIVATION_NOT_SUPPORTED',
#   '.idata$60',
#   'LoadLibrH',
#   'runtime/internal/sys.deBruijn64tab',
#   'golang.org/x/text@v0.3.2/encoding/internal/identifier/identifier.go',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Device).Down',
#   'runtime.extram',
#   'regexp/syntax.(*compiler).plus',
#   'golang.org/x/sys/windows.ERROR_IPSEC_IKE_UNSUPPORTED_ID',
#   'golang.org/x/sys/windows.ERROR_IPSEC_IKE_PROCESS_ERR_CERT',
#   'reflect.Value.Index',
#   '[2]*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.trieEntry',
#   'runtime.addOneOpenDeferFrame.func1',
#   '*crypto/hmac.hmac',
#   '%reflect.funcTypeFixed64',
#   'unicode..stmp_52',
#   'runtime/internal/sys/stubs.go',
#   'golang.org/x/sys/windows.ERROR_EXE_MACHINE_TYPE_MISMATCH',
#   ',<08<><01',
#   'noalg.map.iter[[16]uint8]*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/ratelimiter.RatelimiterEntry',
#   'stdlib.h',
#   'reflect.(*funcTypeFixed4).Field',
#   'golang.org/x/sys/windows._LoadLibraryEx',
#   'unicode..stmp_595',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.IfTypeOpticalChannel',
#   'golang.org/x/sys/windows.HKEY_CURRENT_USER',
#   'CLSID_AggStdMarshal',
#   '&syscall.RawSockaddrUnix',
#   'golang.org/x/sys/windows.HCS_E_INVALID_JSON',
#   '__do_global_ctors',
#   'golang.org/x/sys/windows.NAP_E_MISMATCHED_ID',
#   '*func() (string, error)',
#   '&noalg.struct { bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.siz uint32; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.started bool; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.heap bool; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.openDefer bool; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.sp uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.pc uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.fn uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device._panic uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.link uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.framepc uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.varp uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.fd uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.args [8]uint8 }',
#   '[100]uint8',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.IfTypePlc',
#   'runtime.maxSearchAddr',
#   'insertb',
#   'runtime.(*hmap).oldbucketmask',
#   'hchan<time.Time>',
#   'golang.org/x/sys/windows.RPC_S_UUID_NO_ADDRESS',
#   'unicode..stmp_574',
#   'reflect.(*funcTypeFixed64).ConvertibleTo',
#   'math/big/arith.go',
#   'golang.org/x/sys/windows.DXGI_STATUS_DDA_WAS_STILL_DRAWING',
#   '0*struct { F uintptr; src uintptr; dst *uintptr }',
#   'internal/syscall/windows.MOVEFILE_CREATE_HARDLINK',
#   '280128120000Z0L1 0',
#   'golang.org/x/net/internal/socket.sizeofSockaddrInet6',
#   'syscall.ERROR_HANDLE_EOF',
#   'reflect.(*funcTypeFixed32).NumIn',
#   'time.unitMap',
#   '([^_]A\\A]',
#   'golang.org/x/sys/windows.ERROR_VOLMGR_VOLUME_ID_INVALID',
#   'golang.org/x/sys/windows.DNS_ERROR_NOT_ALLOWED_ON_ZSK',
#   'unicode.Other_Lowercase',
#   '*[67]uint8',
#   '!*runtime.traceStackTable',
#   'context.Context',
#   'encoding/binary.(*encoder).value',
#   'syscall.CTRL_BREAK_EVENT',
#   '3*map.bucket[[16]uint8]*ratelimiter.RatelimiterEntry',
#   'element',
#   'runtime.gcPaceScavenger',
#   'runtime.moduledataverify1',
#   '__ImageBase',
#   '%noalg.struct { F uintptr; os/exec.w io.Writer; os/exec.pr *os.File }',
#   '*sudog<bool>',
#   'zeroKeyMaterial',
#   '**runtime.hchan',
#   'runtime.goyield_m',
#   'NonceSize',
#   '=>?@ABCD?EFG',
#   '!IID_IDummyHICONIncluder',
#   'S0H+S(H',
#   'golang.org/x/sys/windows.ERROR_SXS_PROTECTION_RECOVERY_FAILED',
#   '_defer',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi.DICS_START',
#   'PIMAGE_IMPORT_DESCRIPTOR',
#   'type..eq.io.LimitedReader',
#   'net.onlyValuesCtx.Deadline',
#   'golang.org/x/sys/windows.ERROR_VOLMGR_STRUCTURE_SIZE_INVALID',
#   '*[]ipv6.ICMPType',
#   '*func(time.Time) error',
#   'context.init.0',
#   'golang.org/x/crypto/blake2s.marshaledSize',
#   'retries',
#   'golang.org/x/sys/windows.COMADMIN_E_USER_IN_SET',
#   'golang.org/x/sys/windows.WINCODEC_ERR_STREAMREAD',
#   'golang.org/x/sys/windows.RPC_S_INVALID_STRING_UUID',
#   '!http://ocsp.globalsign.com/rootr103',
#   'internal/syscall/execenv.Default',
#   'runtime.efaceOf',
#   '!*golang.org/x/sys/windows.Tokenprivileges',
#   'net.SplitHostPort',
#   'runtime.(*gcWork).balance',
#   'runtime.preprintpanics',
#   'runtime.mstart1',
#   'reflect.tflag',
#   'setMulticastIf',
#   'golang.org/x/crypto/chacha20poly1305.init',
#   'allocAll',
#   '!GUID_VIDEO_ANNOYANCE_TIMEOUT',
#   'golang.org/x/sys/windows.ERROR_BAD_DEVICE_PATH',
#   'unicode..stmp_339',
#   '!*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.IndexTable',
#   'sync/atomic.StoreUintptr.args_stackmap',
#   'lastSentHandshake',
#   'runtime.semrelease1',
#   'os.errWriteAtInAppendMode',
#   'golang.org/x/sys/windows.ERROR_INVALID_PRIMARY_GROUP',
#   'golang.org/x/net/ipv4.ICMPTypeExtendedEchoRequest',
#   'golang.org/x/sys/windows.ERROR_INVALID_HANDLE_STATE',
#   'internal/poll.(*FD).Read.func1',
#   '!*runtime.funcval',
#   'golang.org/x/sys/windows.SPAPI_E_INCORRECTLY_COPIED_INF',
#   'golang.org/x/net/bpf.ExtNetlinkAttrNested',
#   'unicode..stmp_71',
#   'golang.org/x/sys/windows.SidTypeInvalid',
#   'type..eq.os.PathError',
#   'utilization',
#   'type..eq.os.ProcessState',
#   'ensureSwept',
#   'regexp/syntax.ErrorCode',
#   '*bucket<golang.org/x/text/encoding/unicode.Endianness,[9]golang.org/x/text/encoding/internal/identifier.MIB>',
#   'goroutine running on other thread; stack unavailable',
#   '**struct { F uintptr; ps []unsafe.Pointer }',
#   'golang.org/x/sys/windows.COMADMIN_E_CAT_PARTITION_IN_USE',
#   'golang.org/x/sys/windows.ERROR_PROFILE_DOES_NOT_MATCH_DEVICE',
#   'golang.org/x/sys/windows.TBSIMP_E_INVALID_CONTEXT_HANDLE',
#   'newBytes',
#   '!IID_IRpcSyntaxNegotiate',
#   'Header',
#   'golang.org/x/sys/windows.FILE_MAP_EXECUTE',
#   '*[]context.canceler',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.ScopeLevel',
#   'golang.org/x/sys/windows.TPC_E_INVALID_DATA_FROM_RECOGNIZER',
#   '%noalg.map.iter[[4]uint8]*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/ratelimiter.RatelimiterEntry',
#   'golang.org/x/sys/windows.WPN_E_CALLBACK_ALREADY_REGISTERED',
#   'golang.org/x/sys/windows.CERT_STORE_PROV_SYSTEM',
#   'golang.org/x/sys/windows.WSA_QOS_POLICY_FAILURE',
#   'receivedKeypair',
#   '*hash<int,string>',
#   'width1',
#   'syscall.CERT_CHAIN_POLICY_AUTHENTICODE',
#   'returnlen',
#   'syscall.HKEY_LOCAL_MACHINE',
#   'golang.org/x/sys/windows.KEY_SET_VALUE',
#   'nsmallfree',
#   'golang.org/x/sys/windows.SERVICE_CONFIG_SERVICE_SID_INFO',
#   'type..eq.encoding/base64.Encoding',
#   'ErrorCode',
#   'preemptExtLock',
#   'go.itab.*bytes.Buffer,io.Writer',
#   'golang.org/x/sys/windows.E_SYNCENGINE_PROXY_AUTHENTICATION_REQUIRED',
#   'golang.org/x/sys/windows.ERROR_DS_MACHINE_ACCOUNT_CREATED_PRENT4',
#   'golang.org/x/sys/windows.SQLITE_E_READONLY_DBMOVED',
#   'syscall.makeInheritSa',
#   'internal/fmtsort.compare',
#   'syscall.SW_RESTORE',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.TunnelTypeDirect',
#   'runtime.(*mheap).freeSpanLocked',
#   'GetThreadContext',
#   'internetAddrList',
#   'golang.org/x/text/encoding.Encoder.Reset',
#   '%noalg.struct { F uintptr; runtime.c *runtime.mcache }',
#   'hash<int,*golang.org/x/net/ipv4.sockOpt>',
#   '!*runtime.overlappedEntry',
#   'golang.org/x/net/ipv6.ICMPTypeDuplicateAddressRequest',
#   'golang.org/x/sys/windows.FVE_E_PROTECTOR_CHANGE_MAX_PIN_CHANGE_ATTEMPTS_REACHED',
#   'golang.org/x/sys/windows.SCARD_E_CERTIFICATE_UNAVAILABLE',
#   'math/big/decimal.go',
#   '*reflectlite.tflag',
#   'syscall.OpenProcess',
#   'golang.org/x/sys/windows.UTC_E_REESCALATED_TOO_QUICKLY',
#   'mutexName',
#   'VectorControl',
#   'strings.(*Builder).WriteByte',
#   'time.daysIn',
#   'math/big.maxPow',
#   'golang.org/x/sys/windows.ERROR_NESTING_NOT_ALLOWED',
#   'golang.org/x/net/bpf.JumpGreaterThan',
#   'runtime.useAVXmemmove',
#   '&runtime.gcBitsArena',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device..stmp_64',
#   'golang.org/x/sys/windows.AF_UNIX',
#   '&func(*uint16) error',
#   'strconv.appendQuotedRuneWith',
#   'waitq<bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.PeerConnectionState>',
#   '*runtime.hchan',
#   'runtime.printOneCgoTraceback',
#   'regexp/syntax.OpPlus',
#   'time.stdPM',
#   'runtime.semtable',
#   'time.daysBefore',
#   '%syscall.ByHandleFileInformation',
#   'golang.org/x/sys/windows.DXGI_ERROR_SESSION_DISCONNECTED',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*trieEntry).lookup',
#   'runtime.mSpanManual',
#   'sync.poolLocalInternal',
#   'golang.org/x/sys/windows.MSSIPOTF_E_TABLE_LONGWORD',
#   'golang.org/x/sys/windows.DNS_TYPE_KEY',
#   'insertNew',
#   'golang.org/x/sys/windows.WPN_E_NOTIFICATION_HIDDEN',
#   '*reflectlite.sliceHeader',
#   'golang.org/x/sys/windows.RO_E_EXCLUSIVE_WRITE',
#   'golang.org/x/net/ipv6.ssoTrafficClass',
#   'subkey',
#   'runtime.tmpBuf',
#   'runtime.memhash64Fallback',
#   'time.resetTimer',
#   'BBBBBBBBBBBBBBBB',
#   '**runtime.heapArena',
#   'net.appendHex',
#   'needArgMap',
#   'time.absoluteToInternal',
#   'golang.org/x/sys/windows.ERROR_SERIAL_NO_DEVICE',
#   'reflect.Uint16',
#   'golang.org/x/sys/windows.WINCODEC_ERR_STREAMNOTAVAILABLE',
#   'internal/reflectlite..inittask',
#   '!IID_IInternetSecurityMgrSite',
#   'golang.org/x/sys/windows.TPM_E_EMBEDDED_COMMAND_BLOCKED',
#   'encoding/binary.(*bigEndian).PutUint16',
#   'golang.org/x/crypto/chacha20poly1305.(*chacha20poly1305).Seal',
#   'golang.org/x/sys/windows.NOT_USED_ACCESS',
#   'wwwwwwwwH',
#   '&strconv.decimal',
#   'golang.org/x/text/unicode/norm.Form.Bytes',
#   'localSize',
#   'golang.org/x/net/bpf.opJumpGT',
#   '&golang.org/x/sys/windows.LazyDLL',
#   'runtime.isPowerOfTwo',
#   'golang.org/x/sys/windows.ERROR_IS_SUBST_PATH',
#   '%reflect.sliceType',
#   'time.seekCurrent',
#   '_cgo_get_context_function',
#   'runtime.exitsyscallfast_reacquired.func1',
#   '*[]*norm.formInfo',
#   'golang.org/x/sys/windows.TF_DISCONNECT',
#   '[62]unicode.Range32',
#   'thandle',
#   'dotdot',
#   'golang.org/x/text/runes.(*replaceIllFormed).Span',
#   'golang.org/x/sys/windows.loadLibraryEx',
#   '%*winipcfg.InterfaceAndOperStatusFlags',
#   'net.(*Resolver).lookupIP.func1.stkobj',
#   'reflect.interfaceType',
#   '%runtime.functype',
#   'runtime._SetWaitableTimer',
#   'SetMode',
#   'golang.org/x/sys/windows.ERROR_INSTALL_FAILED',
#   '.refptr.__xi_z',
#   'golang.org/x/crypto/poly1305.macState',
#   '!*struct { runtime.size uint32; runtime.nmalloc uint64; runtime.nfree uint64 }',
#   'racectx',
#   'syscall.procGetComputerNameW',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/config.procInternetGetConnectedState',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Device).PopulatePools.func1',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.IfTypeXboxWireless',
#   '&noalg.struct { F uintptr; runtime.s *runtime.pageAlloc }',
#   'struct { internal/reflectlite.b bool; internal/reflectlite.x interface {} }',
#   'runtime.nan32',
#   '[1]golang.org/x/sys/windows.LUIDAndAttributes',
#   '%bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.MibIPforwardRow2',
#   'bytes.NewBuffer',
#   'golang.org/x/sys/windows.UTC_E_KERNELDUMP_LIMIT_REACHED',
#   '!*golang.org/x/sys/windows.Token',
#   'golang.org/x/net@v0.0.0-20200301022130-244492dfa37a/ipv6/endpoint.go',
#   'golang.org/x/sys/windows.KF_FLAG_CREATE',
#   '___crt_xt_start__',
#   'lpmaximumapplicationaddress',
#   'time.maxWall',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/config/dpapi.dpCRYPTPROTECT_VERIFY_PROTECTION',
#   'pathbuf',
#   'golang.org/x/sys/windows.E_MBN_SERVICE_NOT_ACTIVATED',
#   'golang.org/x/sys/windows.ERROR_NETNAME_DELETED',
#   'CLSID_StdGlobalInterfaceTable',
#   'isWildcard',
#   '<missing>_75',
#   '[]float64',
#   '__IAT_start__',
#   'internal/reflectlite.ValueError',
#   '&runtime.g',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.procNotifyRouteChange2',
#   '%internal/reflectlite.ptrType',
#   'sectionName',
#   'golang.org/x/sys/windows.TPM_20_E_ATTRIBUTES',
#   'golang.org/x/sys/windows.PAGE_READWRITE',
#   'aeshashbody',
#   'runtime._TracebackMaxFrames',
#   '!*sudog<struct {}>',
#   'runtime.fastrand',
#   'loaded',
#   'golang.org/x/sys/cpu.isSet',
#   '%runtime.sudog',
#   'golang.org/x/sys/windows.ERROR_INVALID_EDIT_HEIGHT',
#   'math/big.basicMul',
#   'bucket<int,*golang.org/x/net/ipv6.sockOpt>',
#   'tophash',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.initializeIPForwardEntry.stkobj',
#   'internal/reflectlite.haveIdenticalUnderlyingType.stkobj',
#   '<missing>_18',
#   'internal/reflectlite.unpackEface',
#   'reflect.(*funcTypeFixed128).Name',
#   '&func(int, int, int) (syscall.Handle, error)',
#   'golang.org/x/sys/windows.FACILITY_DEPLOYMENT_SERVICES_IMAGING',
#   '*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.AllowedIPs',
#   'golang.org/x/sys/windows.ERROR_DOMAIN_CONTROLLER_NOT_FOUND',
#   '!*vendor/golang.org/x/net/dns/dnsmessage.RCode',
#   'struct { bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.newKeypairArrived chan struct {}; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.flushNonceQueue chan struct {} }',
#   'golang.org/x/sys/windows.SCARD_E_NO_SUCH_CERTIFICATE',
#   'lastWriteTime',
#   'syscall.STARTF_USESTDHANDLES',
#   '!IID_IUriBuilder',
#   'golang.org/x/sys/windows.ERROR_EXTERNAL_BACKING_PROVIDER_UNKNOWN',
#   'runtime.(*gcWork).tryGetFast',
#   'syscall.KEY_EXECUTE',
#   'golang.org/x/sys/windows.CERT_E_UNTRUSTEDTESTROOT',
#   'internal/reflectlite.(*rtype).In',
#   'golang.org/x/sys/windows.ERROR_DS_NOTIFY_FILTER_TOO_COMPLEX',
#   '&noalg.struct { F uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel.sortedAllowedIPs []bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/config.IPCidr }',
#   'T Z ` f l r x ~ ',
#   'golang.org/x/sys/windows.CERT_REGISTRY_STORE_CLIENT_GPT_FLAG',
#   'golang.org/x/sys/windows.ERROR_CLOUD_FILE_CONNECTED_PROVIDER_ONLY',
#   '+VT_LPWSTR',
#   '.idata$6<',
#   '*[]*syntax.Regexp',
#   'golang.org/x/sys/windows.ERROR_GROUP_EXISTS',
#   'time.Weekday',
#   'syscall.STD_ERROR_HANDLE',
#   'golang.org/x/sys/windows.SHTDN_REASON_FLAG_USER_DEFINED',
#   'chan *bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.QueueOutboundElement',
#   'errcode',
#   '*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.IPCError',
#   'QuickSpan',
#   'golang.org/x/sys/windows.ERROR_APPINSTALLER_ACTIVATION_BLOCKED',
#   'runtime/internal/sys.m2',
#   'unicode..stmp_160',
#   'golang.org/x/sys/windows.ERROR_RM_DISCONNECTED',
#   'golang.org/x/sys/windows.CAT_E_FIRST',
#   'runtime.wbBufFlush.stkobj',
#   'golang.org/x/sys/windows.ERROR_FILE_SYSTEM_VIRTUALIZATION_UNAVAILABLE',
#   'math/tan.go',
#   'crypto/subtle.ConstantTimeByteEq',
#   'iflags',
#   '&runtime.gcWork',
#   'syscall.Syscall12',
#   'findfunctab',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Device).DeleteKeypair',
#   'strings.IndexByte',
#   '*runtime.itab',
#   'e_res2',
#   'runtime._TraceJumpStack',
#   '!IID_IBindStatusCallback',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi.SPDRP_ADDRESS',
#   'golang.org/x/sys/windows.WS_E_PROXY_FAILURE',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.IfTypeG703_2mb',
#   '&strings.Reader',
#   'golang.org/x/net/ipv6.ICMPTypeMulticastRouterAdvertisement',
#   'golang.org/x/sys/windows/registry.EXECUTE',
#   'AppendFormat',
#   'os/exec.(*closeOnce).Close',
#   'bitLen',
#   'golang.org/x/sys/windows.TF_WRITE_BEHIND',
#   'syscall.GetEnvironmentVariable.stkobj',
#   '!*hchan<error>',
#   '_Num_FPE',
#   'unicode..stmp_115',
#   'regexp/syntax.POSIX',
#   '.idata$4T',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/ratelimiter..inittask',
#   '!PPM_IDLE_ACCOUNTING_GUID',
#   'golang.org/x/sys/windows.CREATE_UNICODE_ENVIRONMENT',
#   'runtime/mstats.go',
#   'os/exec.closeOnce.Read',
#   'reflect.haveIdenticalUnderlyingType',
#   'unicode..stmp_206',
#   'golang.org/x/sys/windows.SERVICE_INACTIVE',
#   'sync.(*poolDequeue).unpack',
#   'golang.org/x/sys/windows.ERROR_VOLMGR_PLEX_NOT_SIMPLE',
#   'golang.org/x/sys/windows.STORE_ERROR_PENDING_COM_TRANSACTION',
#   '%hash<string,*unicode.RangeTable>',
#   'golang.org/x/sys/windows.FILE_APPEND_DATA',
#   '&bytes.asciiSet',
#   'golang.org/x/sys/windows.ERROR_INSTALL_FAILURE',
#   '!*hash<uint32,[]*runtime._type>',
#   'reflect.implements.stkobj',
#   'CreateThread',
#   'syscall.SetsockoptInt',
#   'type..eq.runtime.gcSweepBuf',
#   '**struct { addr *uint16; len int; cap int }',
#   'context.goroutines',
#   '*norm.valueRange',
#   'reflect.(*funcTypeFixed16).Elem',
#   '!*runtime.specialprofile',
#   '[0]int',
#   'regexp/syntax..stmp_24',
#   'golang.org/x/sys/windows.ERROR_TOO_MANY_OPEN_FILES',
#   'a.VV881',
#   'type..eq.bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.Interface',
#   'BitLen',
#   'regexp/syntax.nextRune',
#   'sort.Slice',
#   'reflect.(*funcTypeFixed8).Size',
#   'golang.org/x/sys/windows.FILE_SHARE_READ',
#   'golang.org/x/sys/windows.procGetTokenInformation',
#   'golang.org/x/sys/windows.ERROR_SXS_XML_E_BADPEREFINSUBSET',
#   'golang.org/x/sys/windows.procSetSecurityInfo',
#   'internal/reflectlite.name.pkgPath',
#   'stopping',
#   'syscall.IPV6_LEAVE_GROUP',
#   '%hash<*reflect.structType,int>',
#   'PowerRegH',
#   'golang.org/x/sys/windows.PEER_E_CONNECTION_FAILED',
#   'internal/reflectlite.(*rtype).chanDir',
#   '*runtime.Func',
#   '|$xH9;',
#   'golang.org/x/sys/windows.WTS_SESSION_REMOTE_CONTROL',
#   'd||||||',
#   '9*struct { F uintptr; h *runtime.mheap; s *runtime.mspan }',
#   'allocNeedsZero',
#   'runtime.getproccount',
#   'syscall.FILE_MAP_READ',
#   'golang.org/x/sys/windows.CONTEXT_E_FIRST',
#   'file descriptor in bad statefile has already been closedfindrunnable: netpoll with pgcstopm: negative nmspinninginvalid runtime symbol tablemheap.freeSpanLocked - span missing stack in shrinkstackmspan.sweep: m is not lockedmulticast router terminationnewproc1: new g is not Gdeadnewproc1: newg missing stackos: process already finishedprotocol driver not attachedreflect: In of non-func typeregion exceeds uintptr rangeruntime.semasleep unexpectedruntime: bad lfnode address runtime: casgstatus: oldval=runtime: no module data for runtime: stat overflow: val static shared secret is zerostrconv: ',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/config.naturalSortDigitFinder',
#   'golang.org/x/sys/windows.DNS_ERROR_SECONDARY_DATA',
#   'runtime.mheap_',
#   '%noalg.map.hdr[runtime._typePair]struct {}',
#   'regexp/syntax.(*parser).parseUnicodeClass',
#   'golang.org/x/sys/windows.ERROR_INSTALL_PACKAGE_NOT_FOUND',
#   '*tun.NativeTun',
#   '%]%d%H%H%O%y%r%',
#   '[64]*reflect.rtype',
#   '__imp_vfprintf',
#   'unicode..stmp_555',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.HandshakeInitiationConsumed',
#   'GetCurrentProcess',
#   '+*map[[4]uint8]*ratelimiter.RatelimiterEntry',
#   'golang.org/x/sys/windows.ERROR_TOO_MANY_POSTS',
#   'unicode..stmp_594',
#   '&func(interface {}) func(int, int)',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.RouteProtocolBgp',
#   'runtime.itabAdd.stkobj',
#   'golang.org/x/sys/windows.FVE_E_NO_EXISTING_PIN',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.NetIfAdminStatus',
#   '*[96]uint8',
#   'lpFileName',
#   'golang.org/x/sys/windows.SERVICE_FILE_SYSTEM_DRIVER',
#   'golang.org/x/sys/windows.MB_ICONEXCLAMATION',
#   '.idata$4L',
#   'golang.org/x/sys/windows.STORE_ERROR_LICENSE_REVOKED',
#   'reflect.flag.mustBeAssignable',
#   '&func(*runtime.p)',
#   'golang.org/x/sys/windows.ERROR_MRM_DUPLICATE_ENTRY',
#   'deviceDescVal',
#   'unicode.Meetei_Mayek',
#   '*[67]uint16',
#   'golang.org/x/sys/windows.ERROR_PARTIAL_COPY',
#   'objIndex',
#   'runtime.globrunqget',
#   'golang.org/x/crypto/blake2s.init.0',
#   'golang.org/x/sys/windows.TBS_E_INVALID_CONTEXT_PARAM',
#   ')GS_ExceptionRecord',
#   'internal/reflectlite.recvDir',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.IfTypeMioX25',
#   'os.(*File).write',
#   'MulticastAddrs',
#   'RecursionCount',
#   'golang.org/x/sys/windows.UTC_E_SQM_INIT_FAILED',
#   'dwprocessortype',
#   'golang.org/x/sys/windows.FILE_NOTIFY_CHANGE_SIZE',
#   'golang.org/x/sys/windows.COMADMIN_E_COMP_MOVE_SOURCE',
#   'sort.siftDown',
#   '*fmt.wrapError',
#   '*syscall.ProcessInformation',
#   'IID_IAuthenticateEx',
#   '*fmt.pp',
#   'golang.org/x/sys/windows.KF_FLAG_INIT',
#   'reflect.Uint8',
#   '*net.IP',
#   'sortedPeers',
#   'golang.org/x/sys/windows.TPM_20_E_NV_DEFINED',
#   'syscall.CryptAcquireContext',
#   '*runtime.blockRecord',
#   'golang.org/x/sys/windows.MSSIPOTF_E_FAILED_POLICY',
#   'doSlow',
#   'syscall.SockaddrInet6',
#   'golang.org/x/sys/windows.ERROR_WAIT_63',
#   'golang.org/x/sys/windows.DNS_TYPE_TSIG',
#   'golang.org/x/sys/windows.RPC_S_NO_ENDPOINT_FOUND',
#   'golang.org/x/sys/windows.MK_E_NEEDGENERIC',
#   'cleanstack',
#   '9*[67]struct { size uint32; nmalloc uint64; nfree uint64 }',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/config.splitList',
#   ',VARENUM',
#   '!*[3]interface {}',
#   '!IID_IOleLink',
#   'golang.org/x/sys/windows.ERROR_ARENA_TRASHED',
#   'runtime/mpagealloc.go',
#   'golang.org/x/sys/windows.SECURITY_CREATOR_OWNER_RID',
#   'golang.org/x/sys/windows.FVE_E_DE_PROTECTION_SUSPENDED',
#   'math/big.three',
#   'golang.org/x/sys/windows.ERROR_SERVICE_REQUEST_TIMEOUT',
#   'golang.org/x/sys/windows.ERROR_VHD_MISSING_CHANGE_TRACKING_INFORMATION',
#   '%noalg.map.iter[interface {}]*sync.entry',
#   '&runtime.traceAllocBlock',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/config.modadvapi32',
#   'net.UDPAddr',
#   '*[]*config.StoreCallback',
#   '&context.deadlineExceededError',
#   'golang.org/x/sys/windows.ERROR_TRANSACTION_NOT_FOUND',
#   "'*map[device.NoisePublicKey]*device.Peer",
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.GAAFlagIncludeAllCompartments',
#   'runtime.saveAncestors',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*nativeBind).ReceiveIPv4',
#   'golang.org/x/sys/windows.TPM_20_E_TAG',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.LogLevelSilent',
#   'Cookie',
#   '__end__',
#   'regexp.(*Regexp).doOnePass',
#   'setoverflow',
#   '%noalg.struct { bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.siz uint32; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.started bool; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.heap bool; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.openDefer bool; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.sp uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.pc uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.fn uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun._panic uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.link uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.framepc uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.varp uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.fd uintptr; bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.args [8]uint8 }',
#   '!*math/big.Word',
#   'unicode.caseOrbit',
#   'errors.New',
#   'SizeOfRawData',
#   'internal/nettrace',
#   'syscall.NetSetupUnknownStatus',
#   'ToWgQuickWithResolution',
#   'internal/syscall/windows/registry.Key',
#   'runtime/internal/sys.GoarchSparc64',
#   'syscall.FILE_ATTRIBUTE_SYSTEM',
#   '*runtime.evacDst',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.IfTypeFast',
#   'rusage',
#   'closeRead',
#   'golang.org/x/sys/windows.FVE_E_NO_TPM_WITH_PASSPHRASE',
#   'golang.org/x/sys/windows.CERTSRV_E_INVALID_EK',
#   'reflect..stmp_66',
#   'golang.org/x/sys/windows.SE_SELF_RELATIVE',
#   'golang.org/x/sys/windows.HCS_E_WINDOWS_INSIDER_REQUIRED',
#   'golang.org/x/sys/windows.ERROR_VOLMGR_EXTENT_NOT_CONTIGUOUS',
#   'runtime.interequal',
#   'golang.org/x/sys/windows.DXGI_ERROR_ALREADY_EXISTS',
#   'runtime.netpollWriteDeadline',
#   'math/rand.rngLen',
#   'golang.org/x/sys/windows.D2DERR_TEXT_RENDERER_NOT_RELEASED',
#   'runtime.size_to_class8',
#   'runtime.asyncPreempt2',
#   'golang.org/x/sys/windows.TPM_E_KEY_NOT_LOADED',
#   'syscall.SHUT_RDWR',
#   'golang.org/x/sys/windows.S_APPLICATION_ACTIVATION_ERROR_HANDLED_BY_DIALOG',
#   'waitfor',
#   'math/big.maxBaseSmall',
#   'runtime.debugLogBytes',
#   '!IID_ISurrogate',
#   '&E(,"-',
#   ' map[string]int64',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi.DevInfo.DestroyDriverInfoList',
#   'internal/poll/fd.go',
#   'golang.org/x/sys/windows.DCOMPOSITION_ERROR_WINDOW_ALREADY_COMPOSED',
#   'strconv.(*extFloat).frexp10',
#   'callerPC',
#   '!*runtime.traceStack',
#   '&runtime.context',
#   '%bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.mibIPforwardTable2',
#   'vendor/golang.org/x/net/dns/dnsmessage.TypeNS',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi.CR_BUFFER_SMALL',
#   '*syscall.Pointer',
#   '!*syscall.Win32finddata',
#   'VLBBC88B$8.$.88B$.V',
#   'syscall.CreateFile',
#   '%bytes.Buffer',
#   'noptrbss',
#   '+*struct { F uintptr; s *runtime.pageAlloc }',
#   'golang.org/x/sys/windows.ERROR_VID_NO_MEMORY_BLOCK_NOTIFICATION_QUEUE',
#   '*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.Keypair',
#   'golang.org/x/sys/windows.ERROR_DBG_REPLY_LATER',
#   '&noalg.[8]struct {}',
#   'golang.org/x/sys/windows.XACT_S_MADECHANGESCONTENT',
#   'golang.org/x/sys/windows.CO_E_INITIALIZATIONFAILED',
#   '&runtime.sweepdata',
#   '&unicode.d',
#   'golang.org/x/sys/windows.ERROR_GRAPHICS_MONITORDESCRIPTOR_ALREADY_IN_SET',
#   '*context.deadlineExceededError',
#   'runtime.(*pallocData).hasScavengeCandidate',
#   '%bucket<runtime._typePair,struct {}>',
#   'golang.org/x/sys/windows.ERROR_DS_NOT_SUPPORTED_SORT_ORDER',
#   'encoding/hex.fromHexChar',
#   '!**[65535]uint8',
#   'math/big.ErrNaN',
#   'syscall.WSARecvFrom',
#   'golang.org/x/sys/windows.ERROR_CANT_BREAK_TRANSACTIONAL_DEPENDENCY',
#   'ifname2',
#   'parsePerlClassEscape',
#   'internal/reflectlite.name.nameLen',
#   'status',
#   'unicode..stmp_312',
#   'golang.org/x/sys/windows.ERROR_COULD_NOT_RESIZE_LOG',
#   'runtime.gcAssistAlloc1',
#   'math/big.(*Float).SetPrec',
#   '#[]runtime.ancestorInfo',
#   'readbyteOffset',
#   'GNU C99 7.3-win32 20180506 -m64 -mtune=generic -march=x86-64 -g -O2 -std=gnu99 -fno-PIE',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Device).SetPrivateKey.stkobj',
#   '!IID_IAuthenticateEx',
#   '!*internal/reflectlite.structField',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.NdisPhysicalMediumWirelessWan',
#   'aborted',
#   'inCopyStart',
#   'HasEVTSTRM',
#   'net.socket',
#   'reflect.(*structType).NumOut',
#   'pre_c_init',
#   '&runtime._defer',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Device).IpcSetOperation.func1',
#   '*[]*device.Peer',
#   'golang.org/x/sys/windows.SetsockoptInt',
#   'syscall.PAGE_EXECUTE_READWRITE',
#   'haveTemplateThread',
#   'syscall.ENOTCONN',
#   '&error',
#   'golang.org/x/sys/windows.DV_E_FORMATETC',
#   'internal/syscall/windows/registry.SZ',
#   'addend',
#   'golang.org/x/sys/windows.WinAuthenticationFreshKeyAuthSid',
#   'runtime.(*mcentral).init',
#   'sudogcache',
#   '%bucket<string,regexp/syntax.charGroup>',
#   '[178]unicode.Range16',
#   'gcbssmask',
#   'runtime.init.0',
#   'golang.org/x/sys/windows.ERROR_CLUSTER_INCOMPATIBLE_VERSIONS',
#   'type..eq.reflect.ValueError',
#   'golang.org/x/sys/windows.ERROR_SVHDX_ERROR_STORED',
#   'internal/poll.(*FD).Close',
#   'syscall.(*LazyDLL).Load',
#   'golang.org/x/sys/windows.ERROR_DS_NO_FPO_IN_UNIVERSAL_GROUPS',
#   'golang.org/x/sys/windows.STG_E_FILENOTFOUND',
#   'reflexivekey',
#   'net.(*netFD).setAddr',
#   'regexp/syntax.simplify1',
#   '%strconv.floatInfo',
#   'golang.org/x/sys/windows.REG_RESOURCE_LIST',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.getIPForwardTable2',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Device).IpcGetOperation.func1',
#   'golang.org/x/sys/windows.NTE_NOT_SUPPORTED',
#   'main._cgo_7b13f53c5a86_Cfunc_stateCallback',
#   'golang.org/x/sys/windows.DNS_ERROR_SECONDARY_REQUIRES_MASTER_IP',
#   'Q@H9P@t',
#   '!IID_IDropSource',
#   'unicode..stmp_184',
#   '&state',
#   'atexit',
#   'golang.org/x/sys/windows.WSAEPFNOSUPPORT',
#   'golang.org/x/sys/windows.ERROR_PROFILING_AT_LIMIT',
#   'DelSync',
#   'golang.org/x/sys/windows.FVE_E_POLICY_STARTUP_PIN_KEY_NOT_ALLOWED',
#   'runtime.semacreate',
#   'endpointH',
#   'net.threadOnce',
#   '#[]reflect.Type',
#   'regexp/syntax.OpNoWordBoundary',
#   'golang.org/x/sys/windows.HCS_E_IMAGE_MISMATCH',
#   'sync.RWMutex',
#   'reflect.resolveTextOff',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi.DI_FLAGSEX_BACKUPONREPLACE',
#   'unicode..stmp_384',
#   'golang.org/x/sys/windows.ERROR_ENCLAVE_FAILURE',
#   '*fmt.fmtFlags',
#   '|$pH9;',
#   'golang.org/x/sys/windows.procCreateFileW',
#   '!*hash<string,int>',
#   'net.(*UDPConn).readFrom',
#   '*config.Peer',
#   '5*[]struct { mcentral runtime.mcentral; pad [8]uint8 }',
#   'internal/syscall/windows.ERROR_LOCK_VIOLATION',
#   'golang.org/x/sys@v0.0.0-20200302150141-5c8b2ff67527/windows/registry/key.go',
#   'golang.org/x/sys/windows.ERROR_MCA_INTERNAL_ERROR',
#   '!*runtime.stackObject',
#   'descriptor',
#   '*hchan<*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.QueueOutboundElement>',
#   '__data_start__',
#   'golang.org/x/sys/windows.ERROR_CONNECTED_OTHER_PASSWORD',
#   'golang.org/x/sys/windows.EAS_E_POLICY_COMPLIANT_WITH_ACTIONS',
#   'runtime.getargp',
#   'unicode/utf8.RuneError',
#   'numforcedgc',
#   'golang.org/x/sys/windows.procGetConsoleMode',
#   '.debug_gdb_scripts',
#   'hchan<*bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.QueueOutboundElement>',
#   'golang.org/x/sys/windows.ERROR_PAGEFILE_QUOTA',
#   '__imp_strncmp',
#   'runtime..stmp_11',
#   'syscall.DNS_TYPE_DNSKEY',
#   '*golang.org/x/sys/windows.SECURITY_DESCRIPTOR',
#   'golang.org/x/sys/windows.FVE_E_NO_SUCH_CAPABILITY_ON_TARGET',
#   '*regexp/syntax.InstOp',
#   'golang.org/x/sys/windows.ERROR_CLUSTER_RESOURCE_CONFIGURATION_ERROR',
#   'golang.org/x/sys/windows.COMQC_E_APPLICATION_NOT_QUEUED',
#   'golang.org/x/sys/windows.ERROR_DS_DST_NC_MISMATCH',
#   'golang.org/x/sys/windows.UTC_E_UNAPPROVED_SCRIPT',
#   'golang.org/x/sys/windows.ERROR_VIRUS_INFECTED',
#   'golang.org/x/sys/windows.CRYPT_E_ASN1_CONSTRAINT',
#   '&syscall.Rusage',
#   '!*net.IPAddr',
#   '&noalg.struct { F uintptr; runtime.rw *runtime.rwmutex }',
#   'golang.org/x/sys/windows.ERROR_DS_SRC_GUID_MISMATCH',
#   '*runtime.functab',
#   'golang.org/x/sys/windows.SHTDN_REASON_MINOR_POWER_SUPPLY',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/ratelimiter.packetsPerSecond',
#   'unicode..stmp_361',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi..stmp_14',
#   'golang.org/x/sys/windows.CO_E_MSI_ERROR',
#   'golang.org/x/sys/windows.TPM_E_AUTHFAIL',
#   'Immortal',
#   '` 01($@',
#   'golang.org/x/sys/windows..stmp_61',
#   'runtime.checkmcount',
#   '2(5:2U5N2]2}5g2',
#   'golang.org/x/sys/windows.DOMAIN_ALIAS_RID_USERS',
#   'golang.org/x/sys/windows.NTE_BAD_KEYSET_PARAM',
#   'math/big.shrVU',
#   'golang.org/x/sys/windows.CO_E_INVALIDSID',
#   'V$B8.BC',
#   'golang.org/x/sys/windows.ERROR_HOST_NODE_NOT_AVAILABLE',
#   'runtime.(*rwmutex).rlock',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun.(*Interface).DeleteInterface.stkobj',
#   'golang.org/x/sys/windows.SEC_E_NO_SPM',
#   'golang.org/x/sys/windows.ERROR_REPARSE',
#   'golang.org/x/sys/windows.E_HANDLE',
#   ' map[string]int',
#   'runtime.end',
#   'unicode..stmp_403',
#   'syscall.ENOEXEC',
#   '[19]unicode.Range16',
#   '<missing>_7',
#   'libcallpc',
#   'golang.org/x/text/unicode/norm.jamoVTCount',
#   'runtime.startlockedm',
#   'hasLastMAC1',
#   'RtlNtStatusToDosErrorNoTebSaint Pierre Standard TimeSetSecurityDescriptorGroupSetSecurityDescriptorOwnerSetupDiBuildDriverInfoListSouth Africa Standard TimeUAPI: Updating listen portUAPI: Updating private keyUnable to update bind: %v',
#   '*[]syscall.WSABuf',
#   'installFunction',
#   'VersionAndFlags',
#   'golang.org/x/sys/windows.CRYPT_E_EXISTS',
#   'fmt.(*pp).doPrintln',
#   'golang.org/x/sys/windows.UCEERR_PACKETRECORDOUTOFRANGE',
#   'golang.org/x/sys/windows.MARSHAL_E_LAST',
#   'acceptOne',
#   '*uint16',
#   'unicode..stmp_50',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.MibNotificationType',
#   'IID_IWrappedProtocol',
#   '__size_of_heap_reserve__',
#   'math/rand.Source64',
#   '%os/exec.Error',
#   '!GUID_PROCESSOR_PERF_HISTORY',
#   'syscall.compileCallback',
#   'regexp.(*machine).add',
#   '.idata$5',
#   'reflect.(*funcTypeFixed8).common',
#   'golang.org/x/sys/windows.TPM_20_E_SELECTOR',
#   'runtime/cgo/iscgo.go',
#   '!*[2]uint64',
#   'bufio.(*Scanner).advance',
#   'golang.org/x/sys/windows.DNS_ERROR_POLICY_INVALID_CRITERIA_NETWORK_PROTOCOL',
#   'LastBranchFromRip',
#   'unicode..stmp_322',
#   'exceptionaddress',
#   'reflect.(*funcTypeFixed128).ConvertibleTo',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.NdisMediumAtm',
#   'protocolBuffer',
#   'regexp/syntax.code17',
#   'golang.org/x/sys/windows.SW_SHOWNOACTIVATE',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Peer).timersInit.stkobj',
#   '!*hash<vendor/golang.org/x/net/dns/dnsmessage.RCode,string>',
#   'golang.org/x/sys/windows.CO_E_FIRST',
#   'golang.org/x/sys/windows.WSA_IPSEC_NAME_POLICY_ERROR',
#   'syscall.WSARecvFrom.stkobj',
#   'internal/poll/errno_windows.go',
#   'golang.org/x/sys/windows.RegQueryValueEx.stkobj',
#   'golang.org/x/sys/windows.ERROR_BAD_NET_NAME',
#   '!*func(int, int)',
#   'context.CancelFunc',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi.setupDiGetClassDevsEx.stkobj',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.AtomicTrue',
#   'endianness',
#   'syscall.CRYPT_SILENT',
#   'golang.org/x/sys/windows.SidTypeUser',
#   'fmt.(*pp).fmtBytes.stkobj',
#   'encoding/binary.(*encoder).int8',
#   'golang.org/x/sys/windows.MEM_RESET',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device/conn_default.go',
#   'runtime.gcController',
#   'reflect.(*ptrType).IsVariadic',
#   'golang.org/x/text/unicode/norm.Properties.Size',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/setupapi.SetupDiGetDeviceInstallParams',
#   'syscall.procCryptReleaseContext',
#   'syscall.O_WRONLY',
#   'total_alloc',
#   'golang.org/x/sys/windows.ERROR_NETWORK_NOT_AVAILABLE',
#   '.xdata.startup',
#   'golang.org/x/sys/windows.DNS_ERROR_RCODE_NAME_ERROR',
#   'fwmark',
#   'golang.org/x/sys/windows.CERTSRV_E_DOWNLEVEL_DC_SSL_OR_UPGRADE',
#   'copyError',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/windows/tunnel/winipcfg.IfTypeLapD',
#   '"http://crl.globalsign.com/root.crl0G',
#   'base64Key',
#   'runtime.didothers',
#   'golang.org/x/sys/windows.ERROR_EVT_EVENT_DEFINITION_NOT_FOUND',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/tun/wintun/registry.OpenKeyWait.stkobj',
#   'bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.(*Peer).Stop.stkobj',
#   'runtime.(*pageAlloc).find',
#   'golang.org/x/sys/windows.ERROR_EVT_MESSAGE_LOCALE_NOT_FOUND',
#   '!IID_IXMLDOMImplementation',
#   '&bucket.digitalarsenal.net/low-level-hacks/nordlynx-go/device.IPCError',
#   'golang.org/x/sys/windows.D2DERR_PRINT_FORMAT_NOT_SUPPORTED',
#   'runtime.(*mheap).alloc',
#   'IID_IForegroundTransfer',
#   'HasASIMDRDM',
# ...
#   'TATEOnlineSearchProviderDiscogs',
#   'miJumpToClick',
#   'pnlLeft',
#   'FWorkWithCopy',
#   'GetFileListEx',
#   'artist',
#   'btnAutoTag',
#   '@System@Move$qqrpxvpvi',
#   '@Vcl@Controls@TControl@SetPopupMenu$qqrp20Vcl@Menus@TPopupMenu',
#   '@Aimp@Quicktageditor@Core@TAIMPQuickTagEditorController@GetCanEdit$qqrv',
#   '@Acl@Ui@Resources@initialization$qqrv',
#   '&TCollectionNotifyEvent<System.TObject>',
#   '@Abl@Fileinfo@TABLCustomFileInfo@SetTrackNumber$qqrx20System@UnicodeString',
#   'OnGetNodeBackground',
#   '`.data',
#   '@Atl@Tags@Vorbiscomments@Finalization$qqrv',
#   '-TComparison<ATL.Editor.TATLQuickSetMaskField>',
#   'TDiscogsTaskI',
#   'Rename',
#   '@Vcl@Axctrls@initialization$qqrv',
#   '@System@Math@IfThen$qqroxixi',
#   '@System@Generics@Collections@TListHelper@DoExchangeInterface$qqrii',
#   '@System@Sysutils@Finalization$qqrv',
#   '@Atl@Fileformats@Wv@Finalization$qqrv',
#   '@Acl@Ui@Controls@Treelist@TACLCustomTreeList@SetViewPortX$qqrxi',
#   '@Acl@Ui@Controls@Compoundcontrol@Subclass@TACLCompoundControlSubClass@DoDropSourceGetData$qqrp32Acl@Ui@Dropsource@TACLDropSourcep14System@TObject',
#   'bPlayerClose',
#   'Format to X',
#   'TAIMPATEAnalysisResultPreview',
#   '@$xp$15TStringDynArray',
#   'acFileAdd',
#   '@System@Strutils@IfThen$qqrox20System@UnicodeString20System@UnicodeString',
#   'HeightD',
#   '@$xp$22System@Json@TJSONArray',
#   '@Aimpabout@initialization$qqrv',
#   '@System@Dateutils@TTimeZone@$bcctr$qqrv',
#   '@Vcl@Controls@TWinControl@SetFocus$qqrv',
#   '@Vcl@Stdctrls@TCustomComboBox@$bcctr$qqrv',
#   'ParentCtl3D',
#   '@Atl@Fileformats@Oggvorbis@initialization$qqrv',
#   '@Aso@Player@Stream@TASOStreamFadingOptions@SetEnabled$qqro',
#   '@Abl@Filechangenotifier@TABLFileChangeNotifier@Renamed$qqrx20System@UnicodeStringt1o',
#   'TACLActivityIndicator',
#   '@Atl@Editor@TATLEditor@GetPage$qqri',
#   ';TDictionary<System.TObject,System.TObject>.TValueCollection',
#   'tsVolume$',
#   '@System@Generics@Collections@TListHelper@DoIndexOfRev8$qqrpxv',
#   '@Acl@Ui@Forms@TACLForm@ApplicationSettingsChanged$qqr61System@%Set$34Acl@Ui@Forms@TACLApplicationChanget1$i0$t1$i1$%',
#   'PMIAmIgaeContnr',
#   '@Acl@Ui@Forms@TACLLocalizableForm@',
#   'beFilePathButtons1Click',
#   '@Acl@Classes@Stringlist@TACLStringList@Remove$qqrx20System@UnicodeString',
#   'OnDestroy',
#   '@Atl@Editor@Tools@TATLRandomizer@',
#   '@Acl@Ui@Controls@Combobox@TACLComboBox@IndexOf$qqrx20System@UnicodeString',
#   '@Acl@Ui@Controls@Treelist@Options@TACLTreeListCustomOptionsImage@SetImages$qqrp28Vcl@Imglist@TCustomImageList',
#   '@Aimp@Core@Core$qqrv',
#   'stHorizontal',
#   '@System@Classes@TComponent@UpdateRegistry$qqrox20System@UnicodeStringt2',
#   '@Vcl@Controls@TWinControl@AsyncSchedule$qqrxp31System@Classes@TBaseAsyncResult',
#   '@$xp$18System@Rtti@TValue',
#   ...},
#  {' .Jbjx=',
#   ' ]!%s%s%[^',
#   '! 6J[[',
#   '! 6J[[Lj=',
#   '!This program cannot be run in DOS mode.',
#   '""""""!',
#   '""""""""""""""""""""""',
#   '"\' 6Hx',
#   '"\'/5H[DPY',
#   "#''(((-3.....",
#   "#''(-12..91-00",
#   '#CCCCCCCA',
#   '#CCCCCCCCCA',
#   '$$(("-2...',
#   '%[ :]%s',
#   '%[ ]%[^ ',
#   '%[ ]%s',
#   '%s %[^',
#   '%s %s %[^',
#   '%s %s %s',
#   '%s %s %s %s %s',
#   '%s%s%s%s%s%s%s',
#   '%s.%s.%s.%d',
#   '%s... angle for you..!!!',
#   '%s\\WinRaR',
#   '%s\\WinRaR\\WinRAR.exe',
#   '%s\\WinZip',
#   '%s\\WinZip\\WINZIP32.exe',
#   '%s\\zipfldr.dll',
#   '%sdfinstall.log',
#   '%s~%s.exe',
#   '&Eggggggged',
#   "'11-899@@QGO",
#   "'11899AA@KI",
#   "'2899AJA",
#   "'889JJJjx",
#   "'8@AJJJP",
#   "'9AJjjj;",
#   "'9AJjjjm",
#   "'9AJkjjn",
#   "'@@JJjj}f",
#   '((1-823908QKFB',
#   "*'5[Dj",
#   '*Ktuo]]]]=',
#   '+Eyyyyy%',
#   ',TTTTonmvuttuvmnTTTTTTTTTTTTTTTT=',
#   '-Yjoz{',
#   '-min -a -en -r "%s" "%s"',
#   '-s:ftp.txt',
#   '.LjR=W',
#   '1111111(o',
#   '192.168',
#   '2((((((((((((((((((((((((((',
#   '33$?m[',
#   '33333333333333',
#   '333333333333330',
#   '333333333333333',
#   '333333333333333333333333333333333333333333333333333333333333333333333',
#   '4444444',
#   '444444444',
#   '44444444444',
#   '4444444444444444444444',
#   '4444444444444444444444444444444444444444444444444444444444444444',
#   '444444444444444444444444444444444444444444444444444444444444444444',
#   '444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444',
#   '444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444',
#   '555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555',
#   '5n]aaaa%',
#   '6=`qqqq4',
#   '6>Mbbbbbb%',
#   '7,OdddddeydNc%',
#   '7DaMMMMM%',
#   '7lllll',
#   ':]%[ :]%[^',
#   ':]qqqqq%',
#   ':_MMMMMb%',
#   ';INNNNNdNNd%',
#   ';MNNNNNNNN%',
#   '<<<<<<<<<<<<<<<<<<<<<<<<<<u9l',
#   '<<<<<<<T',
#   '<um^^^^=',
#   '??????????????????????????????????????????????????????????????????????????????????????????',
#   '?Mccccccc%',
#   '@.data',
#   'A><<<<<<<<<<<<<<<<<<<<<<<<<<',
#   'ADMIN$',
#   'ADVAPI32.dll',
#   'AKU KELUAR',
#   'AdjustTokenPrivileges',
#   'AgentControlHidden',
#   'All Users',
#   'AppendMenuA',
#   'BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB6',
#   'BeginUpdateResourceA',
#   'Borneo, 2006<p>Kepada Yth.:<p>Bapak Presiden.......<p>di-<p>TEMPAT<p>Dengan Hormat<p>BANGUNLAH DUNIA TEHNOLOGI INFORMASI YANG HANDAL DINEGERI TERCINTA INI<p>Bapak Presiden, mohon dengan sangat agar dapat diperhatikan masalah ini sisihkanlah anggaran negara kita untuk pembangunan TI yang handal, berilah anak-anak didik kita akses murah untuk menuju dunia internet...jadikanlah dalam waktu 10 tahun yang akan datang mereka jawara2 didunia internasional dalam hal TI bukan jawara Pembantu Rumah Tangga...!!!!!<p>SIAPA YANG MENGUASAI DUNIA TEKHNOLOGI INFORMASI, MAKA DIA AKAN MENGUASAI DUNIA..!!<p>Hormat Saya<p><p><p>Yang Tak Ingin Menjadi Budak Negara Lain',
#   'C:\\Surat Buat Presiden.htm',
#   'CCCCCCCCCCCA',
#   'CCCCCCCCCCCCCCCCCCCCCC',
#   'CURRENT_USER',
#   'CloseHandle',
#   'Confirm',
#   'CopyFileA',
#   'CreateProcessA',
#   'CreateToolhelp32Snapshot',
#   'D$dRPh',
#   'D$hRPhP',
#   'D$pRPh',
#   'DBBEBCEBBBCBBBEDDBBBDCCBBBBCBBCBBDDBCBBBCCCBCBBCBBEDBDEBCCBBCDBCEBCBCBBBBBBDCCDCCBDDDCBBD6',
#   'Default User ID',
#   'Delete',
#   'DeleteFileA',
#   'Desktop',
#   'DisableRegistryTools',
#   'Documents and Settings',
#   'DrawIcon',
#   'EEECEEEEEBCCBCBEBEBECCBEEBCCEDECEEEDDBCDBECBEECECCECEEEBEDDBCEEBBDEEEEBBECCEDEEEEDBCECBBC6',
#   'EEEEEEEEEEEEEEEEEEEEECDEEEEEDEECECEEEDEEEEEEEDECEDEEEEEEEECECEEECEEEBEEEECEBECCEEEEEEEEEE7',
#   'EEEEEFEGEFFEGFGEEEEEFEGEFHFGGEEEEEGHEFFEFEEFFFEFEEEEHEGFEHEEGEEEFEEEEHEEEEEEFEEEEFGGEFFFE7',
#   'EH, JANGAN LUPA TEPATI JANJIMU..!!!',
#   'Edit String',
#   'EnableWindow',
#   'EndUpdateResourceA',
#   'EnumResourceNamesA',
#   'EnumWindows',
#   'Error Deleting File or Folder',
#   'ExitProcess',
#   'ExitWindowsEx',
#   'FHHHHFGFHGFHFGEFFEFFHEFEFFFFFFFFGHHHFHGHHHFHHHHFGFGFGHGGEHFHFGGHGGGGHHFFHGHGFFEEEHHEHGHHF8',
#   'FindClose',
#   'FindFirstFileA',
#   'FindNextFileA',
#   'FindResourceA',
#   'Fkqc`ngAOF',
#   'FreeLibrary',
#   'GetClientRect',
#   'GetCurrentProcess',
#   'GetDriveTypeA',
#   'GetLogicalDrives',
#   'GetModuleFileNameA',
#   'GetModuleHandleA',
#   'GetParent',
#   'GetProcAddress',
#   'GetSecurityInfo',
#   'GetStartupInfoA',
#   'GetSystemDirectoryA',
#   'GetSystemMenu',
#   'GetSystemMetrics',
#   'GetTickCount',
#   'GetVersionExA',
#   'GetWindowLongA',
#   'GetWindowTextA',
#   'GetWindowsDirectoryA',
#   'H8^Qc{c"@gphclhk"Wlvwi"Ogl{g`cpicl"Rpmepco"klk"fcl"Ogl{corckicl"Rgqcl"Klk"Igrcfc"Rpgqkfgl',
#   'HIHIIIKHJKKHHIHKHKHKIJKHIJHJIHIJHKJHHHHHIJIIIKHIHIIHHIKIKKKIKIJJIIHKIHKJJJIIKKHHHKHKHIIIH:',
#   'HSQ}|{{tnUWUUWUUUUU=',
#   'Hardware',
#   'Hidden',
#   'HiddenFinder',
#   'HideFileExt',
#   'Hijack',
#   'Hlum^^^^=',
#   'IIIIIIIIIIIIIId7',
#   'IIIII`',
#   'IYA DEH, AKU KELUAR.... SORRY....!!!!',
#   'Id7(1IIIIIIIIIIII',
#   'Identities',
#   'ImagePath',
#   'IsIconic',
#   'JOIN #l1br3n',
#   'JOIN #nyubi',
#   'JOIN %s',
#   'KERNEL32.dll',
#   'KICK %s %s',
#   'KKKIKKKKKKKKIKIIKIKKKKKIKKKKKKKIKKKKKKKKKKIIKKKKKKIKKKKKIKKKIIKKKKIKKLKKKKKKKKIKKKKIIKKKK9',
#   'Klvgplgv"Gzrnmpgp^kgzrnmpg,gzg',
#   'L$ j@Q',
#   'L$4Ph,',
#   'L$`QRh',
#   'L$pQRh',
#   'LMLLLKKNKKNLMKKLKKLLKLKKLKNLLKLLLKKLLMKKNKLNKKNLLKLNMKKLKLKKNNMMLMLLNLKMKKLMKLKLLNKLKLNNL;',
#   'LoadIconA',
#   'LoadLibraryA',
#   'LoadLibraryExA',
#   'LoadResource',
#   'Local Settings',
#   'LocalFree',
#   'LockResource',
#   'LookupPrivilegeValueA',
#   'Lttm[]]]]4',
#   'LuuR^^^^=',
#   'MAPI32.DLL',
#   'MAPIFindNext',
#   'MAPIFreeBuffer',
#   'MAPILogon',
#   'MAPIReadMail',
#   'MAPISendMail',
#   'MFC42.DLL',
#   'MODE %s +b %s',
#   'MODE %s +o %s',
#   'MODE %s -b %s',
#   'MODE %s -o %s',
#   'MPR.dll',
#   'MSVCRT.dll',
#   'MapViewOfFile',
#   'Marshaling',
#   'NETAPI32.dll',
#   'NICK %s',
#   'NICK _%s_abc',
#   'NNNNMNNNNNLNLLNNNNLLNNLLNNLNNNNLLNLLNLNLNNLLLLNNMNLLNLLNNNNLNLNLLLNNNNLLLNLNNNNNNNLNNLLLN>',
#   'NetApiBufferFree',
#   'NetShareEnum',
#   'NetUseAdd',
#   'NetUseDel',
#   'NoSetFolders',
#   'OOONOOONOQNONONOOONONONOONONNORONOQNONOOOONRNORNNQNNOOONOOOONOOOQOQONOQNNRONQNNOORNOONNNN<',
#   'Ogqqglegp^oqoqeq,gzg',
#   'Okapmqmdv"Mddkag^Mddkag33^GZAGN,gzg',
#   'Okapmqmdv"Mddkag^Mddkag33^UKLUMPF,gzg',
#   'Okapmqmdv"Mddkag^Mddkag^GZAGN,gzg',
#   'Okapmqmdv"Mddkag^Mddkag^UKLUMPF,gzg',
#   'OpenProcessToken',
#   '...',
#   'PART %s %s',
#   'POP3 User Name',
#   'PRIVMSG',
#   'PRIVMSG %s :%s',
#   'PRIVMSG %s := |cmd| perintah, |shell| ip port, |file| ftp_server file, |send| channel/nick pesan, |nick| nick baru',
#   'PRIVMSG %s := |cmd|, |shell|, |file|, |send|, |nick|, |join|, |part|, |op|, |deop|, |ban|, |unban|, |help|',
#   'PRIVMSG %s := |join| channel, |part| channel, |op| nick channel, |deop| channel nick, |ban| channel nick, |unban| channel nick, |help|',
#   'PRIVMSG %s :Contoh Perintah-Perintah :',
#   'PRIVMSG %s :Perintah-Perintah',
#   'Patrol',
#   'Please read an attacments bellow and make your opinion,!!!',
#   'PostMessageA',
#   'Printer',
#   'Process',
#   'Process32First',
#   'Program Files',
#   'QRVVht',
#   'Q[QVGO^AmlvpmnQgv223^Qgptkagq^qpqgptkag',
#   'Q[QVGO^AmlvpmnQgv223^amlvpmn^Qcdg@mmv',
#   'Qmdvucpg^Rmnkakgq^Okapmqmdv^Uklfmuq^Q{qvgo',
#   'RRRRRRRROORORRROOORRRORROORRRRRORRRORROOPRRRRORROORRRRRRROROROOSRRRRRRORRRRRRRROORRORRRRR<',
#   'RR````4',
#   'RSSRRRRSSSRRSVRSRRRSSSSRVSSRRSRRSRSSSSSSUURSSRRRSSRSUSUSVSRSSRURSRRSSUSVURSSSSSRRVRSRRVVS=',
#   'RTaaaa4',
#   'RUXXWXXXXW=',
#   'RVVVGGGGFFFFF::::CCCC/////<',
#   'RXYYXYXXX=',
#   'RegCloseKey',
#   'RegCreateKeyA',
#   'RegEnumKeyA',
#   'RegEnumValueA',
#   'RegOpenKeyA',
#   'RegOpenKeyExA',
#   'RegQueryValueExA',
#   'RegSetValueExA',
#   'Remove',
#   'Rn````4',
#   'RtlInitUnicodeString',
#   'SHELL32.dll',
#   'SHGetSpecialFolderPathA',
#   'SSSSSSSSSSSSSSTTTTTTTTT:kK^l',
#   'SSVVVVSVVTSSTVTVTSTVVVVWTSTVVWTVVVVVVVVSVSSSSSVSWSSWWVVVVSSVVVVVSVVVSVVVVVWVSSVVVWSVVSSSS@',
#   'SUVWPh',
#   'SeDebugPrivilege',
#   'SeShutdownPrivilege',
#   'SendMessageA',
#   'SetEntriesInAclA',
#   'SetFileAttributesA',
#   'SetSecurityInfo',
#   'ShellExecuteA',
#   'SizeofResource',
#   'Software\\Microsoft\\Internet Account Manager\\Accounts',
#   'Software\\Microsoft\\Internet Account Manager\\Accounts\\%s',
#   'Software\\Microsoft\\Office\\Outlook\\OMI Account Manager\\Accounts',
#   'Software\\Microsoft\\Office\\Outlook\\OMI Account Manager\\Accounts\\%s',
#   'Software\\Microsoft\\Windows\\CurrentVersion\\Explorer\\Advanced',
#   'Software\\Microsoft\\Windows\\CurrentVersion\\Policies',
#   'Software\\Microsoft\\Windows\\CurrentVersion\\Policies\\Explorer',
#   'Software\\Microsoft\\Windows\\CurrentVersion\\Policies\\System',
#   'Svm____4',
#   'System Restore',
#   'T$$QRWP',
#   'T$(QRP',
#   'T$dQRh',
#   'T$hQRh',
#   'T$hQRhP',
#   'Tamara_Blezynsky',
#   'USER 1%s_ "" "2%s-" :3%s__',
#   'USER32.dll',
#   'Uklfmuq"Ogfkc"Rnc{gp^uornc{gp,gzg',
#   'UnmapViewOfFile',
#   'UpdateResourceA',
#   'V211111111111111111111111111',
#   'WINDOWS',
#   'WNetCancelConnection2A',
#   'WS2_32.dll',
#   'WSASocketA',
#   'WVZWWWVWWZZWWWVWWWWWWVWWWYZWWWWWVWVWWVWWVZZZWWWWWWWZWZWWWVWWVZWWWWWWYYWVWWVWWWWZZZWWYVWWV@',
#   'Warn on Mapi Send',
#   'WinExec',
#   'Windows',
#   'XwwwwwwwwwwwwwwSSSTTpNJBllll',
#   'You can send your opinion back to my email address',
#   'Z[Z[WWZZWWZZZXXZZZZWZXZZ[X[[[ZZWZZZZZWZZXWWZXZWZWZZZZZZZZZ[ZW[ZZ[ZZ[ZWWZ[[ZZWZZZZ[[WZZZZZA',
#   'ZwOpenSection',
#   '[>6cj0',
#   '[[[[[Y',
#   '[[[[[[',
#   '[[[[[[[',
#   '[[[[[[[[',
#   '[[[[[[[[7',
#   '[[[[[jxzW',
#   '[[^[^[^[[]^[^[[[[[[[[[^^[[[[^^[[[[[^^[[[^^[[[[[[[^]^[[[[^[[^^[[[^ZZ[[^[[[^^^^[[ZZ[[][[[[^-',
#   '[c*(((((((((((((((((wl',
#   '[fPFMlllll',
#   '[f}tttttttttt',
#   '[i)<<<<<<<<<<<<<<:nK_l',
#   '[i>wTTTTTTTTwpN',
#   '[i}<<<<<<<<<<<<<<<<<wl',
#   '[o$(111111111((#',
#   '[o2T<<<<<<<11<t9Ll',
#   '[o>wSSTTTw:nLglll',
#   '[q~b[Fllll',
#   '[sTtpk',
#   '\\Software\\Microsoft\\Outlook Express\\5.0\\Mail',
#   '\\\\%s\\%s',
#   '].%[^.',
#   '^_^\\^_\\^[__^^_^^__^^^^___^__^\\_\\\\_^^^^\\^^_[__^^__^_^__^^\\[^^_^_^^_^\\_^_^^\\^\\^[^[[__^\\^^^\\-',
#   '_XcptFilter',
#   '__CxxFrameHandler',
#   '__dllonexit',
#   '__getmainargs',
#   '__p__commode',
#   '__p__fmode',
#   '__set_app_type',
#   '__setusermatherr',
#   '_acmdln',
#   '_adjust_fdiv',
#   '_beginthread',
#   '_controlfp',
#   '_endthread',
#   '_except_handler3',
#   '_glllll',
#   '_initterm',
#   '_mbscmp',
#   '_onexit',
#   '_setmbcp',
#   '_strcmpi',
#   '`.rdata',
#   'a -ao -ep "%s" "%s"',
#   'abbbbbbbababbabebababbbbbbbbbbbbbbbbbabaaababbabbbbbbaabbabbaabbabbdbabbbaaabbabbabababbb.',
#   'ba_`__aa_____aaaab__a_aa``ab__a__a___b__a____`___a__a______a_a_b_a__a__`_aa`a__aa_abaa``a.',
#   'cleaner',
#   'cleng,Xkr',
#   'cleng,gZg',
#   'd3st1n1ty_1',
#   'ddddddddddddd',
#   'dkzgf,gZg',
#   'eeebeccbefbefefeffbbbeffeecbfbeeeebefebebefbceefeceefefffffbfebeebeeebebfeebfecbbbeeecffc/',
#   'fEeeeeeee',
#   'fclose',
#   'ffiffffffffififfffffffffffffieffffffffffiifffiiffffiffiifffffffiffffffiffffffhffffffffiif/',
#   'ftp.exe',
#   'ftp.txt',
#   'fwrite',
#   'gzagn,gZg',
#   'gzrmpv"JIG[]NMACN]OCAJKLG^Q[QVGO^AmlvpmnQgv223^Qgptkagq^qpqgptkag',
#   'h7dllll',
#   'ha[]dlll',
#   'ha[llll',
#   'hre,gZg',
#   'iiiiiiii',
#   'ijjgijggjfifjjgijijjjjigjijgjiiijijjiiiffjijjjjjjijjijijjiijiijjjiigfijjjjjijjjjjjjgijjjj0',
#   'import %s',
#   'irc.librenet.net',
#   'jjmjjjjjllllljjjkljlkjjmljljljjjkkjjjmkljjjjkjjjmljjklljljljjjkllkjmjjlljlkllmkllkklljllj1',
#   'kgzrnmpg,gZg',
#   'lstrcatA',
#   'mRpppp4',
#   'mbstowcs',
#   'mm____4',
#   'mmlmmlmmmmlmmmmmkmmlmmlmmmmmmmmmmmmmmmmmlmmmmlmmlmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm2',
#   'mmpppp4',
#   'moTUTTTTTTUUT=',
#   'nKB\\`lll',
#   'nKG[llll',
#   'nYZYYYY[=',
#   'nhGFlllll',
#   'npoppnomnomnmppnopomopommmnopmpnmonpppomopmooopmoppponpppmmpnompmompopnnompnopmmmmmoopoom2',
#   'ntdll.dll',
#   'ogqqglegp,gZg',
#   'oqoqeq,gZg',
#   'pge,gzg',
#   'pgegfkv,pge',
#   "ppppppqpppppppppsqpqprpppppppprpqppqrrprpqspppqrppprpppprqqrppppqpppprprpqpppqppppppppppr'",
#   'print$',
#   'pssssssqrssssssspqssssssprqsssssssqrqssqsrrsqssrrqrsssrqsspsqqsspsqqsssspsssssqqqrrsqssss(',
#   'qtajmqv,gZg',
#   'qtajmqv,gzg',
#   'rar.exe',
#   'reg.exe',
#   's0lp0t',
#   'sprintf',
#   'sscanf',
#   'strncpy',
#   'strstr',
#   "thank's...!!!",
#   'tn]]]]\\4',
#   'ttttttttj',
#   'ukccaoep,gzg',
#   'ukcqjgzv,fnn',
#   'uklcor,gZg',
#   'uklcor^uklcor,gzg',
#   'umpf,gZg',
#   'uornc{gp,gZg',
#   'v[\\\\\\\\\\4',
#   'version',
#   'vm^___=',
#   'vtwvtvvttstvwwvtwsvsswvtsvtsvtwstwvsssvvtsssssswvswsssswsttvsssswwsssvwstwvswvssswtvvsvvv(',
#   'winzip32.exe',
#   'wwwwwww',
#   'wwwwwwwwwwwwxwwwxwwwwwwwwwwtwwwwwwxwwwwwuwwwwwwxtwwwwwwwwwwwwwwwwwwxwxwwwwwwwwwwwwwxwwwww)',
#   'xkrpcp,gZg',
#   'xyyzzzwyzyzzzzwzwwxzzyxzzzyyzzxxzzwxxxyxxxzzzzxyyyywzzzxyyxzzxzxzxyywyzzzwxxzxzyyxzzxwzzz*',
#   'xyyzzzwyzyzzzzwzwwxzzyxzzzyyzzxxzzwxxzz|zz|{zzz{|zzz{z{zzzzzzz|z{z{z{{z{zzzzzz{{{zzz{z{{{+',
#   'yyyy3Wq',
#   'yyyyyy',
#   'zz{{zz|{zzzzzz|}zzzzzzzzzz{z{|zz{zzz|{}}}}{}}}}{}{}}}}{}}}}{}}}}}}}{}}{}{}}{{}}zz}}}{}}}},',
#   '{{{{{x',
#   '{{{{{{{{{{{{{{0',
#   '|%##########################',
#   '|deop|',
#   '|file|',
#   '|help|',
#   '|join|',
#   '|kick|',
#   '|nick|',
#   '|part|',
#   '|send|',
#   '|shell|',
#   '|unban|',
#   '|{zzzzzz{|tmoTTTTTTTTTTTTT=',
#   '}}}{{{}}}{{}{{{}}{}}{{}}}{}}}{z}{}}{}{}}}}{}}}}{}{}}}}{}}}}{}}}}}}}{}}{}{}}{{}}zz}}}{}}}},',
#   '}}}~}~}~~~~~}~~~~',
#   '}~}}~}}~~}~~~~~~~~',
#   '~~to[\\[\\\\\\=',
#   '~~~}~}}'}]

# %%
with open("./datasets/pkl/pe_benign_string.pkl", "wb") as f:
    pickle.dump(benign_strings, f)

# %%
def main(payload_path, signature_path, stopword_path, virtual_vector_path, big_group_path,
         window_size, K, M, # MV2 파라미터
         thetaJ,  # JIG 파라미터
         vector_size, eps, minpts, ngram, hh1_size, hh2_size, hh3_size, ratio # SG2, AWL 파라미터
        ):
    
    with open(payload_path, 'rb') as f:
        payloads_data = pickle.load(f)

    print(len(payloads_data))
    payloads = [x for x in payloads_data]

    print(len(payloads))

    # 빅 그룹 식별
    minhashed_virtual_vectors = MV2(payloads=payloads, window_size=window_size, K=K, M=M)
    with open(virtual_vector_path, 'wb') as f:
        pickle.dump(minhashed_virtual_vectors, f)

    big_group_indices = JIG(vectors=minhashed_virtual_vectors, thetaJ=thetaJ)
    with open(big_group_path, 'wb') as f:
        pickle.dump(big_group_indices, f)
    
    big_group_payloads = []
    non_big_group_paylaods = []

    for idx, payload in enumerate(payloads):
        if idx in big_group_indices:
            big_group_payloads.append(payload)
        else:
            non_big_group_paylaods.append(payload)
    
    # 시그니처 생성
    cluster_signatures = SG2(payloads=big_group_payloads, window_size=window_size, vector_size=vector_size, 
                             eps=eps, minpts=minpts, ngram=ngram, hh1_size=hh1_size, hh2_size=hh2_size, hh3_size=hh3_size, ratio=ratio)
    
    with open(signature_path, 'wb') as f:
        pickle.dump(cluster_signatures, f)
    
    stopwords = AWL(payloads=non_big_group_paylaods, ngram=ngram, hh1_size=hh1_size, hh2_size=hh2_size, hh3_size=hh3_size, ratio=ratio)

    with open(stopword_path, 'wb') as f:
        pickle.dump(stopwords, f)

# %%
# 파라미터

file_path = './datasets/pkl/pe_benign_string.pkl'
virtual_vector_path = f'./res/PE_benign_virtual_vector.pkl'
big_group_indices_path = f'./res/PE_benign_big_group.pkl'
signature_path = f'./res/PE_benign_signature.pkl'
stopword_path = f'./res/PE_benign_stopword.pkl'

K = 64
M = 2 ** 14
thetaJ = 0.6
window_size = 4
vector_size = 512
eps = 0.4
minpts = 5
ngram = 4
hh1_size = 3000
hh2_size = 3000
hh3_size = 3000
ratio = 0.1

# %%
main(payload_path=file_path, signature_path=signature_path, stopword_path=stopword_path,
         virtual_vector_path=virtual_vector_path, big_group_path=big_group_indices_path,
         window_size=window_size, vector_size=vector_size, K=K, M=M, thetaJ=thetaJ,
         eps=eps, minpts=minpts, ngram=ngram, hh1_size=hh2_size, hh2_size=hh2_size, hh3_size=hh3_size, ratio=ratio)
# Out:
# 29909
# 29909
# make minhashed vector
# 100%|██████████| 29909/29909 [14:42<00:00, 33.91it/s]
# checking big group
# 100%|██████████| 29909/29909 [03:34<00:00, 139.26it/s]
# chunking
# 100%|██████████| 8167/8167 [00:40<00:00, 201.09it/s]
# start DBSCAN
# end DBSCAN
# make signature
# 100%|██████████| 2/2 [00:23<00:00, 11.85s/it]
# end signature
# start whtie list
# end white list

# %%
with open(signature_path, 'rb') as f:
    signature = pickle.load(f)
    
with open(stopword_path, 'rb') as f:
    stopword = pickle.load(f)
    
with open(big_group_indices_path, 'rb') as f:
    big_group = pickle.load(f)

# %%
signatures = dict()

print('SIGNAURE')
for idx, sig in enumerate(signature.values()):
    print(f'cluster: {idx}, size: {len(sig)}')
    for j in sig:
        if j[0] not in signatures:
            signatures[j[0]] = 0
        signatures[j[0]] += j[1]
        print(j, end=" ")
    print()
# Out:
# SIGNAURE
# cluster: 0, size: 28
# ('String', 15843) ('Thread', 14031) ('System', 11916) ('.rdata', 11717) ('.idata', 11167) ('Exception', 10937) ('GetCurrentProcess', 10378) ('Object', 8212) ('A_A^A]', 7181) ('Delete', 7141) ('      ', 7133) ('0123456789', 6026) ('Version', 5854) ('GetValue', 5598) ('!This program cannot be run in DOS mode.', 5285) ('ExitProcess', 5057) ('KERNEL32', 4878) ('.reloc', 4395) ('@.data', 3999) ('TerminateProcess', 3995) ('static ', 2846) ('atexit', 2700) ('Default', 2631) ('GetWindow', 2615) ('Unknown', 2524) ('@.rsrc', 2399) ('</trustInfo>', 1303) ('`.rsrc', 122)
# cluster: 1, size: 1
# ('F0@(BB', 13)

# %%
PE_stopword = set()

for sig, cnt in signatures.items():
	print(f'{sig}:\t{cnt}')
	PE_stopword.add(sig)

with open('./datasets/pkl/pe_stopword.pkl', 'wb') as f:
	pickle.dump(PE_stopword, f)
# Out:
# String:	15843
# Thread:	14031
# System:	11916
# .rdata:	11717
# .idata:	11167
# Exception:	10937
# GetCurrentProcess:	10378
# Object:	8212
# A_A^A]:	7181
# Delete:	7141
#       :	7133
# 0123456789:	6026
# Version:	5854
# GetValue:	5598
# !This program cannot be run in DOS mode.:	5285
# ExitProcess:	5057
# KERNEL32:	4878
# .reloc:	4395
# @.data:	3999
# TerminateProcess:	3995
# static :	2846
# atexit:	2700
# Default:	2631
# GetWindow:	2615
# Unknown:	2524
# @.rsrc:	2399
# </trustInfo>:	1303
# `.rsrc:	122
# F0@(BB:	13

# %%
with open("./res/PE_signature.pkl", "rb") as f:
    pe_sig = pickle.load(f)

# %%
pe_signatures = dict()

print('SIGNAURE')
for idx, sig in enumerate(pe_sig.values()):
    print(f'cluster: {idx}, size: {len(sig)}')
    for j in sig:
        if j[0] not in pe_signatures:
            pe_signatures[j[0]] = 0
        pe_signatures[j[0]] += j[1]
        print(j, end=" ")
    print()
# Out:
# SIGNAURE
# cluster: 0, size: 91
# ('Delete', 17858) ('ExitProcess', 13513) ('Exception', 13364) ('System', 12775) ('GetProcAddress', 12421) ('LoadLibraryA', 12023) ('user32', 11764) ('advapi32', 10161) ('RegCloseKey', 9995) ('CloseHandle', 9885) ('!This program cannot be run in DOS mode.', 8859) ('kernel32', 8343) ('WriteFile', 8152) ('VirtualFree', 7675) ('VirtualAlloc', 7296) ('gram must be run ', 7120) ('GetCurrentThread', 6939) ('GetLastError', 6782) ('oleaut32.dll', 6375) ('ReadFile', 6369) ('KERNEL32.DLL', 6353) ('USER32', 6315) ('GetFileSize', 6314) ('FindClose', 6247) ('CharNextA', 6175) ('SetFilePointer', 6154) ('EnterCriticalSection', 5961) ('GetFileType', 5673) ('TObject', 5574) ('CreateFileA', 5569) ('RtlUnwind', 5425) ('LocalFree', 5279) ('TlsSetValue', 5199) ('WideCharToMultiByte', 5123) ('Windows', 5113) ('.reloc', 4369) ('KERNEL32.dll', 4004) ('ADVAPI32.dll', 3858) ('.rdata', 3675) ('`.data', 3434) ('StringX', 3378) ('CreateDirectoryA', 3041) ('ole32.dll', 2666) ('Interface', 2284) ('MSVBVM60.DLL', 1969) ('Boolean', 1897) ('`.rdat', 1709) ('SysFreeString', 1697) ('GetOEMCP', 1520) ('C:\\Program Files\\Microsoft Visual Studio\\VB98\\VB6.OLB', 1312) ('UpdateResourceA', 1298) ('September', 1295) ('version', 1290) ('[[[[[[', 1243) ('~ExC[)', 1193) ('{&8p^)j6', 1134) ('LookupPrivilegeValueA', 926) ('result', 687) ('MSVCRT.dll', 644) ('MM/dd/yy', 606) ('PathFileExistsA', 488) ('s`)L$4', 459) ('RtlMoveMemory', 456) ('t$t#t$l', 408) ('shlwapi', 390) ('! 6J[[', 361) ('lstrcmpiA', 358) ('__vbaStrCopy', 354) ('nKB\\`lll', 334) ('<<<<<<<<<<<<<<<<<<<<<<<<<<u9l', 321) ('[fPFMlllll', 271) ("'HSplit", 259) ('VC20XC00', 247) ('Dvn+|Ax', 239) ('class_main', 230) ('8x1Mjc<', 227) ('FillRect', 209) ('2 x|2 ', 200) ('T!pNJBN4', 188) ('u_:o 8', 173) ('. T:At', 143) ('8s9S=A', 143) ('invalid window size', 127) ('[hU-|x&Q `', 126) (':.datu', 118) ('proggam', 105) ('"M#m#F', 100) ('.pas7k', 92) ('This instance will close.', 73) ('Rich(!', 55) ('t"SS9] u', 53)
# cluster: 1, size: 4
# ('/scripts/inst_VER103.gz', 509) ('x@@P4`/!', 83) ('hitechcell.ca', 3) ('InternetConnectW', 3)
# cluster: 2, size: 1
# ('DefWindowProcW', 128)

# %%
for sig, cnt in pe_signatures.items():
    if sig not in PE_stopword:
        print(sig, cnt)
# Out:
# GetProcAddress 12421
# LoadLibraryA 12023
# user32 11764
# advapi32 10161
# RegCloseKey 9995
# CloseHandle 9885
# kernel32 8343
# WriteFile 8152
# VirtualFree 7675
# VirtualAlloc 7296
# gram must be run  7120
# GetCurrentThread 6939
# GetLastError 6782
# oleaut32.dll 6375
# ReadFile 6369
# KERNEL32.DLL 6353
# USER32 6315
# GetFileSize 6314
# FindClose 6247
# CharNextA 6175
# SetFilePointer 6154
# EnterCriticalSection 5961
# GetFileType 5673
# TObject 5574
# CreateFileA 5569
# RtlUnwind 5425
# LocalFree 5279
# TlsSetValue 5199
# WideCharToMultiByte 5123
# Windows 5113
# KERNEL32.dll 4004
# ADVAPI32.dll 3858
# `.data 3434
# StringX 3378
# CreateDirectoryA 3041
# ole32.dll 2666
# Interface 2284
# MSVBVM60.DLL 1969
# Boolean 1897
# `.rdat 1709
# SysFreeString 1697
# GetOEMCP 1520
# C:\Program Files\Microsoft Visual Studio\VB98\VB6.OLB 1312
# UpdateResourceA 1298
# September 1295
# version 1290
# [[[[[[ 1243
# ~ExC[) 1193
# {&8p^)j6 1134
# LookupPrivilegeValueA 926
# result 687
# MSVCRT.dll 644
# MM/dd/yy 606
# PathFileExistsA 488
# s`)L$4 459
# RtlMoveMemory 456
# t$t#t$l 408
# shlwapi 390
# ! 6J[[ 361
# lstrcmpiA 358
# __vbaStrCopy 354
# nKB\`lll 334
# <<<<<<<<<<<<<<<<<<<<<<<<<<u9l 321
# [fPFMlllll 271
# 'HSplit 259
# VC20XC00 247
# Dvn+|Ax 239
# class_main 230
# 8x1Mjc< 227
# FillRect 209
# 2 x|2  200
# T!pNJBN4 188
# u_:o 8 173
# . T:At 143
# 8s9S=A 143
# invalid window size 127
# [hU-|x&Q ` 126
# :.datu 118
# proggam 105
# "M#m#F 100
# .pas7k 92
# This instance will close. 73
# Rich(! 55
# t"SS9] u 53
# /scripts/inst_VER103.gz 509
# x@@P4`/! 83
# hitechcell.ca 3
# InternetConnectW 3
# DefWindowProcW 128
